# %%
from rdkit import Chem
from rdkit.Chem import PandasTools
from IPython.display import Image
import pandas as pd

# サンプルのデータフレームを作成
data = {'ID': [1, 2, 3],
        'SMILES': ['CCO', 'CCN', 'C=O']}
df = pd.DataFrame(data)

# SMILESからRDKitの分子オブジェクトを作成し、データフレームに追加
PandasTools.AddMoleculeColumnToFrame(df, smilesCol='SMILES')

# %%
df
# Out:
#    ID SMILES                                              ROMol
# 0   1    CCO  <rdkit.Chem.rdchem.Mol object at 0x00000120AC6...
# 1   2    CCN  <rdkit.Chem.rdchem.Mol object at 0x00000120C00...
# 2   3    C=O  <rdkit.Chem.rdchem.Mol object at 0x00000120C00...

# %%
PandasTools.AddMoleculeColumnToFrame(df, smilesCol='SMILES')
df

# %%
# 分子データフレームをグリッド画像に変換
img = PandasTools.FrameToGridImage(df)

# %%
# 分子データフレームをグリッド画像に変換
img = PandasTools.FrameToGridImage(df, legendsCol='ID', molsPerRow=3)

# %%
img

# %%
from rdkit import Chem
from rdkit.Chem import PandasTools
from IPython.display import Image

# サンプルのデータフレームを作成
data = {'ID': [1, 2, 3],
        'SMILES': ['CCO', 'CCN', 'C=O']}
df = pd.DataFrame(data)

# SMILESからRDKitの分子オブジェクトを作成し、データフレームに追加
PandasTools.AddMoleculeColumnToFrame(df, 'SMILES', 'Molecule')

# %%
df
# Out:
#    ID SMILES                                           Molecule
# 0   1    CCO  <rdkit.Chem.rdchem.Mol object at 0x00000120C00...
# 1   2    CCN  <rdkit.Chem.rdchem.Mol object at 0x00000120C00...
# 2   3    C=O  <rdkit.Chem.rdchem.Mol object at 0x00000120C00...
