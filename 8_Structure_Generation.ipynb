# %% [markdown]
# # 情報活用講座：　ケモインフォマテックス 編
# # 第6回：　BRICSを使った構造生成と仮想分子ライブラリ

# %% [markdown]
# ## 底本
# 船津 公人、柴山 翔二郎 **『実践 マテリアルズインフォマティクス　Pythonによる材料設計のための機械学習』**、近代科学社、2020
# 第８章　8.1.2　RECAPとBRICSを利用した構造生成
# 第９章　9.3.1　並列処理を用いた構造生成
#
#
# ## データセット
# delaney-processed.csvは1128化合物の水溶解度についてのデータセットです。このデータセットは、Delaneyの論文『ESOL: Estimating Aqueous Solubility Directly from Molecular Structure』[1] で発表されたものに基づいています。
#
# [1] John S. Delaney, "ESOL:  Estimating Aqueous Solubility Directly from Molecular Structure", J. Chem. Inf. Comput. Sci. 44, 1000–1005 (2004) (DOI: 10.1021/ci034243x)
#
# Delaney-processed.csvは、分子の化学式、SMILES表記、また、水溶解度としてオクタノール水分配係数が含まれており、これらの特性は薬物探索や環境影響評価などの目的で使用されています。
#
#
# 1. Compound ID	：化合物ID
# 1. ESOL predicted log solubility in mols per litre　：log水溶解度（オクタノール水分配係数）の予測値
# 1. Minimum Degree：　最小次数
# 1. Molecular Weight：分子量
# 1. Number of H-Bond Donors	：　水素結合に関与するDonor数
# 1. Number of Rings	：芳香環の数
# 1. Number of Rotatable Bonds　：　回転可能結合数
# 1. Polar Surface Area　：　極性表面積
# 1. measured log solubility in mols per litre：log水溶解度の実測値
# 1. smiles：SMILES表記
#
#
# ## pythonライブラリ
#
#
# **NumPy**：　高性能の数値計算やデータ処理に特化したPythonのライブラリです。NumPyは多次元の配列や行列を効率的に操作する機能を提供し、科学技術計算やデータ解析の分野で広く使用されています。
#
# **Pandas**：　データ操作と解析のための高レベルのPythonライブラリです。Pandasは、テーブル形式のデータを効率的に処理し、データのフィルタリング、変換、集約、および結合などの機能を提供します。データの整形やクリーニング、欠損値の処理などを容易に行うことができます。
#
# **Matplotlib**：　Pythonでデータを可視化するための強力なライブラリです。Matplotlibは、グラフや図を描画するための多様な機能を提供し、折れ線グラフ、ヒストグラム、散布図、バーチャートなどの多くのプロットスタイルをサポートしています。データの傾向や関係性を視覚的に理解するための強力なツールです。
#
# **RDKit**：　RDKitは、化学情報学や薬学の分野で広く使用されるオープンソースのソフトウェア開発キットです。RDKitはPythonで実装されており、様々な化学情報の処理や分子の構造解析、化学反応の予測などをサポートします。
#
# ## 目標
#
# 分子のフラグメント化アルゴリズムである**BRICS（Breaking of Retrosynthetically Interesting Chemical Substructures)** [2]を使い、仮想的な分子ライブラリを作成します。BRICSを使った分子の構造生成についてPythonで学ぶポイントを以下にまとめました。
#
#
# * BRICSの適用: RDKitの`rdkit.Chem.BRICS.BRICSDecompose()`メソッドを使用して、BRICSを適用し分子を分解します。このメソッドは、分解された部分構造のジェネレータを返します。
#
# * 生成された部分構造の操作: 分解された部分構造は、Pythonのリストとして取得できます。これらの部分構造を組み合わせて新しい分子を作成するために、必要な操作を実行できます。例えば、部分構造を結合したり、部分構造を変更したりすることができます。
#
# * 新しい分子の生成: 部分構造の組み合わせに基づいて、`rdkit.Chem.BRICS.BRICS.BRICSBuild()`メソッドから新しい分子を生成します。
#
#
# [2] Jörg Degen, Christof Wegscheid-Gerlach, Andrea Zaliani, Matthias Rarey, 「On the Art of Compiling and Using ‘Drug‐Like’ Chemical Fragment Spaces」, ChemMedChem, 3, 1503. 2008. (DOI:10.1002/cmdc.200800178)

# %% [markdown]
# # Google Colabにおける環境設定
# google colab環境でなければ実行不要

# %%
# !pip install rdkit-pypi
# !git clone https://github.com/ARIM-Training/Training_python_4.git
# %cd Training_python_4

# %% [markdown]
# ## 1.分子構造データの読み込み （底本 P.99）
# ### 汎用ライブラリのインポート

# %%
#データ構造化ライブラリ
import pandas as pd 
import numpy as np

#記述子ライブラリ
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw

from warnings import filterwarnings
filterwarnings('ignore')# 警告を無視

# %% [markdown]
# ### サンプルファイルの読み込み
#
# ここでもdelaney-processed.csvを使います。pandasの`read_csv()`からデータフレーム（DataFrame）オブジェクトとして変数dfに格納します。

# %%
df = pd.read_csv('./data/dataset/delaney-processed.csv')
df['mol'] = df['smiles'].apply(Chem.MolFromSmiles)
df
# Out:
#          Compound ID  ESOL predicted log solubility in mols per litre  \
# 0          Amigdalin                                           -0.974
# 1           Fenfuram                                           -2.885
# 2             citral                                           -2.579
# 3             Picene                                           -6.618
# 4          Thiophene                                           -2.232
# ...              ...                                              ...
# 1123       halothane                                           -2.608
# 1124          Oxamyl                                           -0.908
# 1125       Thiometon                                           -3.323
# 1126  2-Methylbutane                                           -2.245
# 1127        Stirofos                                           -4.320
#
#       Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# 0                  1           457.432                        7
# 1                  1           201.225                        1
# 2                  1           152.237                        0
# 3                  2           278.354                        0
# 4                  2            84.143                        0
# ...              ...               ...                      ...
# 1123               1           197.381                        0
# 1124               1           219.266                        1
# 1125               1           246.359                        0
# 1126               1            72.151                        0
# 1127               1           365.964                        0
#
#       Number of Rings  Number of Rotatable Bonds  Polar Surface Area  \
# 0                   3                          7              202.32
# 1                   2                          2               42.24
# 2                   0                          4               17.07
# 3                   5                          0                0.00
# 4                   1                          0                0.00
# ...               ...                        ...                 ...
# 1123                0                          0                0.00
# 1124                0                          1               71.00
# 1125                0                          7               18.46
# 1126                0                          1                0.00
# 1127                1                          5               44.76
#
#       measured log solubility in mols per litre  \
# 0                                        -0.770
# 1                                        -3.300
# 2                                        -2.060
# 3                                        -7.870
# 4                                        -1.330
# ...                                         ...
# 1123                                     -1.710
# 1124                                      0.106
# 1125                                     -3.091
# 1126                                     -3.180
# 1127                                     -4.522
#
#                                                  smiles  \
# 0     OCC3OC(OCC2OC(OC(C#N)c1ccccc1)C(O)C(O)C2O)C(O)...
# 1                                Cc1occc1C(=O)Nc2ccccc2
# 2                                  CC(C)=CCCC(C)=CC(=O)
# 3                    c1ccc2c(c1)ccc3c2ccc4c5ccccc5ccc43
# 4                                               c1ccsc1
# ...                                                 ...
# 1123                                   FC(F)(F)C(Cl)Br
# 1124                          CNC(=O)ON=C(SC)C(=O)N(C)C
# 1125                                  CCSCCSP(=S)(OC)OC
# 1126                                            CCC(C)C
# 1127              COP(=O)(OC)OC(=CCl)c1cc(Cl)c(Cl)cc1Cl
#
#                                                     mol
# 0     <rdkit.Chem.rdchem.Mol object at 0x00000241B6E...
# 1     <rdkit.Chem.rdchem.Mol object at 0x00000241B6E...
# 2     <rdkit.Chem.rdchem.Mol object at 0x00000241B6E...
# 3     <rdkit.Chem.rdchem.Mol object at 0x00000241B6E...
# 4     <rdkit.Chem.rdchem.Mol object at 0x00000241B6E...
# ...                                                 ...
# 1123  <rdkit.Chem.rdchem.Mol object at 0x00000241B6E...
# 1124  <rdkit.Chem.rdchem.Mol object at 0x00000241B6E...
# 1125  <rdkit.Chem.rdchem.Mol object at 0x00000241B6E...
# 1126  <rdkit.Chem.rdchem.Mol object at 0x00000241B6E...
# 1127  <rdkit.Chem.rdchem.Mol object at 0x00000241B6E...
#
# [1128 rows x 11 columns]

# %%
df['mol'][0]

# %% [markdown]
# ## 2.BRICSによる分子ライブラリの作成

# %% [markdown]
#  BRICSを使用するためには、RDKitでBRICSモジュールを読み込む必要があります。以下のコードを使用して、`BRICS`モジュールをインポートします。

# %%
from rdkit.Chem import BRICS

# %% [markdown]
# ### フラグメント化（部分構造化）
#
# RDKitの`BRICS.BRICSDecompose()`メソッドは、分子をBRICS (Bristol-Myers Squibb Reaction-Inspired Clustering System) 法に基づいてフラグメント化するための機能を提供します。
# `BRICSDecompose()`によって、元の分子が複数のフラグメントに分割され、それぞれのフラグメントが独立した化学構造となります。なお、デフォルトでは切断位置にダミーアトムを挿入して表示されます。
#
# 化合物IDゼロ番目をフラグメント化させると、6つに分解されることがわかります。

# %%
frag0 = BRICS.BRICSDecompose(df['mol'][0])
frag0
# Out:
# {'[13*]C1OC([13*])C(O)C(O)C1O',
#  '[16*]c1ccccc1',
#  '[3*]O[3*]',
#  '[4*]C([8*])C#N',
#  '[4*]C[8*]',
#  '[8*]CO'}

# %%
 len(frag0)
# Out:
# 6

# %% [markdown]
# `BRICSDecompose()`の引数で`returnMols`オプションでTrueを指定しフラグメントをMol化させておくと、`MolsToGridImage()`関数で視覚化することが楽になります。上記の6つの部分骨格は、次のような構成になっています。

# %%
frag0_mols = BRICS.BRICSDecompose(df['mol'][0], returnMols=True)
Draw.MolsToGridImage(frag0_mols, molsPerRow=3)

# %% [markdown]
# 【練習】別分子のフラグメント化を見てみることにしましょう。

# %%
df['mol'][20]

# %%
frag20 = BRICS.BRICSDecompose(df['mol'][20])
frag20
# Out:
# {'[16*]c1c(Cl)ccc(Cl)c1Cl', '[16*]c1ccc(Cl)cc1Cl'}

# %%
frag20_mols = BRICS.BRICSDecompose(df['mol'][20], returnMols=True)
Draw.MolsToGridImage(frag20_mols, molsPerRow=3)

# %% [markdown]
# ### フラグメントライブラリ作成
# 上記は1分子でのフラグメントの方法でした。次はdelaney-processed.csvにある1128分子のフラグメント化を行います。1128化合物の全フラグメントを重複のないリスト形式としてまとめライブラリ化します。
#
# まず、三項演算子を使い、df['mol']を、逐次、`BRICSDecompose()`関数へmolという変数で受け渡し`list()`関数でリスト配置をとらせます。

# %%
fragments = [list(BRICS.BRICSDecompose(mol)) for mol in df['mol']]
fragments
# Out:
# [['[13*]C1OC([13*])C(O)C(O)C1O',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[4*]C([8*])C#N',
#   '[4*]C[8*]',
#   '[8*]CO'],
#  ['[1*]C([6*])=O', '[16*]c1ccccc1', '[16*]c1ccoc1C', '[5*]N[5*]'],
#  ['[7*]CC=O', '[7*]CCCC([7*])C', '[7*]C(C)C'],
#  ['c1ccc2c(c1)ccc1c2ccc2c3ccccc3ccc21'],
#  ['c1ccsc1'],
#  ['c1ccc2scnc2c1'],
#  ['[16*]c1c(Cl)cc(Cl)cc1Cl', '[16*]c1c(Cl)cccc1Cl'],
#  ['CC12CCC3c4ccc(O)cc4CCC3C1CCC2O'],
#  ['ClC1=C(Cl)C2(Cl)C3C4CC(C5OC45)C3C1(Cl)C2(Cl)Cl'],
#  ['[3*]OC', '[16*]c1cc2c(cc1[16*])C1C(=O)c3ccc4c(c3OC1CO2)CC(C(=C)C)O4'],
#  ['O=C1CCCN1'],
#  ['Clc1ccc2ccccc2c1'],
#  ['C=CCCC'],
#  ['[15*]C1([15*])C(=O)NCNC1=O', '[16*]c1ccccc1', '[8*]CC'],
#  ['CCCCCCCCCCCCCC'],
#  ['CC(C)Cl'],
#  ['CCC(C)CO'],
#  ['N#Cc1ccccc1'],
#  ['[4*]CC', '[14*]c1cc(C)nc([14*])n1', '[8*]C(C)C', '[3*]OP(=S)(O[3*])O[3*]'],
#  ['CCCCCCCCCC(C)O'],
#  ['[16*]c1ccc(Cl)cc1Cl', '[16*]c1c(Cl)ccc(Cl)c1Cl'],
#  ['[15*]C1CCCCC1', '[9*]n1c(=O)[nH]c2c(c1=O)CCC2'],
#  ['[4*]CC', '[3*]OP(=S)(O[3*])SCS[11*]'],
#  ['[16*]c1ccc([16*])cc1', '[1*]C(C)=O', '[4*]CC', '[3*]O[3*]', '[5*]N[5*]'],
#  ['[4*]CC',
#   '[8*]C(F)(F)F',
#   '[5*]N([5*])[5*]',
#   '[16*]c1cc([N+](=O)[O-])c([16*])c([N+](=O)[O-])c1N'],
#  ['CCCCCCCO'],
#  ['Cn1c(=O)c2[nH]cnc2n(C)c1=O'],
#  ['[15*]C1([15*])C(=O)NC(=O)NC1=O', '[8*]CC', '[8*]CCCC'],
#  ['ClC(Cl)=C(c1ccc(Cl)cc1)c1ccc(Cl)cc1'],
#  ['[3*]OC', '[1*]C(=O)CCCCCCC'],
#  ['[8*]CC', '[16*]c1ccc([16*])cc1'],
#  ['[4*]CC', '[3*]OP(=S)(O[3*])SCS[11*]', '[4*]C(C)(C)C'],
#  ['[3*]OC',
#   '[16*]c1cccc([16*])c1',
#   '[3*]O[3*]',
#   '[16*]c1cccc(C)c1',
#   '[5*]N[5*]',
#   '[1*]C([1*])=O'],
#  ['C=C(Cl)Cl'],
#  ['Cc1cccc2c1Cc1ccccc1-2'],
#  ['CCCCC=O'],
#  ['[16*]c1ccccc1', '[5*]N[5*]'],
#  ['[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[5*]N(C)C',
#   '[4*]CCCC[4*]',
#   '[1*]C(=O)S[11*]'],
#  ['[3*]OP(=S)(O[3*])S[11*]', '[5*]N1CCCCC1C', '[1*]C(=O)C[4*]', '[4*]CCC'],
#  ['CCCCCCCI'],
#  ['[16*]c1cccc(Cl)c1', '[16*]c1ccccc1'],
#  ['C=CCCCO'],
#  ['O=C1NC(=O)C2(CCC2)C(=O)N1'],
#  ['[8*]C(C)C', '[15*]C1CCC(C)CC1O'],
#  ['[4*]C(C)C', '[3*]OC=O'],
#  ['CCCCCC(C)O'],
#  ['[16*]c1ccc(Br)cc1', '[5*]N[5*]', '[1*]C(C)=O'],
#  ['[16*]c1ccccc1', '[9*]n1ncc(N)c(Br)c1=O'],
#  ['[3*]OC',
#   '[1*]C(=O)C1=C(C)NC(C)=C(C([1*])=O)C1[15*]',
#   '[16*]c1ccccc1[N+](=O)[O-]'],
#  ['Cc1ccc2ccc(C)nc2c1'],
#  ['C#CCCCCCC'],
#  ['[8*]CC', '[15*]C1(C2=CCCCC2)C(=O)NC(=O)NC1=O'],
#  ['c1ccc2c(c1)ccc1c3ccccc3ccc21'],
#  ['[8*]C(C)CC', '[9*]n1c(=O)[nH]c(C)c(Br)c1=O'],
#  ['[16*]c1c(Cl)c(Cl)cc(Cl)c1Cl', '[16*]c1cccc(Cl)c1Cl'],
#  ['Cc1ccccc1O'],
#  ['CC(C)CCC(C)(C)C'],
#  ['Cc1ccc(C)c2ccccc12'],
#  ['Cc1cc2c3ccccc3ccc2c2ccccc12'],
#  ['CCCC(C)=O'],
#  ['[16*]c1c(Cl)c(Cl)cc(Cl)c1Cl'],
#  ['[3*]O[3*]', '[1*]C(=O)CC', '[4*]CCC'],
#  ['[15*]C1(O)C(O)CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC21C', '[6*]C(=O)CO'],
#  ['Nc1ccc(O)cc1'],
#  ['[1*]C(=O)C[8*]',
#   '[16*]c1ccccc1',
#   '[4*]C[8*]',
#   '[5*]N[5*]',
#   '[9*]n1ccnc1[N+](=O)[O-]'],
#  ['[16*]c1ccc(Cl)cc1', '[15*]C1CCC(C2=C(O)C(=O)c3ccccc3C2=O)CC1'],
#  ['[4*]CC', '[5*]N([5*])[5*]', '[14*]c1nc([14*])nc(Cl)n1', '[5*]N[5*]'],
#  ['[14*]c1cnccn1', '[6*]C(N)=O'],
#  ['[1*]C(N)=O', '[5*]N[5*]', '[1*]C(=O)C(Br)(CC)CC'],
#  ['[16*]c1ccccc1Cl'],
#  ['O=C1CN(N=Cc2ccc([N+](=O)[O-])o2)C(=O)N1'],
#  ['[16*]c1ccc(Cl)cc1Cl', '[16*]c1ccc([N+](=O)[O-])cc1', '[3*]O[3*]'],
#  ['CC12CCC(CC1=O)C2(C)C'],
#  ['[8*]CC=C', '[15*]C1([15*])C(=O)NC(=O)NC1=O', '[16*]c1ccccc1'],
#  ['[4*]CC', '[3*]O[3*]', '[1*]C(=O)CCCC'],
#  ['[4*]CCC(C)C', '[3*]O[3*]', '[1*]C(C)=O'],
#  ['[3*]OC[8*]',
#   '[16*]c1ccccc1',
#   '[10*]N1C(=O)NC([13*])([13*])C1=O',
#   '[1*]C(=O)CCCCC'],
#  ['[16*]c1cccc(Cl)c1', '[16*]c1cc(Cl)ccc1Cl'],
#  ['CCCBr'],
#  ['[8*]C[8*]',
#   '[8*]CCC',
#   '[13*]C1COC([13*])([13*])O1',
#   '[16*]c1ccc(Cl)cc1Cl',
#   '[9*]n1cncn1'],
#  ['[1*]C(=O)C[4*]', '[5*]N(C)C=O', '[11*]SP(=S)(OC)OC'],
#  ['Cc1ncnc2nccnc12'],
#  ['NC(N)=S'],
#  ['Cc1ccc(C)cc1'],
#  ['[8*]CC', '[16*]c1ccccc1[16*]'],
#  ['ClC(Cl)(Cl)C(Cl)(Cl)Cl'],
#  ['[16*]c1ccc([16*])cc1',
#   '[1*]C(=O)C([8*])C(C)C',
#   '[16*]c1cccc([16*])c1',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[4*]C([8*])C#N',
#   '[3*]OC(F)F'],
#  ['CCC[N+](=O)[O-]'],
#  ['[15*]C1CCC(C)CC1=O', '[8*]C(C)C'],
#  ['[4*]CC', '[5*]N1c2cc(Cl)ccc2NC(=O)c2cccnc21'],
#  ['O=[N+]([O-])c1cccc(Cl)c1Cl'],
#  ['[8*]CC=C', '[15*]C1([15*])C(=O)NC(=S)NC1=O', '[8*]C(C)CCC'],
#  ['c1ccc2c(c1)-c1cccc3cccc-2c13'],
#  ['[3*]O[3*]', '[4*]C(C)C', '[4*]CCC'],
#  ['Cc1cc(C)c2ccccc2c1'],
#  ['[16*]c1ccc(O)cc1', '[7*]C([8*])CC'],
#  ['N#Cc1c(Cl)c(Cl)c(Cl)c(C#N)c1Cl'],
#  ['[16*]c1cc(Cl)ccc1Cl', '[16*]c1ccc(Cl)c(Cl)c1'],
#  ['[16*]c1ccccc1', '[13*]C1CO1'],
#  ['[16*]c1ccccc1', '[8*]C(C)C'],
#  ['[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C', '[6*]C(=O)CO'],
#  ['Clc1c(Cl)c(Cl)c2nccnc2c1Cl'],
#  ['OC1COC(O)C(O)C1O'],
#  ['ClCCl'],
#  ['[16*]c1cccc2ccccc12', '[8*]CC'],
#  ['COC=O'],
#  ['O=[N+]([O-])c1ccccc1O'],
#  ['Cc1c[nH]c(=O)[nH]c1=O'],
#  ['CC(C)C'],
#  ['[13*]C1OC([13*])C(O)C1O', '[9*]n1cnc2c(O)ncnc21', '[8*]CO'],
#  ['N#Cc1cc(I)c(O)c(I)c1'],
#  ['[1*]C([6*])=O',
#   '[16*]c1ccc([N+](=O)[O-])cc1Cl',
#   '[16*]c1cc(Cl)ccc1O',
#   '[5*]N[5*]'],
#  ['CCCCC'],
#  ['Oc1ccccc1'],
#  ['Nc1ccc2cc3ccccc3cc2c1'],
#  ['Cn1cnc2c1c(=O)[nH]c(=O)n2C'],
#  ['c1ccc2cnccc2c1'],
#  ['[16*]c1ccc(Cl)cc1',
#   '[4*]C(C)C',
#   '[11*]SP(=S)(OC)OC',
#   '[1*]C(=O)C[4*]',
#   '[5*]N([5*])[5*]'],
#  ['[8*]CCCCCC', '[16*]c1ccccc1'],
#  ['[16*]c1ccccc1', '[16*]c1ccccc1Cl'],
#  ['C=C(C)CCC'],
#  ['CC(C)C(C)C(C)C'],
#  ['Clc1cc(Cl)c(Cl)c(Cl)c1Cl'],
#  ['O=[N+]([O-])c1cccc(O)c1'],
#  ['C=CCCCCCCCC'],
#  ['[4*]CC([4*])C[4*]', '[3*]O[3*]', '[1*]C(C)=O'],
#  ['[5*]N(C)C', '[14*]c1nc(C)c([16*])c(O)n1', '[8*]CCCC'],
#  ['[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[4*]C([8*])C#N',
#   '[1*]C([6*])=O',
#   '[16*]c1ccc(F)c([16*])c1',
#   '[15*]C1C(C=C(Cl)Cl)C1(C)C'],
#  ['c1ccncc1'],
#  ['CCCCCCCBr'],
#  ['Cc1ccncc1C'],
#  ['[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3(F)C(O)CC21C', '[6*]C(=O)CO'],
#  ['[4*]CC',
#   '[3*]O[3*]',
#   '[11*]S[11*]',
#   '[4*]C[8*]',
#   '[16*]c1ccccc1[16*]',
#   '[5*]NC',
#   '[1*]C([1*])=O'],
#  ['[4*]CC', '[3*]O[3*]', '[1*]C(=O)CC([1*])=O'],
#  ['C=C(C)C1CC=C(C)CC1'],
#  ['c1ccc2c(c1)CCC2'],
#  ['[16*]c1ccc(O)cc1', '[8*]C(C)(C)C'],
#  ['O=C1NC(=O)C2(CC2)C(=O)N1'],
#  ['Clc1cccc(I)c1'],
#  ['Brc1cccc2ccccc12'],
#  ['[7*]CC', '[7*]CCC'],
#  ['Cc1cccc(C)n1'],
#  ['ClC=C(Cl)Cl'],
#  ['Nc1cccc2ccccc12'],
#  ['Cc1cccc(C)c1'],
#  ['Oc1ncc2nccnc2n1'],
#  ['CO'],
#  ['[15*]C1([15*])C(=O)NC(=O)NC1=O', '[8*]CC', '[8*]CCC(C)C'],
#  ['CCC(C)=O'],
#  ['O=c1[nH]cc(F)c(=O)[nH]1'],
#  ['[13*]C1OC([13*])C(O)C1O', '[9*]n1ccc2c(N)ncnc21', '[8*]CO'],
#  ['Oc1cccc(O)c1'],
#  ['CCCCCCO'],
#  ['CCCCCCl'],
#  ['C=CC=C'],
#  ['[4*]CCC', '[3*]O[3*]', '[1*]C(C)=O'],
#  ['Oc1ccc2c(c1)CCCC2'],
#  ['NC(=O)CCl'],
#  ['[3*]OP(=S)(OC)OC', '[16*]c1cc(Cl)c(I)cc1Cl'],
#  ['Cc1ccc(Cl)cc1'],
#  ['[8*]C(C)(C)C', '[14*]c1nnc([14*])n(N)c1=O', '[11*]SC'],
#  ['[16*]c1ccc(C)cc1',
#   '[16*]c1cccc(C)c1',
#   '[3*]OP(=O)(O[3*])O[3*]',
#   '[16*]c1ccccc1C'],
#  ['CCCCCC=O'],
#  ['[1*]C([6*])=O', '[3*]O[3*]', '[16*]c1ccc(N)cc1', '[4*]CCCC'],
#  ['Cc1ccc2c(c1)Oc1ncc(N)cc1C(=O)N2C'],
#  ['[7*]CCCC([7*])C', '[7*]CCO', '[7*]C(C)C'],
#  ['[16*]c1ccc(Cl)cc1', '[16*]c1ccccc1Cl'],
#  ['[3*]OC[8*]',
#   '[10*]N1C(=O)NC([13*])([13*])C1=O',
#   '[16*]c1ccccc1',
#   '[1*]C(=O)CCCCCCC'],
#  ['CC[N+](=O)[O-]'],
#  ['[4*]CC(=C)C',
#   '[4*]CC',
#   '[8*]C(F)(F)F',
#   '[16*]c1cc([N+](=O)[O-])c([16*])c([N+](=O)[O-])c1',
#   '[5*]N([5*])[5*]'],
#  ['Clc1ccc(Cl)c(Cl)c1Cl'],
#  ['[3*]O[3*]', '[1*]C(N)=O', '[4*]CC(C)(C[4*])CCC'],
#  ['[15*]C1CCC2C3CC=C4CC(O)CCC4(C)C3CCC12C', '[6*]C(C)=O'],
#  ['CI'],
#  ['[15*]C1CC(=O)NC(=O)C1', '[15*]C1CC(C)CC(C)C1=O', '[8*]CC([8*])O'],
#  ['[3*]OC[8*]',
#   '[10*]N1C(=O)NC([13*])([13*])C1=O',
#   '[16*]c1ccccc1',
#   '[1*]C(=O)CCCCCC'],
#  ['CC1=CC(=O)CC(C)(C)C1'],
#  ['[8*]C(C)CC', '[8*]CC', '[15*]C1([15*])C(=O)NC(=O)NC1=O'],
#  ['CCCCC(=O)CCCC'],
#  ['[15*]C1([15*])CCC(=O)NC1=O', '[16*]c1ccccc1', '[8*]CC'],
#  ['CCC(C)CC'],
#  ['[16*]c1ccc([16*])cc1',
#   '[4*]CC',
#   '[16*]c1cccc([16*])c1',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[4*]C[8*]',
#   '[4*]CC([8*])(C)C'],
#  ['[16*]c1ccccc1C', '[9*]n1c(C)nc2ccccc2c1=O'],
#  ['N#CCCl'],
#  ['[4*]CC', '[3*]OP(=S)(CC)O[3*]', '[16*]c1cc(Cl)c(Cl)cc1Cl'],
#  ['C#CC1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3CCC21C'],
#  ['c1ccnnc1'],
#  ['Clc1cc(Cl)c(Cl)c(Cl)c1'],
#  ['CC1COC2CC3(C)C(CC4C5C=C6CC(O)CCC6(C)CC5CCC43C)OC2C1'],
#  ['Nc1ccccc1O'],
#  ['[1*]C(=O)CCCCCCCC', '[3*]O[3*]', '[4*]CC'],
#  ['[3*]OC',
#   '[1*]C(=O)C([4*])C',
#   '[16*]c1c(C)cccc1C',
#   '[1*]C(=O)C[4*]',
#   '[5*]N([5*])[5*]'],
#  ['[3*]O[3*]', '[4*]C(C)C', '[16*]c1ccccc1[16*]', '[5*]NC', '[1*]C([1*])=O'],
#  ['CCC(C)Cl'],
#  ['Oc1ccc2ccccc2c1'],
#  ['[9*]n1nc([14*])oc1=O',
#   '[8*]C(C)(C)C',
#   '[3*]O[3*]',
#   '[4*]C(C)C',
#   '[16*]c1cc([16*])c(Cl)cc1Cl'],
#  ['C#CCCCC'],
#  ['C#CCCCCCCC'],
#  ['Cc1ccccc1Cl'],
#  ['[3*]O[3*]', '[4*]C(C)C'],
#  ['Nc1ccc(S(=O)(=O)c2ccc(N)cc2)cc1'],
#  ['CNN'],
#  ['C#CC'],
#  ['[4*]CC', '[3*]OP(=S)(O[3*])ON=C(C#N)c1ccccc1'],
#  ['[3*]O[3*]', '[4*]C(C)C', '[7*]C(C)OP(=S)(NCC)OC', '[1*]C(=O)C[7*]'],
#  ['C=CC=O'],
#  ['O=c1[nH]cnc2nc[nH]c12'],
#  ['Oc1ccc2ncccc2c1'],
#  ['Fc1ccccc1'],
#  ['CCCCl'],
#  ['[4*]CC', '[3*]O[3*]', '[1*]C(C)=O'],
#  ['CCCC(C)(C)C'],
#  ['Cc1cc(C)c(C)c(C)c1C'],
#  ['CC12CCC(CC1)C(C)(C)O2'],
#  ['[3*]O[3*]', '[1*]C(=O)CCCCCCCCC([1*])=O', '[4*]CCCC'],
#  ['[16*]c1ccc(Cl)cc1'],
#  ['Cc1cccnc1C'],
#  ['C=C(C)C1CC=C(C)C(=O)C1'],
#  ['[4*]CC', '[16*]c1ccc(Cl)cc1', '[3*]OP(=S)(O[3*])SCS[11*]'],
#  ['[3*]OC',
#   '[13*]C1OC2COC(C)OC2C(O)C1O',
#   '[3*]OC1c2cc3c(cc2C(c2cc([16*])c(O)c([16*])c2)C2C(=O)OCC12)OCO3'],
#  ['c1cc2cccc3c4cccc5cccc(c(c1)c23)c54'],
#  ['Cc1ccc([N+](=O)[O-])cc1[N+](=O)[O-]'],
#  ['Brc1ccc2ccccc2c1'],
#  ['[5*]NC', '[1*]C([1*])=O', '[16*]c1cccc(N=CN(C)C)c1', '[3*]O[3*]'],
#  ['[3*]OC', '[14*]c1cnc2ncncc2n1'],
#  ['[15*]C1CC1', '[5*]N1c2ncccc2C(=O)Nc2c(C)ccnc21'],
#  ['[4*]CC', '[9*]n1nc([14*])nc1Cl', '[8*]C(C)C', '[3*]OP(=S)(O[3*])O[3*]'],
#  ['C=CC(=C)C'],
#  ['[7*]CCCC(C)(O)C=C', '[7*]C(C)C'],
#  ['[16*]c1ccc([16*])c(C)c1', '[3*]OP(=S)(OC)OC', '[11*]SC'],
#  ['OC1CCCCC1'],
#  ['[8*]CC=C', '[15*]C1(C)C(=O)NC(=O)NC1=O'],
#  ['CC12CCC3C(CCC4CC(O)CCC43C)C1CCC2=O'],
#  ['OCC(O)C(O)C(O)C(O)CO'],
#  ['[16*]c1ccc(C)cc1', '[16*]c1ccccc1'],
#  ['[4*]CC', '[4*]C(C)C', '[14*]c1nc([14*])nc(Cl)n1', '[5*]N[5*]'],
#  ['[16*]c1ccccc1', '[5*]NC(N)=S'],
#  ['CCCC(=O)CCC'],
#  ['CC(=O)C(C)(C)C'],
#  ['Oc1ccc(Cl)cc1'],
#  ['O=C1CCCCC1'],
#  ['Cc1cccc(N)c1'],
#  ['N#CC(Cl)(Cl)Cl'],
#  ['[16*]c1cccc([16*])c1',
#   '[8*]C(F)(F)F',
#   '[5*]NC',
#   '[9*]n1ncc([16*])c(Cl)c1=O'],
#  ['CCCCCCCCC(C)=O'],
#  ['[14*]c1nc([14*])nc(Cl)n1',
#   '[4*]CC',
#   '[4*]C(C)C',
#   '[5*]N[5*]',
#   '[5*]N([5*])[5*]'],
#  ['[4*]CC', '[1*]C([6*])=O', '[3*]O[3*]', '[16*]c1ccc(N)cc1'],
#  ['Clc1ccc(Cl)c(Cl)c1'],
#  ['Cc1nnc2n1-c1ccc(Cl)cc1C(c1ccccc1Cl)=NC2'],
#  ['Oc1ccccc1O'],
#  ['[4*]CC', '[5*]N1c2ncccc2C(=O)N(C)c2cccnc21'],
#  ['CSC'],
#  ['Cc1ccccc1Br'],
#  ['[4*]CC', '[3*]O[3*]', '[1*]C(N)=O'],
#  ['[1*]C(C)=O',
#   '[3*]O[3*]',
#   '[15*]C1([15*])CCC2C3C=C(C)C4=CC(=O)CCC4(C)C3CCC21C',
#   '[4*]C1([15*])CCC2C3C=C(C)C4=CC(=O)CCC4(C)C3CCC21C',
#   '[6*]C(C)=O'],
#  ['CC(C)C(O)C(C)C'],
#  ['c1ccc2ccccc2c1'],
#  ['[4*]CC', '[16*]c1ccccc1', '[5*]N[5*]'],
#  ['[16*]c1ccccc1', '[13*]C1([13*])NC(=O)NC1=O'],
#  ['Cc1c2ccccc2c(C)c2c1ccc1ccccc12'],
#  ['[4*]CC',
#   '[10*]N1C(=O)c2ccccc2C1=O',
#   '[4*]C([8*])CCl',
#   '[3*]OP(=S)(O[3*])S[11*]'],
#  ['[3*]OC', '[8*]C([8*])C(Cl)(Cl)Cl', '[16*]c1ccc([16*])cc1'],
#  ['[1*]C([6*])=O',
#   '[5*]N[5*]',
#   '[16*]c1c(F)cccc1F',
#   '[1*]C([1*])=O',
#   '[16*]c1cc(Cl)c(F)c(Cl)c1F'],
#  ['[3*]OC[8*]',
#   '[10*]N1C(=O)NC([13*])([13*])C1=O',
#   '[16*]c1ccccc1',
#   '[1*]C(=O)CCCC'],
#  ['[5*]N(C)C', '[16*]c1ccc(Cl)cc1', '[1*]C([1*])=O', '[5*]N[5*]'],
#  ['[16*]c1ccccc1F', '[9*]n1cncn1', '[16*]c1ccc(F)cc1', '[8*]CC([8*])([8*])O'],
#  ['[3*]O[3*]',
#   '[4*]CC([6*])=O',
#   '[15*]C1CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C1([15*])O',
#   '[1*]C(C)=O'],
#  ['CCCCBr'],
#  ['Brc1cc(Br)c(Br)cc1Br'],
#  ['CC(=O)CC(C)C'],
#  ['[4*]CC', '[15*]C1CCCCC1', '[5*]N([5*])[5*]', '[1*]C(=O)S[11*]'],
#  ['[3*]OC', '[16*]c1ccc(Cl)cc1'],
#  ['[16*]c1cccc([16*])c1',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[4*]C([8*])C#N',
#   '[1*]C([6*])=O',
#   '[15*]C1C(C=C(Br)Br)C1(C)C'],
#  ['[8*]CC=C', '[8*]C(C)CC', '[15*]C1([15*])C(=O)NC(=O)NC1=O'],
#  ['[16*]c1ccc([N+](=O)[O-])c(C)c1', '[3*]OP(=S)(OC)OC'],
#  ['Ic1cccc2ccccc12'],
#  ['OCC(O)C(O)C(O)C(O)CO'],
#  ['CCS'],
#  ['ClCC(Cl)Cl'],
#  ['[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[9*]n1nc(C)cc1[14*]',
#   '[5*]N(C)C',
#   '[1*]C([1*])=O'],
#  ['[6*]C(N)=O', '[16*]c1ccccc1O'],
#  ['Cc1ccccc1[N+](=O)[O-]'],
#  ['[15*]C1([15*])C(=O)NC(=O)NC1=O', '[8*]C(C)C'],
#  ['[16*]c1ccccc1C', '[8*]CC'],
#  ['CCCCCCCCl'],
#  ['[15*]C1([15*])C(=O)NC(=O)NC1=O', '[8*]CC'],
#  ['[16*]c1ccccc1', '[8*]CC[8*]'],
#  ['ClC(Cl)C(Cl)Cl'],
#  ['[3*]OC', '[5*]N1c2cc([16*])cc(C)c2NC(=O)c2cccnc21', '[4*]CC'],
#  ['Cc1ccc2c(ccc3ccccc32)c1'],
#  ['[1*]C([6*])=O', '[3*]O[3*]', '[16*]c1ccccc1[16*]', '[4*]CCCC'],
#  ['[3*]OC', '[16*]c1c(O)c(Cl)c(Cl)c(Cl)c1Cl'],
#  ['[4*]CC',
#   '[3*]OP(=O)(OC)OC',
#   '[1*]C(=O)C([7*])Cl',
#   '[4*]CC[7*]',
#   '[5*]N([5*])[5*]'],
#  ['CC12CCC3C(=CCc4cc(O)ccc43)C1CCC2=O'],
#  ['[4*]CC',
#   '[3*]OC',
#   '[3*]O[3*]',
#   '[14*]c1cc(Cl)nc(N(C=O)NS(=O)(=O)c2ccccc2[16*])n1',
#   '[1*]C([6*])=O'],
#  ['[3*]OC', '[16*]c1ccc([N+](=O)[O-])cc1'],
#  ['CCCCCCCl'],
#  ['[16*]c1cc(Cl)c(Cl)c(Cl)c1Cl'],
#  ['[13*]C1OC([13*])C(O)C(O)C1O',
#   '[4*]C1([13*])OC([13*])C(O)C1O',
#   '[3*]O[3*]',
#   '[13*]C1OC([13*])([13*])C(O)C1O',
#   '[4*]C[8*]',
#   '[8*]CO'],
#  ['CCCCCCCCCCCCCCCCCCCCCCCCCC'],
#  ['[4*]CC', '[5*]N1c2ccccc2N(C)C(=O)c2cccnc21'],
#  ['CC(Cl)Cl'],
#  ['Nc1ccc(S(N)(=O)=O)cc1'],
#  ['[16*]c1cc([N+](=O)[O-])c([16*])c([N+](=O)[O-])c1',
#   '[5*]N([5*])[5*]',
#   '[8*]C(C)C',
#   '[4*]CCC'],
#  ['ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl'],
#  ['[4*]CC',
#   '[3*]O[3*]',
#   '[4*]C(C)C',
#   '[3*]OP(=S)(NC(C)C)O[3*]',
#   '[1*]C([6*])=O',
#   '[16*]c1ccccc1[16*]'],
#  ['Clc1cccc(Cl)c1Cl'],
#  ['ClC(Cl)(Cl)Cl'],
#  ['O=[N+]([O-])c1ccc(Cl)c(Cl)c1'],
#  ['OC1CCCCCCC1'],
#  ['CC12CCC(=O)C=C1CCC1C2CCC2(C)C1CCC2(C)O'],
#  ['[16*]c1ccc([16*])cc1', '[4*]CC', '[3*]O[3*]', '[1*]C(N)=O', '[5*]N[5*]'],
#  ['CC1CCC(C)CC1'],
#  ['c1cnc2c(c1)ccc1ncccc12'],
#  ['[3*]OC', '[4*]C(C)(C)C'],
#  ['[3*]OC', '[7*]CC', '[16*]c1ccc([16*])cc1', '[7*]C[8*]'],
#  ['CCCCCCCCCCCCCCCCO'],
#  ['O=c1cc[nH]c(=O)[nH]1'],
#  ['Nc1ncnc2nc[nH]c12'],
#  ['[16*]c1cccc(Cl)c1Cl', '[16*]c1cc(Cl)c(Cl)cc1Cl'],
#  ['[8*]C([8*])([8*])O',
#   '[16*]c1ccc([16*])cc1',
#   '[3*]OC',
#   '[15*]C1CC1',
#   '[16*]c1cncnc1'],
#  ['c1ccc2c(c1)-c1cccc3c1c-2cc1ccccc13'],
#  ['[16*]c1ccccc1', '[1*]C([1*])=O', '[5*]N[5*]'],
#  ['[15*]C1([15*])C(=O)NC(=O)NC1=O', '[16*]c1ccccc1', '[8*]CC'],
#  ['[16*]c1ccc(Cl)cc1', '[16*]c1cccc(Cl)c1Cl'],
#  ['[16*]c1ccc([16*])cc1',
#   '[8*]C(C)C',
#   '[5*]N[5*]',
#   '[5*]N(C)C',
#   '[1*]C([1*])=O'],
#  ['[4*]CC',
#   '[14*]c1ccc(Cl)nn1',
#   '[11*]S[11*]',
#   '[1*]C(=O)C[4*]',
#   '[5*]N([5*])[5*]'],
#  ['CCC(C)(C)CO'],
#  ['[3*]O[3*]', '[1*]C(=O)CCC', '[4*]CCC'],
#  ['Cc1c([N+](=O)[O-])cc([N+](=O)[O-])cc1[N+](=O)[O-]'],
#  ['[12*]S(=O)(=O)c1ccccc1',
#   '[3*]OP(=S)(O[3*])S[11*]',
#   '[4*]C(C)C',
#   '[4*]CC[4*]',
#   '[5*]N[5*]'],
#  ['C1CCCCCC1'],
#  ['[4*]CCC', '[3*]OC=O'],
#  ['[16*]c1ccccc1C', '[8*]C(C)C'],
#  ['Nc1cccc(Cl)c1'],
#  ['CC(C)CC(C)C'],
#  ['c1ccc2c(c1)oc1ccccc12'],
#  ['[4*]CC', '[3*]OS(C)(=O)=O', '[13*]C1Oc2ccc([16*])cc2C1(C)C', '[3*]O[3*]'],
#  ['[16*]c1cccc([16*])c1',
#   '[5*]N[5*]',
#   '[5*]N(C)C',
#   '[1*]C([1*])=O',
#   '[8*]C(F)(F)F'],
#  ['c1ccc2nc3ccccc3cc2c1'],
#  ['[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(=O)CC21C', '[6*]C(=O)CO'],
#  ['[13*]C1OC(O)C(O)C(O)C1O', '[8*]CO'],
#  ['Cc1cccc(O)c1'],
#  ['[6*]C(=O)NN1c2ccccc2CC1C', '[16*]c1ccc(Cl)c(S(N)(=O)=O)c1'],
#  ['[15*]C1CC(C)C=C2C=CC(C)C([15*])C21',
#   '[3*]O[3*]',
#   '[8*]CC[8*]',
#   '[1*]C(=O)C(C)CC',
#   '[13*]C1CC(O)CC(=O)O1'],
#  ['O=[N+]([O-])c1ccc([N+](=O)[O-])cc1'],
#  ['[15*]C1(C2=CCC3CCC2C3)C(=O)NC(=O)NC1=O', '[8*]CC'],
#  ['[4*]CC', '[1*]C(=O)CCCCCCCCC', '[3*]O[3*]'],
#  ['[5*]N(C)C', '[16*]c1ccccc1', '[1*]C([1*])=O', '[5*]N[5*]'],
#  ['[4*]CC', '[3*]O[3*]', '[4*]CCC'],
#  ['CC(C)O'],
#  ['Cc1ccc2ccccc2c1'],
#  ['ClC(Br)Br'],
#  ['[16*]c1ccc(O)cc1', '[8*]C(CC)C([8*])CC'],
#  ['[4*]CC', '[3*]O[3*]', '[11*]SP(=S)(OC)OC', '[1*]C(=O)CC([4*])C([1*])=O'],
#  ['[16*]c1ccccc1', '[8*]CCl'],
#  ['[7*]CC', '[7*]CC=O'],
#  ['[16*]c1ccc(Br)c(Cl)c1', '[5*]N[5*]', '[1*]C(=O)N(C)OC'],
#  ['Cc1c2ccccc2c(C)c2ccccc12'],
#  ['[3*]OC', '[1*]C(=O)CCCCC'],
#  ['[16*]c1ccc([16*])c(Cl)c1',
#   '[9*]n1nc([14*])oc1=O',
#   '[8*]C(C)(C)C',
#   '[5*]N[5*]',
#   '[5*]N(C)C',
#   '[1*]C([1*])=O'],
#  ['[16*]c1ccc(F)cc1', '[5*]N[5*]', '[1*]C(C)=O'],
#  ['[1*]C(=O)CCl', '[16*]c1cccc([16*])c1[16*]', '[8*]CC', '[5*]N([5*])COC'],
#  ['C1=CCCCC1'],
#  ['[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(O)CC21C', '[6*]C(=O)CO'],
#  ['c1cncnc1'],
#  ['O=[N+]([O-])c1ccc(Cl)cc1'],
#  ['[3*]OC', '[1*]C(=O)CC'],
#  ['O=[N+]([O-])c1ccccc1Cl'],
#  ['[5*]N([5*])C',
#   '[16*]c1ccc(Cl)c(Cl)c1',
#   '[5*]N[5*]',
#   '[4*]CCCC',
#   '[1*]C([1*])=O'],
#  ['[14*]c1nnc([14*])s1', '[8*]C(C)(C)C', '[10*]N1C(=O)N(C)CC1O'],
#  ['O=[N+]([O-])c1ccccc1'],
#  ['Ic1ccccc1'],
#  ['[16*]c1ccccc1C', '[10*]N1C(=O)c2cc(S(N)(=O)=O)c(Cl)cc2NC1C'],
#  ['[3*]OC', '[3*]O[3*]', '[4*]CC(O)C[4*]', '[1*]C(N)=O', '[16*]c1ccccc1[16*]'],
#  ['[1*]C(=O)CCl',
#   '[16*]c1cccc([16*])c1[16*]',
#   '[3*]OCN([5*])[5*]',
#   '[8*]CC',
#   '[4*]CCCC'],
#  ['Oc1cccc(Cl)c1Cl'],
#  ['[3*]OC', '[1*]C(=O)CCC'],
#  ['[1*]C(=O)CC', '[5*]N[5*]', '[16*]c1ccc(Cl)c(Cl)c1'],
#  ['[16*]c1ccccc1', '[14*]c1nc2c(N)nc(N)nc2nc1N'],
#  ['[4*]CC', '[3*]O[3*]', '[1*]C(=O)CCCCC'],
#  ['[8*]C(Cl)(Cl)Cl', '[8*]C(O)CO', '[13*]C1OC2OC([13*])C(O)C2O1'],
#  ['Cc1ccc(N=CN(C)C=Nc2ccc(C)cc2C)c(C)c1'],
#  ['[3*]OC', '[14*]c1nc([14*])nc([14*])n1', '[4*]C(C)C', '[5*]N[5*]'],
#  ['C=CCCCCCC'],
#  ['Cc1ccc(N)cc1'],
#  ['Nc1nccs1'],
#  ['[16*]c1ccccc1', '[5*]NC', '[1*]C([1*])=O', '[3*]O[3*]'],
#  ['CCCC(O)CC'],
#  ['Oc1c2ccccc2cc2ccccc12'],
#  ['Cc1ccc2cc3ccccc3cc2c1'],
#  ['Cc1cccc(C)c1C'],
#  ['[3*]O[3*]',
#   '[16*]c1ccc([16*])c(C)c1',
#   '[5*]N(C)C',
#   '[5*]NC',
#   '[1*]C([1*])=O'],
#  ['CCCCCCCC(C)O'],
#  ['[5*]N([5*])C',
#   '[16*]c1ccccc1',
#   '[4*]C([8*])(C)C',
#   '[5*]N[5*]',
#   '[1*]C([1*])=O'],
#  ['CCCC(=O)CC'],
#  ['N#Cc1cc(Br)c(O)c(Br)c1'],
#  ['[16*]c1ccccc1', '[16*]c1ccc(Cl)c(Cl)c1'],
#  ['[5*]N([5*])C',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[14*]c1nc2ccccc2s1',
#   '[1*]C(=O)C[4*]'],
#  ['Oc1cccc2ncccc12'],
#  ['[16*]c1ccccc1', '[1*]C(=O)C1=C(C)OCCS1', '[5*]N[5*]'],
#  ['[4*]CC', '[3*]O[3*]', '[16*]c1ccc2nc(S(N)(=O)=O)sc2c1'],
#  ['Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl'],
#  ['ClCBr'],
#  ['[8*]CC', '[15*]C1([15*])C(=O)NC(=O)N(C)C1=O'],
#  ['[3*]O[3*]',
#   '[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C',
#   '[4*]CC([6*])=O',
#   '[1*]C(C)=O'],
#  ['[4*]C[8*]', '[16*]c1ccccc1', '[1*]C(N)=O', '[5*]N[5*]'],
#  ['[5*]N(C)C', '[1*]C([1*])=O', '[16*]c1ccc(C)c(Cl)c1', '[5*]N[5*]'],
#  ['[5*]N[5*]', '[1*]C(=O)N(C)OC', '[16*]c1ccc(Cl)c(Cl)c1'],
#  ['OC1CCCCCC1'],
#  ['[1*]C(=O)C(Cl)Cl',
#   '[4*]C(CO)C([8*])O',
#   '[16*]c1ccc(S(C)(=O)=O)cc1',
#   '[5*]N[5*]'],
#  ['[8*]CC', '[15*]C1([15*])C(=O)NC(=S)NC1=O', '[8*]C(C)CCC'],
#  ['[14*]c1nnc(S(N)(=O)=O)s1', '[5*]N[5*]', '[1*]C(C)=O'],
#  ['O=[N+]([O-])c1ccc(O)cc1'],
#  ['ClC1=C(Cl)C2(Cl)C3C4C=CC(C4)C3C1(Cl)C2(Cl)Cl'],
#  ['C1CCOC1'],
#  ['Nc1ccccc1[N+](=O)[O-]'],
#  ['[16*]c1cccc(Cl)c1Cl'],
#  ['[10*]N1C(=O)C([15*])C(=O)N1[10*]', '[16*]c1ccccc1', '[8*]CCCC'],
#  ['Cc1c([N+](=O)[O-])cccc1[N+](=O)[O-]'],
#  ['[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C', '[6*]C(C)=O'],
#  ['[4*]CC', '[5*]N([5*])[5*]', '[14*]c1nc([14*])nc(Cl)n1'],
#  ['[4*]C(Cl)(Cl)C(Cl)Cl', '[11*]SN1C(=O)C2CC=CCC2C1=O'],
#  ['Brc1ccc(Br)c(Br)c1'],
#  ['O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O'],
#  ['[8*]CC=C', '[15*]C1([15*])C(=O)NC(=O)NC1=O', '[8*]C(C)CCC'],
#  ['[16*]c1ccc(C)c(O)c1', '[8*]C(C)C'],
#  ['O=C1CSC(=S)N1'],
#  ['[16*]c1ccc(O)cc1O', '[14*]c1oc2cc(O)cc(O)c2c(=O)c1O'],
#  ['O=C1C2(Cl)C3(Cl)C4(Cl)C(Cl)(Cl)C5(Cl)C3(Cl)C1(Cl)C5(Cl)C24Cl'],
#  ['[4*]CC', '[5*]N([5*])C(=S)SSC(=S)N([5*])[5*]'],
#  ['C1CCCCC1'],
#  ['ClC1=C(Cl)C(Cl)(C2(Cl)C(Cl)=C(Cl)C(Cl)=C2Cl)C(Cl)=C1Cl'],
#  ['Cc1cc(Cl)ccc1N=CN(C)C'],
#  ['CC12CCc3c(ccc4cc(O)ccc34)C1CCC2=O'],
#  ['CCCCCCCCO'],
#  ['[4*]CC', '[11*]S[11*]'],
#  ['ClCCCl'],
#  ['CCC(C)(C)Cl'],
#  ['ClCCBr'],
#  ['Nc1ccc([N+](=O)[O-])cc1'],
#  ['[13*]C1OC(O)C(O)C(O)C1[15*]',
#   '[3*]O[3*]',
#   '[13*]C1OC([13*])C(O)C(O)C1O',
#   '[8*]CO'],
#  ['[4*]CC', '[5*]N1c2ncccc2C(=O)N(CC)c2cccnc21'],
#  ['Clc1ccccc1'],
#  ['C=CCCCCCCC'],
#  ['Brc1ccc(I)cc1'],
#  ['CCC(C)(O)CC'],
#  ['[16*]c1ccccc1', '[8*]CCCCC'],
#  ['[13*]C1NC(=O)NC1=O', '[1*]C(N)=O', '[5*]N[5*]'],
#  ['[3*]O[3*]',
#   '[4*]CC(O)CO',
#   '[1*]C([6*])=O',
#   '[5*]N[5*]',
#   '[16*]c1ccccc1[16*]',
#   '[16*]c1ccnc2cc(Cl)ccc12'],
#  ['[16*]c1ccc(Cl)cc1', '[8*]C([8*])C(Cl)Cl'],
#  ['[3*]O[3*]', '[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C', '[1*]C(C)=O'],
#  ['Clc1cccc2ccccc12'],
#  ['[4*]CC', '[5*]N1c2ccccc2C(=O)N(C)c2ccccc21'],
#  ['CCCCC(C)O'],
#  ['[8*]CCC', '[15*]C1CCCC1'],
#  ['[4*]CC',
#   '[9*]n1cncc1[14*]',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[8*]C([8*])C',
#   '[1*]C([6*])=O'],
#  ['Oc1ccc(Cl)c(Cl)c1'],
#  ['[16*]c1cccc([16*])c1',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[4*]C([8*])C#N',
#   '[1*]C([6*])=O',
#   '[15*]C1C(C=C(Cl)Cl)C1(C)C'],
#  ['c1ccc2ocnc2c1'],
#  ['CCCCCO'],
#  ['[4*]CC', '[16*]c1ccccc1', '[5*]N([5*])[5*]'],
#  ['Fc1cccc(F)c1'],
#  ['N#CCCCl'],
#  ['[16*]c1ccccc1', '[8*]CC(C)(C)C'],
#  ['[15*]C1([15*])C(=O)NC(=O)NC1=O', '[16*]c1ccccc1', '[8*]CC'],
#  ['Clc1ccccc1I'],
#  ['c1ccc2[nH]nnc2c1'],
#  ['[5*]NC', '[1*]C([1*])=O', '[16*]c1cccc2c1OC(C)(C)C2', '[3*]O[3*]'],
#  ['Cc1cccc(C)c1O'],
#  ['CC(C)C(C)O'],
#  ['[16*]c1ccccc1', '[8*]C([8*])O'],
#  ['[3*]OC', '[1*]C(=O)CCCCCCCCC'],
#  ['[3*]OP(=S)(OC)OC', '[16*]c1ccc([N+](=O)[O-])cc1Cl'],
#  ['CC(C)CBr'],
#  ['CCI'],
#  ['[5*]N(C)C', '[3*]O[3*]', '[1*]C([1*])=O', '[14*]c1nc([14*])c(C)c(C)n1'],
#  ['CCCCCCBr'],
#  ['CCCC(C)C'],
#  ['[3*]O[3*]',
#   '[15*]C1C([15*])C1(C)C',
#   '[7*]C[8*]',
#   '[1*]C([6*])=O',
#   '[4*]C[8*]',
#   '[16*]c1c(F)c(F)c(C)c(F)c1F',
#   '[7*]C(Cl)C(F)(F)F'],
#  ['[1*]C(=O)CCl',
#   '[4*]CC([4*])C',
#   '[16*]c1cccc(C)c1[16*]',
#   '[3*]OC',
#   '[8*]CC',
#   '[5*]N([5*])[5*]'],
#  ['O=[N+]([O-])c1ccc(C=NO)o1'],
#  ['[16*]c1ccc([16*])c(Cl)c1',
#   '[16*]c1cccc([16*])c1',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[4*]C([8*])C#N',
#   '[5*]N[5*]',
#   '[8*]C(F)(F)F',
#   '[1*]C(=O)C([4*])C(C)C'],
#  ['Nc1nc[nH]n1'],
#  ['BrC(Br)Br'],
#  ['COP(=O)(OC)C(O)C(Cl)(Cl)Cl'],
#  ['[4*]CC', '[3*]OP(=S)(O[3*])SC[8*]', '[9*]n1c(=O)oc2cc(Cl)ccc21'],
#  ['[16*]c1ccccc1', '[8*]CO'],
#  ['O=c1oc2ccccc2c(O)c1C1CCCc2ccccc21'],
#  ['Oc1ccc(Br)cc1'],
#  ['CC(C)Br'],
#  ['CC(C)CC(C)(C)C'],
#  ['O=[N+]([O-])c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1'],
#  ['CN1C(=O)CN=C(c2ccccc2)c2cc([N+](=O)[O-])ccc21'],
#  ['CCC'],
#  ['[5*]N1CCCCC1', '[14*]c1cc(N)[n+]([O-])c(N)n1'],
#  ['Nc1cccc2nc3ccccc3cc12'],
#  ['c1ccc2cc3c(cc2c1)-c1cccc2cccc-3c12'],
#  ['[16*]c1ccc(Cl)cc1', '[8*]C([8*])(O)C(Cl)(Cl)Cl'],
#  ['c1cc2c3c(cccc3c1)CC2'],
#  ['[4*]CC',
#   '[10*]N1C(=O)c2ccccc2C1=O',
#   '[4*]C([8*])CCl',
#   '[3*]OP(=S)(O[3*])S[11*]'],
#  ['Brc1ccc(Br)cc1'],
#  ['[9*]n1oc(=O)n(C)c1=O', '[16*]c1ccc(Cl)c(Cl)c1'],
#  ['[16*]c1ccc(O)cc1', '[16*]c1ccccc1'],
#  ['[1*]C(=O)C1=C(C)OCCC1', '[16*]c1ccccc1', '[5*]N[5*]'],
#  ['[4*]CC', '[3*]OC=C'],
#  ['C#CCC'],
#  ['[3*]OC', '[14*]c1ncnc2nccnc12'],
#  ['CCCCC(C)(O)CC'],
#  ['Clc1ccc(Cl)cc1'],
#  ['[3*]OC[8*]',
#   '[10*]N1C(=O)NC([13*])([13*])C1=O',
#   '[16*]c1ccccc1',
#   '[1*]C(C)=O'],
#  ['[16*]c1c(C)[nH]c(=O)[nH]c1=O',
#   '[1*]C(=O)C[7*]',
#   '[7*]C[8*]',
#   '[4*]C(CO)CS(=O)CSC',
#   '[5*]N[5*]'],
#  ['Cc1c[nH]c2ccccc12'],
#  ['[3*]OC', '[14*]c1ncc2nccnc2n1'],
#  ['[3*]O[3*]',
#   '[16*]c1ccccc1[16*]',
#   '[13*]C1OCCO1',
#   '[5*]NC',
#   '[1*]C([1*])=O'],
#  ['[4*]CC(C)C', '[10*]N1CCNC1=O', '[1*]C([1*])=O', '[5*]N[5*]'],
#  ['CC#N'],
#  ['[16*]c1ccc([16*])cc1',
#   '[4*]CC',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[4*]CC[4*]',
#   '[5*]N[5*]',
#   '[1*]C([1*])=O'],
#  ['[5*]N([5*])S(=O)c1ccc(N)cc1', '[14*]c1onc(C)c1C', '[1*]C(C)=O'],
#  ['ClCC(Cl)(Cl)Cl'],
#  ['CCCCO'],
#  ['[15*]C1CCCCC1C', '[16*]c1ccccc1', '[1*]C([1*])=O', '[5*]N[5*]'],
#  ['Clc1cc(Cl)cc(Cl)c1'],
#  ['O=Cc1ccco1'],
#  ['CC(C)CCO'],
#  ['O=Cc1ccc2c(c1)OCO2'],
#  ['C=C(C)C'],
#  ['O=Cc1ccccc1'],
#  ['C=C(C)C(=C)C'],
#  ['[4*]CC',
#   '[5*]N([5*])SN([5*])C',
#   '[3*]O[3*]',
#   '[4*]C(C)C',
#   '[1*]C(=O)CC[4*]',
#   '[16*]c1cccc2c1OC(C)(C)C2',
#   '[1*]C([1*])=O'],
#  ['CN1C(=O)c2cccnc2Oc2ccccc21'],
#  ['c1ccc2c(c1)Cc1ccccc1-2'],
#  ['CC1CCCCC1'],
#  ['[12*]S(=O)(=O)c1ccc(N)cc1', '[5*]NC(=N)N'],
#  ['[3*]OC', '[1*]C([6*])=O', '[16*]c1ccc(O)cc1'],
#  ['CC1CCCO1'],
#  ['CC1=C2C3OC(=O)C(C)C3CCC2(C)C=CC1=O'],
#  ['[3*]O[3*]', '[13*]C1OC([13*])C(O)C(O)C1O', '[16*]c1ccccc1[16*]', '[8*]CO'],
#  ['CCCI'],
#  ['[4*]CC',
#   '[14*]c1nc([14*])nc([14*])n1',
#   '[4*]C(C)C',
#   '[5*]N[5*]',
#   '[11*]SC'],
#  ['CCCO'],
#  ['[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3CCC21C', '[6*]C(C)=O'],
#  ['CCCC(C)O'],
#  ['[6*]C(=O)C([8*])O', '[16*]c1ccccc1'],
#  ['Cc1ccc(O)c(C)c1'],
#  ['O=[N+]([O-])c1cccc(Cl)c1'],
#  ['[16*]c1ccccc1', '[9*]n1c(=O)c(N)c(C)n1C'],
#  ['[16*]c1ccc(Cl)cc1Cl', '[16*]c1cc(Cl)ccc1Cl'],
#  ['ClC(Cl)=C(Cl)C(Cl)=C(Cl)Cl'],
#  ['[4*]CC',
#   '[14*]c1nc([14*])nc([14*])n1',
#   '[5*]N[5*]',
#   '[4*]C(C)(C)C',
#   '[11*]SC'],
#  ['CCC(C)CCO'],
#  ['Cc1ncc2nccnc2n1'],
#  ['C#CC1(O)CCC2C3CCC4=Cc5oncc5CC4(C)C3CCC21C'],
#  ['CCCCI'],
#  ['Brc1ccc2ccccc2c1'],
#  ['[3*]O[3*]',
#   '[15*]C1CCC2(C)C(CCC3C2CC(O)C2(C)C(C4=CC(=O)OC4)CCC32O)C1',
#   '[13*]C1CC(O)C([15*])C(C)O1',
#   '[13*]C1CC(O)C(O)C(C)O1'],
#  ['[8*]C(F)(F)F', '[16*]c1ccccc1'],
#  ['[1*]C([6*])=O', '[3*]O[3*]', '[16*]c1ccccc1[16*]', '[4*]CCCCCC'],
#  ['c1ccc2c(c1)sc1ccccc12'],
#  ['[16*]c1ccc(Cl)cc1Cl', '[16*]c1ccc(Cl)c(Cl)c1Cl'],
#  ['[16*]c1ccc(Cl)c(Cl)c1Cl'],
#  ['[16*]c1c(O)c2ccccc2oc1=O', '[8*]C([8*])CC(C)=O', '[16*]c1ccccc1'],
#  ['[16*]c1ccccc1', '[8*]C(O)C([8*])O'],
#  ['[3*]OC', '[1*]C([6*])=O', '[16*]c1ccccc1[16*]'],
#  ['[4*]CC', '[3*]O[3*]', '[1*]C(=O)CCCCCCC'],
#  ['[4*]CC', '[11*]SS[11*]'],
#  ['[4*]CC', '[3*]O[3*]', '[4*]CC[4*]'],
#  ['Clc1cc(Cl)c(Cl)cc1Cl'],
#  ['[16*]c1ccc(N)cc1'],
#  ['C=CCCCCC'],
#  ['[4*]CC', '[14*]c1nc(C)c([16*])c(=O)[nH]1', '[8*]CCCC', '[5*]N[5*]'],
#  ['[8*]C(C)CCC', '[15*]C1([15*])C(=O)NC(=O)NC1=O', '[8*]CC'],
#  ['Nc1ccccc1Cl'],
#  ['[3*]OC', '[16*]c1cccc(Cl)c1'],
#  ['[4*]CC', '[4*]CCCC', '[4*]CCC', '[5*]N([5*])[5*]', '[1*]C(=O)S[11*]'],
#  ['[4*]CCCC', '[3*]OC=O'],
#  ['[15*]C1(O)CCC2C3CCC4=CC(=O)C=CC4(C)C3C(O)CC21C', '[6*]C(=O)CO'],
#  ['ClC(Cl)Br'],
#  ['CC12CC(=O)C3C(CCC4=CC(=O)CCC43C)C1CCC2=O'],
#  ['[16*]c1ccccc1', '[16*]c1ccc([16*])cc1'],
#  ['O=Cc1ccc(O)cc1'],
#  ['CBr'],
#  ['[5*]N[5*]', '[12*]S(=O)(=O)C(F)(F)F', '[16*]c1ccc(S(=O)(=O)c2ccccc2)cc1C'],
#  ['[16*]c1c(O)c2ccccc2oc1=O', '[8*]C([8*])CC(C)=O', '[16*]c1ccc(Cl)cc1'],
#  ['[16*]c1ccc2ccccc2c1', '[8*]CC'],
#  ['Cc1c[nH]c(=O)nc1N'],
#  ['[16*]c1ccccc1', '[16*]c1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl'],
#  ['[1*]C([6*])=O', '[16*]c1ccccc1I', '[16*]c1ccccc1', '[5*]N[5*]'],
#  ['[9*]n1c2nc(=O)[nH]c(=O)c-2nc2cc(C)c(C)cc21', '[8*]CC(O)C(O)C(O)CO'],
#  ['Fc1ccccc1Br'],
#  ['Oc1ccc(Cl)cc1Cl'],
#  ['[16*]c1cccc([16*])c1',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[1*]C([6*])=O',
#   '[4*]C[8*]',
#   '[15*]C1C(C=C(Cl)Cl)C1(C)C'],
#  ['[14*]c1ccccn1', '[5*]N[5*]', '[1*]C(=O)C1=C(O)c2ccccc2S(=O)(=O)N1C'],
#  ['[3*]OC[8*]',
#   '[10*]N1C(=O)NC([13*])([13*])C1=O',
#   '[16*]c1ccccc1',
#   '[1*]C(=O)CC'],
#  ['C1CCCC1'],
#  ['Cc1ccccc1N'],
#  ['[3*]OC', '[8*]CC=C', '[16*]c1ccc([16*])cc1'],
#  ['[16*]c1cccc([16*])c1',
#   '[3*]O[3*]',
#   '[4*]C(C)(C)C',
#   '[5*]N[5*]',
#   '[5*]N(C)C',
#   '[1*]C([1*])=O'],
#  ['C=CC(C)C'],
#  ['Oc1ccccn1'],
#  ['CC'],
#  ['Clc1ccccc1Cl'],
#  ['Sc1nc2ccccc2s1'],
#  ['[16*]c1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl'],
#  ['[3*]OC', '[16*]c1c2occc2cc2ccc(=O)oc12'],
#  ['CC(N)=O'],
#  ['Cc1cccc2ccccc12'],
#  ['[4*]CC',
#   '[3*]O[3*]',
#   '[1*]C(=O)C([4*])C',
#   '[16*]c1cccc2ccccc12',
#   '[5*]N([5*])[5*]'],
#  ['CC(O)C(C)(C)C'],
#  ['[4*]CC', '[3*]O[3*]', '[1*]C(=O)CCC'],
#  ['CC1=CC(=O)c2ccccc2C1=O'],
#  ['c1ccc2c(c1)ccc1ccccc12'],
#  ['Cc1ccnc(C)c1'],
#  ['CCCCCCCCCO'],
#  ['BrCBr'],
#  ['[15*]C1(O)C(C)CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC21C', '[6*]C(=O)CO'],
#  ['Cc1ccc2cc(C)ccc2c1'],
#  ['[4*]CC', '[5*]N([5*])[5*]', '[4*]CC(C)C', '[1*]C(=O)S[11*]'],
#  ['[4*]CC([4*])C[4*]', '[3*]O[N+](=O)[O-]'],
#  ['Nc1cccc([N+](=O)[O-])c1'],
#  ['CCCCCl'],
#  ['[5*]N1C=CN([5*])C=C1', '[4*]C([4*])C(Cl)(Cl)Cl', '[5*]NC=O'],
#  ['[16*]c1cccc([16*])c1',
#   '[8*]C(F)(F)F',
#   '[16*]c1ccccc1',
#   '[16*]c1cn(C)cc([16*])c1=O'],
#  ['Nc1cc2c3ccccc3ccc2c2ccccc12'],
#  ['CC12CCC3c4ccc(O)cc4CCC3C1CCC2=O'],
#  ['[4*]CC', '[5*]N1c2ccccc2N(C)C(=S)c2cccnc21'],
#  ['CC1CO1'],
#  ['O=C1CN=C(c2ccccc2)c2cc([N+](=O)[O-])ccc2N1'],
#  ['[4*]CC', '[5*]NC(=S)N[5*]'],
#  ['Oc1cc(Cl)cc(Cl)c1Cl'],
#  ['[3*]OC', '[1*]C(=O)CCCC'],
#  ['Nc1ccccc1'],
#  ['Cc1cccc2c(C)cccc12'],
#  ['NS(=O)(=O)c1cc2c(cc1Cl)NCNS2(=O)=O'],
#  ['C1=Cc2cccc3cccc1c23'],
#  ['[4*]CCCCC', '[3*]O[3*]', '[1*]C(=O)CC'],
#  ['[3*]OC', '[4*]CC', '[14*]c1nc([14*])nc([14*])n1', '[4*]C(C)C', '[5*]N[5*]'],
#  ['c1ccc2c(c1)cc1ccc3cccc4ccc2c1c34'],
#  ['CCBr'],
#  ['CCC#CCC'],
#  ['[15*]C1CCC2(C)C(CCC3C2CCC2(C)C(C4=CC(=O)OC4)CCC32O)C1',
#   '[3*]O[3*]',
#   '[13*]C1CC(O)C([15*])C(C)O1',
#   '[13*]C1CC(O)C(O)C(C)O1'],
#  ['C=C(C)CC'],
#  ['Oc1cccc2cccnc12'],
#  ['c1ccc2c(c1)CCCC2'],
#  ['O=C1OC(c2ccc(O)cc2)(c2ccc(O)cc2)c2ccccc21'],
#  ['Brc1cc(Br)cc(Br)c1'],
#  ['[3*]OP(=S)(OC)OC', '[16*]c1cc(Cl)c(Cl)cc1Cl'],
#  ['Cc1cc(=O)[nH]c(=S)[nH]1'],
#  ['[3*]OC', '[8*]CC=C', '[16*]c1ccc(O)c([16*])c1'],
#  ['[8*]CC=C', '[15*]C1([15*])C(=O)NC(=O)NC1=O', '[8*]C(C)C'],
#  ['c1cc2ccc3cccc4ccc(c1)c2c34'],
#  ['[4*]CC', '[3*]O[3*]', '[4*]C([4*])C'],
#  ['[8*]C[8*]', '[16*]c1ccccc1Cl', '[10*]N1OCC(C)(C)C1=O'],
#  ['[4*]CCO', '[3*]O[3*]', '[4*]CCCC'],
#  ['O=[N+]([O-])c1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl'],
#  ['CC12CCC3C(CCC4CC(O)CCC43C)C1CCC2=O'],
#  ['[16*]c1cccc([16*])c1',
#   '[8*]C(F)(F)F',
#   '[8*]CCl',
#   '[10*]N1CC([15*])C(Cl)C1=O'],
#  ['c1ccc2ncccc2c1'],
#  ['[3*]OC', '[1*]C([6*])=O', '[16*]c1cc(O)c(O)c(O)c1'],
#  ['[9*]n1cncn1', '[16*]c1ccc(F)cc1F', '[8*]CC([8*])(O)C[8*]'],
#  ['O=c1[nH]c2cc(Cl)ccc2o1'],
#  ['[16*]c1ccc(Cl)cc1Cl', '[16*]c1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl'],
#  ['O=C1NC(=O)C(=O)C(=O)N1'],
#  ['ClCCCCl'],
#  ['Fc1cccc(Br)c1'],
#  ['Clc1ccc(Br)cc1'],
#  ['CC(C)C(C)C'],
#  ['C=CCC'],
#  ['[16*]c1cc(Cl)c(Cl)c(Cl)c1Cl', '[16*]c1cc(Cl)ccc1Cl'],
#  ['Nc1cc[nH]c(=O)n1'],
#  ['FC(F)(Cl)C(F)(Cl)Cl'],
#  ['CCC#N'],
#  ['[16*]c1ccc(Cl)cc1', '[8*]C([8*])C(Cl)Cl', '[16*]c1ccccc1Cl'],
#  ['[3*]OC', '[16*]c1ccccc1[N+](=O)[O-]'],
#  ['CC12CCC3C(CC=C4CC(O)CCC43C)C1CCC2=O'],
#  ['[10*]N1C(=O)C2(C)CC2(C)C1=O', '[16*]c1cc(Cl)cc(Cl)c1'],
#  ['c1cc2ccc3ccc4ccc5cccc6c(c1)c2c3c4c56'],
#  ['[8*]C(C)CC', '[16*]c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O'],
#  ['COC1=C(OC)C2C(=O)OCC2C=C1'],
#  ['OCC(O)CO'],
#  ['[3*]OC', '[16*]c1ccccc1O'],
#  ['[4*]CC', '[14*]c1nc(Cl)c(Cl)cc1Cl', '[3*]OP(=S)(O[3*])O[3*]'],
#  ['Cc1c2ccccc2cc2ccccc12'],
#  ['[9*]n1c(=O)cc(C)n1C', '[16*]c1ccccc1'],
#  ['[3*]OC', '[4*]CCCC'],
#  ['Cc1cnc2cncnc2n1'],
#  ['[4*]CC', '[14*]c1nc([14*])nc(Cl)n1', '[5*]N[5*]'],
#  ['[5*]N(C)C', '[1*]C(C)=O'],
#  ['[5*]N(C)C', '[14*]c1nc([14*])nc([14*])n1', '[11*]SC'],
#  ['C=C'],
#  ['CC(C)(C)CCO'],
#  ['[8*]CC=C', '[15*]C1([15*])C(=O)NC(=O)NC1=O', '[8*]CC'],
#  ['Oc1ccc(Cl)c(Cl)c1Cl'],
#  ['[3*]OC', '[16*]c1ccccc1'],
#  ['[16*]c1ccc(Cl)cc1',
#   '[16*]c1cccc(Cl)c1',
#   '[3*]O[3*]',
#   '[4*]C(C)C',
#   '[1*]C(=O)C([8*])([8*])O'],
#  ['[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3C(O)CC12C=O', '[6*]C(=O)CO'],
#  ['[16*]c1ccc([16*])cc1',
#   '[3*]OC',
#   '[3*]O[3*]',
#   '[5*]N[5*]',
#   '[5*]N(C)C',
#   '[1*]C([1*])=O'],
#  ['[16*]c1ccc(C)cc1', '[8*]CC'],
#  ['[4*]C(C)C', '[11*]S[11*]'],
#  ['O=[N+]([O-])c1cccc([N+](=O)[O-])c1'],
#  ['[4*]CC', '[3*]OP(=S)(O[3*])SCSP(=S)(O[3*])O[3*]'],
#  ['[15*]C1([15*])C(=O)NC(=O)NC1=O', '[8*]CC', '[8*]C(C)C'],
#  ['[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(=O)CC21C',
#   '[3*]O[3*]',
#   '[4*]CC([6*])=O',
#   '[1*]C(C)=O'],
#  ['[8*]CCO', '[9*]n1c([N+](=O)[O-])cnc1C'],
#  ['Nc1ccc(Cl)cc1'],
#  ['CCCC(C)(C)CO'],
#  ['c1ccoc1'],
#  ['[3*]OC',
#   '[14*]c1nc([14*])nc([14*])n1',
#   '[4*]C(C)C',
#   '[5*]N[5*]',
#   '[4*]CCC[4*]',
#   '[11*]SC'],
#  ['[5*]N(C)C', '[1*]C([1*])=O', '[5*]N[5*]', '[15*]C1CC2CC1C1CCCC21'],
#  ['[8*]C(C)(C)C', '[16*]c1ccccc1'],
#  ['[10*]N1C(=O)C([15*])C(=O)N1[10*]', '[16*]c1ccccc1', '[8*]CCC(C)=O'],
#  ['[3*]O[3*]',
#   '[15*]C1(O)CCC2C3CCC4=CC(=O)C=CC4(C)C3C(O)CC21C',
#   '[4*]CC([6*])=O',
#   '[1*]C(C)=O'],
#  ['[3*]OC', '[4*]CCC'],
#  ['[3*]O[3*]', '[4*]C(C)C', '[1*]C(C)=O'],
#  ['Brc1ccccc1'],
#  ['[4*]CC', '[1*]C([6*])=O', '[3*]O[3*]', '[16*]c1ccc(O)cc1'],
#  ['[3*]OC[8*]',
#   '[10*]N1C(=O)NC([13*])([13*])C1=O',
#   '[16*]c1ccccc1',
#   '[1*]C(=O)CCC'],
#  ['[3*]O[3*]', '[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C', '[1*]C(=O)CC'],
#  ['c1cc2ccc3ccc4ccc5ccc6ccc1c1c2c3c4c5c61'],
#  ['O=c1[nH]cnc2[nH]ncc12'],
#  ['C=CCl'],
#  ['[5*]N(C)C', '[16*]c1ccccc1', '[1*]C(=O)C([8*])[8*]'],
#  ['BrC(Br)(Br)Br'],
#  ['[4*]CC', '[5*]N(C)C', '[5*]N1c2cc([16*])cc(C)c2NC(=O)c2cccnc21'],
#  ['O=C1NC(=O)c2ccccc21'],
#  ['[16*]c1cncnc1',
#   '[16*]c1ccc(Cl)cc1',
#   '[8*]C([8*])([8*])O',
#   '[16*]c1ccccc1Cl'],
#  ['[3*]OC', '[1*]C([6*])=O', '[16*]c1ccccc1'],
#  ['Cn1ccc(=O)[nH]c1=O'],
#  ['[16*]c1ccc(O)cc1',
#   '[16*]c1ccccc1',
#   '[8*]CCCC',
#   '[10*]N1C(=O)C([15*])C(=O)N1[10*]'],
#  ['[16*]c1cccc(Cl)c1Cl', '[16*]c1cc(Cl)ccc1Cl'],
#  ['[8*]CC', '[13*]C1NC(=O)c2cc(S(N)(=O)=O)c(Cl)cc2N1'],
#  ['[5*]N(C)C', '[1*]C([1*])=O', '[5*]N[5*]', '[16*]c1ccc(Cl)c(Cl)c1'],
#  ['C1=CCCC1'],
#  ['O=C1NC(=O)C(O)(C2(O)C(=O)NC(=O)NC2=O)C(=O)N1'],
#  ['CCCCCCCCC'],
#  ['Oc1ccccc1Cl'],
#  ['Cc1cc2ccccc2c2ccc3ccccc3c12'],
#  ['[4*]CC', '[3*]O[3*]', '[16*]c1ccccc1'],
#  ['[1*]C(=O)C[7*]', '[4*]CC', '[3*]O[3*]', '[16*]c1ccccc1', '[7*]C[8*]'],
#  ['[8*]C(C)(C)C', '[9*]n1c(=O)[nH]c(C)c(Cl)c1=O'],
#  ['O=C1CN=C(c2ccccc2Cl)c2cc([N+](=O)[O-])ccc2N1'],
#  ['Cc1ccc(S(N)(=O)=O)cc1'],
#  ['[16*]c1cccc(Cl)c1',
#   '[3*]O[3*]',
#   '[4*]C(C)C#C',
#   '[5*]N[5*]',
#   '[1*]C([1*])=O'],
#  ['CCCCCC(C)C'],
#  ['[16*]c1cccc([16*])c1',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[4*]C([8*])C#N',
#   '[15*]C1C([15*])C1(C)C',
#   '[7*]C[8*]',
#   '[1*]C([6*])=O',
#   '[7*]C(Cl)C(F)(F)F'],
#  ['[8*]CCC', '[15*]C1C(=O)N2C(N(C)C)=Nc3ccc(C)cc3N2C1=O'],
#  ['CN1C(=O)CN=C(c2ccccc2)c2cc(Cl)ccc21'],
#  ['CCC(O)C(C)C'],
#  ['[4*]CC', '[16*]c1ccc(S(C)=O)cc1', '[3*]OP(=S)(O[3*])O[3*]'],
#  ['CC1(C)C2CCC1(C)C(O)C2'],
#  ['CC12CCC(=O)C=C1CCC1C2CCC2(C)C(O)CCC12'],
#  ['CCCCCCC'],
#  ['Oc1cccc2ccccc12'],
#  ['CC1CCCCC1C'],
#  ['[3*]OC',
#   '[3*]O[3*]',
#   '[5*]N1CCN([5*])CC1',
#   '[14*]c1nc(N)c2cc([16*])c([16*])c([16*])c2n1',
#   '[1*]C([1*])=O',
#   '[4*]CC(C)(C)O'],
#  ['c1cc2c3c(c4ccc5ccccc5c4cc3c1)CC2'],
#  ['[15*]C1(C)CCC2C3C=C(C)C4=CC(=O)CCC4(C)C3CCC21C', '[6*]C(C)=O'],
#  ['CCCCCC(C)=O'],
#  ['COP(=O)(NC(C)=O)SC'],
#  ['[11*]SP(=O)(S[11*])S[11*]', '[4*]CCCC'],
#  ['O=C1NC(=O)C2C=CC=CC12'],
#  ['[13*]C1Nc2cc(Cl)c(S(N)(=O)=O)cc2S(=O)(=O)N1', '[8*]C(Cl)Cl'],
#  ['[7*]CC', '[7*]C(C)C'],
#  ['Cc1ccc(C)c(C)c1'],
#  ['Oc1cc(Cl)c(Cl)cc1Cl'],
#  ['c1ccc2c(c1)cnc1ccccc12'],
#  ['CCCC(C)(O)CC'],
#  ['CCCCCCCC'],
#  ['c1ccc2cc3ccccc3cc2c1'],
#  ['NNc1ccccc1'],
#  ['CCC=O'],
#  ['C1CCCCCCC1'],
#  ['[8*]CC=C', '[15*]C1([15*])C(=O)NC(=O)NC1=O'],
#  ['ClC(Cl)Cl'],
#  ['O=c1ccnc(S)[nH]1'],
#  ['[16*]c1ccc(Cl)cc1',
#   '[16*]c1ccccc1',
#   '[4*]C[8*]',
#   '[5*]N[5*]',
#   '[1*]C([1*])=O',
#   '[5*]N([5*])[5*]',
#   '[15*]C1CCCC1'],
#  ['CC1=CCCCC1'],
#  ['CCCCC(C=O)CC'],
#  ['[3*]OC', '[16*]c1c2occc2c([16*])c2c(=O)cc(C)oc12'],
#  ['[15*]C1([15*])C(=O)NC(=O)NC1=O', '[8*]CC', '[8*]CCC(C)C'],
#  ['c1ccc2c3c(ccc2c1)-c1cccc2cccc-3c12'],
#  ['CCC(C=O)CC'],
#  ['[3*]O[3*]', '[4*]CCC'],
#  ['CCCCCCCCCCCCCCO'],
#  ['Oc1c(Cl)ccc(Cl)c1Cl'],
#  ['NC(N)=O'],
#  ['C#CCCC'],
#  ['Brc1cccc(Br)c1'],
#  ['CCCCCCCCCCCCCCCCCCO'],
#  ['[16*]c1ccccc1', '[5*]N[5*]', '[1*]C(C)=O'],
#  ['O=C1C=C2CC3(O)COc4c(ccc(O)c4O)C3=C2C=C1O'],
#  ['[6*]C(=O)NN', '[16*]c1ccncc1'],
#  ['OC1C=CC2C1C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl'],
#  ['[4*]CCC(C)C', '[3*]OC=O'],
#  ['[16*]c1ccccc1', '[6*]C(C)=O'],
#  ['[14*]c1ccc2ccccc2n1'],
#  ['[4*]CC', '[3*]OP(=O)(O[3*])O[3*]'],
#  ['CC12CCC(C1)C(C)(C)C2=O'],
#  ['[3*]OC', '[14*]c1cnc2cncnc2n1'],
#  ['ClC1=C(Cl)C2(Cl)C3CC=CC3C1(Cl)C2(Cl)Cl'],
#  ['CC(C)[N+](=O)[O-]'],
#  ['c1ccc2c(c1)[nH]c1ccccc12'],
#  ['OCC(O)C(O)CO'],
#  ['[1*]C([6*])=O', '[3*]O[3*]', '[16*]c1ccc(N)cc1', '[4*]CCC'],
#  ['[5*]NC', '[7*]C(C)OP(=O)(OC)OC', '[1*]C(=O)C[7*]'],
#  ['O=C1CCC(=O)N1'],
#  ['CCC(C)C(C)C'],
#  ['[8*]CCCC',
#   '[4*]CC',
#   '[3*]OS(=O)(=O)N(C)C',
#   '[5*]N[5*]',
#   '[14*]c1nc([14*])c([16*])c(C)n1'],
#  ['[4*]CC', '[5*]N1c2ncccc2C(=S)N(C)c2cccnc21'],
#  ['CCN1C(=O)c2ccccc2Oc2ccccc21'],
#  ['C1CCOCC1'],
#  ['C#CCCCCC'],
#  ['[3*]OC', '[16*]c1ccc2ccc(=O)oc2c1[16*]', '[7*]CC[8*]', '[7*]C(C)C'],
#  ['Cc1ccc2c(ccc3c4c5c(cccc5cc32)CC4)c1'],
#  ['[4*]CC', '[1*]C([6*])=O', '[3*]O[3*]', '[16*]c1ccccc1'],
#  ['CC(C)CCl'],
#  ['C#CC1(O)CCC2C3CCc4cc(O)ccc4C3CCC21C'],
#  ['[3*]OC', '[1*]C(=O)CCCCCCCCCCC'],
#  ['[11*]S[11*]', '[4*]CCC'],
#  ['c1ccc2cc3cc4ccccc4cc3cc2c1'],
#  ['CCCCCBr'],
#  ['[7*]CCCCC', '[7*]CC'],
#  ['[8*]CCO', '[9*]n1c([N+](=O)[O-])cnc1C'],
#  ['[15*]C1CCCC1', '[8*]CCCCC'],
#  ['[16*]c1c(Cl)c(Cl)cc(Cl)c1Cl', '[16*]c1cc(Cl)ccc1Cl'],
#  ['[15*]C1([15*])C(=O)NC(=O)NC1=O', '[8*]CC', '[8*]C(C)C'],
#  ['CC(Cl)(Cl)Cl'],
#  ['[5*]N[5*]', '[16*]c1ccc(Cl)cc1', '[1*]C(=O)N(C)OC'],
#  ['O=C1NC(=O)C2(CCCCC2)C(=O)N1'],
#  ['[5*]N(C)C', '[1*]C([1*])=O', '[3*]OC1=CC(=O)CC(C)(C)C1'],
#  ['Cc1ccc(Br)cc1'],
#  ['[4*]CC', '[3*]O[3*]'],
#  ['[4*]C(C)C',
#   '[10*]N1CC(=O)N([10*])C1=O',
#   '[16*]c1cc(Cl)cc(Cl)c1',
#   '[5*]N[5*]',
#   '[1*]C([1*])=O'],
#  ['[4*]CC',
#   '[4*]CCCC',
#   '[8*]C(F)(F)F',
#   '[16*]c1cc([N+](=O)[O-])c([16*])c([N+](=O)[O-])c1',
#   '[5*]N([5*])[5*]'],
#  ['Cc1cc(C)c(O)c(C)c1'],
#  ['c1ccccc1'],
#  ['Clc1ccc(I)cc1'],
#  ['[16*]c1ccc([16*])c(Cl)c1',
#   '[3*]OC',
#   '[5*]N[5*]',
#   '[5*]N(C)C',
#   '[1*]C([1*])=O'],
#  ['[1*]C(=O)CCl', '[16*]c1ccccc1', '[4*]C(C)C', '[5*]N([5*])[5*]'],
#  ['C=Cc1ccccc1'],
#  ['COCOC'],
#  ['Cc1ccccc1C'],
#  ['CCC(C)O'],
#  ['Oc1ccc(O)cc1'],
#  ['CC12CCC3c4ccc(O)cc4CCC3C1CC(O)C2O'],
#  ['c1ccc2c(c1)Cc1cc3ccccc3cc1-2'],
#  ['O=C1CNC(=O)N1'],
#  ['[16*]c1ccc(O)cc1O', '[8*]CCCCCC'],
#  ['[4*]CC=C', '[11*]SS(=O)CC=C'],
#  ['[4*]CC', '[16*]c1ccc2oc(=O)c(Cl)c(C)c2c1', '[3*]OP(=S)(O[3*])O[3*]'],
#  ['Cc1c(C)c2c3ccccc3ccc2c2ccccc12'],
#  ['[3*]O[3*]',
#   '[4*]C1([15*])C(C)CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC21C',
#   '[6*]C(=O)CO',
#   '[1*]C(=O)CCCC',
#   '[15*]C1([15*])C(C)CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC21C'],
#  ['O=c1[nH]c(=O)c2[nH]c(=O)[nH]c2[nH]1'],
#  ['Oc1c(Cl)cc(Cl)c(Cl)c1Cl'],
#  ['Clc1cccc(Cl)c1'],
#  ['[8*]C([8*])C(Cl)(Cl)Cl', '[16*]c1ccc(Cl)cc1'],
#  ['[4*]CC(C)C', '[3*]OC=O'],
#  ['[16*]c1ccccc1', '[11*]SC'],
#  ['[4*]CC', '[8*]C(F)(F)F', '[5*]N1c2ncccc2C(=O)Nc2c([16*])cc(C)nc21'],
#  ['CCCCCC'],
#  ['[3*]OC', '[1*]C([6*])=O', '[16*]c1cccnc1'],
#  ['[8*]C(F)(F)F',
#   '[16*]c1ccccc1',
#   '[8*]C[8*]',
#   '[13*]C1Nc2cc([16*])c(S(N)(=O)=O)cc2S(=O)(=O)N1'],
#  ['[16*]c1cc(Cl)c(Cl)c(Cl)c1Cl', '[16*]c1ccc(Cl)c(Cl)c1'],
#  ['[10*]N1C(=O)OC(C)(C=C)C1=O', '[16*]c1cc(Cl)cc(Cl)c1'],
#  ['[4*]CC', '[14*]c1nc([14*])nc(Cl)n1', '[4*]C(C)(C)C#N', '[5*]N[5*]'],
#  ['c1ccc2c(c1)c1ccccc1c1ccccc21'],
#  ['[16*]c1ccc(O)cc1', '[7*]CC', '[7*]C([8*])C([7*])[8*]'],
#  ['[1*]C([6*])=O', '[3*]O[3*]', '[4*]CC(CC)CCCC', '[16*]c1ccccc1[16*]'],
#  ['[14*]c1ccccn1', '[8*]CC'],
#  ['[4*]C(Br)C(Cl)(Cl)Br', '[3*]OP(=O)(OC)OC'],
#  ['[16*]c1ccccc1'],
#  ['[16*]c1c(Cl)cc(Cl)cc1Cl'],
#  ['[5*]N(C)C', '[14*]c1nc([14*])nc([14*])n1'],
#  ['CC(C)CC(C)(C)O'],
#  ['O=C1NC(=O)C2(CCCCCC2)C(=O)N1'],
#  ['[13*]C1OC([13*])(O)C(O)C1O', '[8*]CO'],
#  ['Cc1cc(C)cc(O)c1'],
#  ['[16*]c1cccc(Cl)c1',
#   '[3*]O[3*]',
#   '[4*]CC#CCCl',
#   '[5*]N[5*]',
#   '[1*]C([1*])=O'],
#  ['[16*]c1ccc(Cl)cc1', '[5*]N[5*]', '[1*]C(C)=O'],
#  ['[16*]c1cc(Cl)ccc1Cl', '[16*]c1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl'],
#  ['CCC(C)(C)C'],
#  ['[5*]NC', '[16*]c1ccccc1'],
#  ['C=CCC=C'],
#  ['[3*]O[3*]',
#   '[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(O)CC21C',
#   '[4*]CC([6*])=O',
#   '[1*]C(C)=O'],
#  ['Cc1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O'],
#  ['O=C1Nc2ccc(Cl)cc2C(c2ccccc2Cl)=NC1O'],
#  ['Oc1cccc(Cl)c1'],
#  ['Clc1cccc(Br)c1'],
#  ['NS(=O)(=O)c1cc2c(cc1Cl)N=CNS2(=O)=O'],
#  ['[15*]C1(C)C(=O)NC(=O)NC1=O', '[8*]CC'],
#  ['[4*]CCO', '[3*]O[3*]', '[16*]c1ccccc1'],
#  ['[16*]c1ccccc1', '[8*]C[8*]'],
#  ['CCCCCC(O)CC'],
#  ['[4*]CC',
#   '[4*]C[8*]',
#   '[16*]c1c(F)cccc1Cl',
#   '[16*]c1cc([N+](=O)[O-])c([16*])c([N+](=O)[O-])c1',
#   '[5*]N([5*])[5*]',
#   '[8*]C(F)(F)F'],
#  ['[4*]C(C)C', '[14*]c1nc([14*])nc(Cl)n1', '[5*]N[5*]'],
#  ['CCCC(C)CO'],
#  ['CCCCC(C)(C)O'],
#  ['[16*]c1ccccc1', '[8*]CC'],
#  ['[7*]CC[8*]', '[8*]CC', '[15*]C1([15*])C(=O)NC(=O)NC1=O', '[7*]C(C)C'],
#  ['ClC1=C(Cl)C2(Cl)C3C(Cl)C=CC3C1(Cl)C2(Cl)Cl'],
#  ['[8*]CC(=C)Br', '[8*]C(C)CC', '[15*]C1([15*])C(=O)NC(=O)NC1=O'],
#  ['[16*]c1cccc([16*])c1',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[4*]C([8*])C#N',
#   '[1*]C([6*])=O',
#   '[15*]C1C(C)(C)C1(C)C'],
#  ['[4*]C(C)(C)CCCC(C)CC[7*]',
#   '[1*]C(=O)C[7*]',
#   '[3*]OC',
#   '[3*]O[3*]',
#   '[4*]C(C)C',
#   '[7*]CC([7*])C'],
#  ['[4*]CC', '[3*]O[3*]', '[1*]C(=O)CC'],
#  ['[14*]c1nc([14*])nc([14*])n1', '[4*]C(C)C', '[11*]SC', '[5*]N[5*]'],
#  ['[16*]c1ccc(Cl)cc1',
#   '[5*]N([5*])C',
#   '[4*]C(C)C#C',
#   '[5*]N[5*]',
#   '[1*]C([1*])=O'],
#  ['Cc1cc2ccccc2cc1C'],
#  ['[16*]c1ccc(Cl)cc1', '[16*]c1cc(Cl)ccc1Cl'],
#  ['[16*]c1ccc(Cl)cc1Cl', '[16*]c1cc(Cl)c(Cl)c(Cl)c1Cl'],
#  ['N#CN=C(N)N'],
#  ['O=[N+]([O-])C(Cl)(Cl)Cl'],
#  ['[16*]c1c(Cl)cccc1Cl', '[16*]c1ccccc1'],
#  ['[3*]OC', '[16*]c1ccc(C=O)cc1'],
#  ['[16*]c1ccc([N+](=O)[O-])cc1', '[5*]N[5*]', '[1*]C(C)=O'],
#  ['[4*]CC', '[3*]O[3*]', '[1*]C(=O)CCCCCC'],
#  ['[16*]c1ccc(O)cc1', '[5*]N[5*]', '[1*]C(C)=O'],
#  ['c1ccc2[nH]ncc2c1'],
#  ['[13*]C12OC(C)(C)OC1CC1C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC12C',
#   '[15*]C12OC(C)(C)OC1CC1C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC12C',
#   '[6*]C(=O)CO'],
#  ['Nc1nc2[nH]cnc2c(=O)[nH]1'],
#  ['[3*]OC', '[1*]C(C)=O'],
#  ['CC12CCC3C(CCC4CC(=O)CCC43C)C1CCC2O'],
#  ['C=CC(O)CCC'],
#  ['[14*]c1ccccn1',
#   '[7*]C([8*])[8*]',
#   '[16*]c1ccccc1',
#   '[7*]C1C2C=C(C([8*])([8*])O)C1C1C(=O)NC(=O)C21'],
#  ['[3*]O[3*]', '[4*]CCCC'],
#  ['CCCCCCCCCCCCO'],
#  ['[4*]CC', '[5*]N1c2nc([14*])ccc2NC(=O)c2cccnc21', '[4*]CCO', '[5*]N([5*])C'],
#  ['CCCC(C)(C)O'],
#  ['Nc1nc(=O)[nH]cc1F'],
#  ['[4*]CC',
#   '[3*]O[3*]',
#   '[16*]c1ccc([16*])c([16*])c1',
#   '[1*]C([6*])=O',
#   '[4*]CCCC',
#   '[5*]N([5*])[5*]'],
#  ['CCCCCC(C)(C)O'],
#  ['Cc1c(C)c(C)c(C)c(C)c1C'],
#  ['[16*]c1ccc(C)cc1O', '[8*]C(C)C'],
#  ['c1cnc2ncncc2n1'],
#  ['[4*]CC', '[16*]c1ccc([N+](=O)[O-])cc1', '[3*]OP(=S)(O[3*])O[3*]'],
#  ['C'],
#  ['c1ccc2c(c1)CCN2'],
#  ['O=[N+]([O-])c1cccc2ccccc12'],
#  ['CCC(C)C(C)=O'],
#  ['Nc1nc(O)nc2nc[nH]c12'],
#  ['[16*]c1c(O)c2ccccc2oc1=O',
#   '[16*]c1ccc([16*])cc1',
#   '[16*]c1ccc(Br)cc1',
#   '[16*]c1ccccc1',
#   '[8*]C([8*])CC([8*])O'],
#  ['C[N+](=O)[O-]'],
#  ['[4*]CC(Cl)=C(Cl)Cl', '[4*]C(C)C', '[5*]N([5*])[5*]', '[1*]C(=O)S[11*]'],
#  ['C=CCCC=C'],
#  ['c1ccc2[nH]ccc2c1'],
#  ['CC12CCC3C(CCC4=CC(=O)CCC43C)C1CCC2=O'],
#  ['C=CCCCC'],
#  ['[1*]C([6*])=O',
#   '[16*]c1c(C)cccc1C',
#   '[16*]c1cc(S(N)(=O)=O)c(Cl)cc1O',
#   '[5*]N[5*]'],
#  ['[15*]C1CCCCC1', '[8*]CC'],
#  ['CCCCCCCC(C)=O'],
#  ['[3*]OC',
#   '[16*]c1ccccc1',
#   '[6*]C([6*])=O',
#   '[1*]C([1*])=O',
#   '[5*]N[5*]',
#   '[14*]c1nc2ccc([16*])cc2[nH]1'],
#  ['[16*]c1cccc(Cl)c1', '[3*]O[3*]', '[4*]C(C)C', '[5*]N[5*]', '[1*]C([1*])=O'],
#  ['[4*]CC', '[5*]N1c2ncccc2C(=O)N(C)c2ccc(Cl)nc21'],
#  ['[5*]NC', '[1*]C([1*])=O', '[16*]c1cccc2ccccc12', '[3*]O[3*]'],
#  ['C#C'],
#  ['Cc1cncc(C)c1'],
#  ['C1=CCC=CC1'],
#  ['[5*]N([5*])C',
#   '[4*]CC',
#   '[3*]OP(=S)(O[3*])S[11*]',
#   '[3*]O[3*]',
#   '[1*]C(=O)C[4*]',
#   '[1*]C([1*])=O'],
#  ['[16*]c1ccccc1', '[8*]C(C)O'],
#  ['CC(Cl)CCl'],
#  ['[7*]CCCC', '[7*]C(C=O)CC'],
#  ['[4*]CC', '[4*]CC[4*]', '[3*]OP(=S)(O[3*])S[11*]', '[11*]S[11*]'],
#  ['[3*]O[3*]',
#   '[4*]C1(C)CCC2C3CCC4=CC(=O)CCC4(C)C3CCC21C',
#   '[15*]C1(C)CCC2C3CCC4=CC(=O)CCC4(C)C3CCC21C',
#   '[1*]C(C)=O'],
#  ['[16*]c1c(Cl)cccc1Cl', '[16*]c1ccc(Cl)cc1'],
#  ['[16*]c1ccc(Cl)cc1',
#   '[1*]C([6*])=O',
#   '[5*]N[5*]',
#   '[16*]c1c(F)cccc1F',
#   '[1*]C([1*])=O'],
#  ['[16*]c1ccc(Cl)cc1O', '[3*]O[3*]', '[16*]c1ccc(Cl)cc1Cl'],
#  ['[1*]C([6*])=O', '[3*]O[3*]', '[4*]CCCCCC(C)C', '[16*]c1ccccc1[16*]'],
#  ['[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3C(O)CC12C', '[6*]C(=O)CO'],
#  ['Cc1cc(C)cc(C)c1'],
#  ['[1*]C([6*])=O', '[3*]O[3*]', '[4*]CCCCCCCC', '[16*]c1ccccc1[16*]'],
#  ['CCCCCCCCCCCCCCCO'],
#  ['[16*]c1c(Cl)cccc1Cl'],
#  ['CC1(C)C(=O)NC(=O)NC1=O'],
#  ['CC(C)I'],
#  ['O=[N+]([O-])c1ccccc1[N+](=O)[O-]'],
#  ['CC(=O)C(C)C'],
#  ['CCCCCCCCCCCCCCCC'],
#  ['CC12CCC(CC1)C(C)(C)O2'],
#  ['Cc1cccc2sc3nncn3c12'],
#  ['CCCCCCC(C)=O'],
#  ['[3*]OC', '[1*]C(=O)CCCCCCCC'],
#  ['Fc1ccc(F)cc1'],
#  ['[15*]C1CCC(=O)NC1=O', '[10*]N1C(=O)c2ccccc2C1=O'],
#  ['[8*]C(F)(F)F',
#   '[16*]c1cc([N+](=O)[O-])c([16*])c([N+](=O)[O-])c1',
#   '[5*]N([5*])[5*]',
#   '[4*]CCC'],
#  ['CCO'],
#  ['O=C1NC(=O)C2(CCCC2)C(=O)N1'],
#  ['[4*]CC',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[1*]C(=O)C([4*])C',
#   '[5*]N[5*]',
#   '[1*]C([1*])=O'],
#  ['[16*]c1cccc([16*])c1',
#   '[3*]O[3*]',
#   '[16*]c1ccccc1',
#   '[15*]C1C([15*])C1(C)C',
#   '[7*]C(C)C',
#   '[7*]C[8*]',
#   '[1*]C([6*])=O',
#   '[4*]C[8*]'],
#  ['[5*]N(C)C', '[15*]C1CCCCCCC1', '[1*]C([1*])=O', '[5*]N[5*]'],
#  ['ClC1(Cl)C2(Cl)C3(Cl)C4(Cl)C(Cl)(Cl)C5(Cl)C3(Cl)C1(Cl)C5(Cl)C24Cl'],
#  ['CCCCCCCCBr'],
#  ['[3*]OC',
#   '[1*]C(=O)n1c([14*])nc2ccccc21',
#   '[5*]N[5*]',
#   '[4*]CCCC',
#   '[1*]C([1*])=O'],
#  ['[9*]n1c(=O)c([16*])c(C)n1C', '[5*]N(C)C', '[16*]c1ccccc1'],
#  ['CCC(O)CC'],
#  ['Cc1ccc([N+](=O)[O-])cc1'],
#  ['CC(C)CCCO'],
#  ['C#CC1(O)CCC2C3CCC4=CC(=O)CCC4(O)C3CCC21C'],
#  ['[16*]c1ccc(Br)cc1', '[3*]O[3*]', '[4*]C(C)C', '[1*]C(=O)C([8*])([8*])O'],
#  ['[9*]n1ncc(N)c(Cl)c1=O', '[16*]c1ccccc1'],
#  ['CCC(C)(C)O'],
#  ['Cc1ccc(O)cc1'],
#  ...]

# %%
len(fragments)
# Out:
# 1128

# %% [markdown]
# このようにフラグメントは1128分子についてネスト化されたリスト構造となっています。ネストを解消させてフラグメントのリスト構造とする方法として、次のような`unwrap`関数を準備します。

# %%
def unwrap(list_data):
    list_output = []
    for li in list_data: 
        list_output += li
    return list_output

# %% [markdown]
# unwrap関数にかけると、フラグメントの総数は2315のパーツであることがわかります。

# %%
fr_all = unwrap(fragments)
fr_all
# Out:
# ['[13*]C1OC([13*])C(O)C(O)C1O',
#  '[3*]O[3*]',
#  '[16*]c1ccccc1',
#  '[4*]C([8*])C#N',
#  '[4*]C[8*]',
#  '[8*]CO',
#  '[1*]C([6*])=O',
#  '[16*]c1ccccc1',
#  '[16*]c1ccoc1C',
#  '[5*]N[5*]',
#  '[7*]CC=O',
#  '[7*]CCCC([7*])C',
#  '[7*]C(C)C',
#  'c1ccc2c(c1)ccc1c2ccc2c3ccccc3ccc21',
#  'c1ccsc1',
#  'c1ccc2scnc2c1',
#  '[16*]c1c(Cl)cc(Cl)cc1Cl',
#  '[16*]c1c(Cl)cccc1Cl',
#  'CC12CCC3c4ccc(O)cc4CCC3C1CCC2O',
#  'ClC1=C(Cl)C2(Cl)C3C4CC(C5OC45)C3C1(Cl)C2(Cl)Cl',
#  '[3*]OC',
#  '[16*]c1cc2c(cc1[16*])C1C(=O)c3ccc4c(c3OC1CO2)CC(C(=C)C)O4',
#  'O=C1CCCN1',
#  'Clc1ccc2ccccc2c1',
#  'C=CCCC',
#  '[15*]C1([15*])C(=O)NCNC1=O',
#  '[16*]c1ccccc1',
#  '[8*]CC',
#  'CCCCCCCCCCCCCC',
#  'CC(C)Cl',
#  'CCC(C)CO',
#  'N#Cc1ccccc1',
#  '[4*]CC',
#  '[14*]c1cc(C)nc([14*])n1',
#  '[8*]C(C)C',
#  '[3*]OP(=S)(O[3*])O[3*]',
#  'CCCCCCCCCC(C)O',
#  '[16*]c1ccc(Cl)cc1Cl',
#  '[16*]c1c(Cl)ccc(Cl)c1Cl',
#  '[15*]C1CCCCC1',
#  '[9*]n1c(=O)[nH]c2c(c1=O)CCC2',
#  '[4*]CC',
#  '[3*]OP(=S)(O[3*])SCS[11*]',
#  '[16*]c1ccc([16*])cc1',
#  '[1*]C(C)=O',
#  '[4*]CC',
#  '[3*]O[3*]',
#  '[5*]N[5*]',
#  '[4*]CC',
#  '[8*]C(F)(F)F',
#  '[5*]N([5*])[5*]',
#  '[16*]c1cc([N+](=O)[O-])c([16*])c([N+](=O)[O-])c1N',
#  'CCCCCCCO',
#  'Cn1c(=O)c2[nH]cnc2n(C)c1=O',
#  '[15*]C1([15*])C(=O)NC(=O)NC1=O',
#  '[8*]CC',
#  '[8*]CCCC',
#  'ClC(Cl)=C(c1ccc(Cl)cc1)c1ccc(Cl)cc1',
#  '[3*]OC',
#  '[1*]C(=O)CCCCCCC',
#  '[8*]CC',
#  '[16*]c1ccc([16*])cc1',
#  '[4*]CC',
#  '[3*]OP(=S)(O[3*])SCS[11*]',
#  '[4*]C(C)(C)C',
#  '[3*]OC',
#  '[16*]c1cccc([16*])c1',
#  '[3*]O[3*]',
#  '[16*]c1cccc(C)c1',
#  '[5*]N[5*]',
#  '[1*]C([1*])=O',
#  'C=C(Cl)Cl',
#  'Cc1cccc2c1Cc1ccccc1-2',
#  'CCCCC=O',
#  '[16*]c1ccccc1',
#  '[5*]N[5*]',
#  '[3*]O[3*]',
#  '[16*]c1ccccc1',
#  '[5*]N(C)C',
#  '[4*]CCCC[4*]',
#  '[1*]C(=O)S[11*]',
#  '[3*]OP(=S)(O[3*])S[11*]',
#  '[5*]N1CCCCC1C',
#  '[1*]C(=O)C[4*]',
#  '[4*]CCC',
#  'CCCCCCCI',
#  '[16*]c1cccc(Cl)c1',
#  '[16*]c1ccccc1',
#  'C=CCCCO',
#  'O=C1NC(=O)C2(CCC2)C(=O)N1',
#  '[8*]C(C)C',
#  '[15*]C1CCC(C)CC1O',
#  '[4*]C(C)C',
#  '[3*]OC=O',
#  'CCCCCC(C)O',
#  '[16*]c1ccc(Br)cc1',
#  '[5*]N[5*]',
#  '[1*]C(C)=O',
#  '[16*]c1ccccc1',
#  '[9*]n1ncc(N)c(Br)c1=O',
#  '[3*]OC',
#  '[1*]C(=O)C1=C(C)NC(C)=C(C([1*])=O)C1[15*]',
#  '[16*]c1ccccc1[N+](=O)[O-]',
#  'Cc1ccc2ccc(C)nc2c1',
#  'C#CCCCCCC',
#  '[8*]CC',
#  '[15*]C1(C2=CCCCC2)C(=O)NC(=O)NC1=O',
#  'c1ccc2c(c1)ccc1c3ccccc3ccc21',
#  '[8*]C(C)CC',
#  '[9*]n1c(=O)[nH]c(C)c(Br)c1=O',
#  '[16*]c1c(Cl)c(Cl)cc(Cl)c1Cl',
#  '[16*]c1cccc(Cl)c1Cl',
#  'Cc1ccccc1O',
#  'CC(C)CCC(C)(C)C',
#  'Cc1ccc(C)c2ccccc12',
#  'Cc1cc2c3ccccc3ccc2c2ccccc12',
#  'CCCC(C)=O',
#  '[16*]c1c(Cl)c(Cl)cc(Cl)c1Cl',
#  '[3*]O[3*]',
#  '[1*]C(=O)CC',
#  '[4*]CCC',
#  '[15*]C1(O)C(O)CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC21C',
#  '[6*]C(=O)CO',
#  'Nc1ccc(O)cc1',
#  '[1*]C(=O)C[8*]',
#  '[16*]c1ccccc1',
#  '[4*]C[8*]',
#  '[5*]N[5*]',
#  '[9*]n1ccnc1[N+](=O)[O-]',
#  '[16*]c1ccc(Cl)cc1',
#  '[15*]C1CCC(C2=C(O)C(=O)c3ccccc3C2=O)CC1',
#  '[4*]CC',
#  '[5*]N([5*])[5*]',
#  '[14*]c1nc([14*])nc(Cl)n1',
#  '[5*]N[5*]',
#  '[14*]c1cnccn1',
#  '[6*]C(N)=O',
#  '[1*]C(N)=O',
#  '[5*]N[5*]',
#  '[1*]C(=O)C(Br)(CC)CC',
#  '[16*]c1ccccc1Cl',
#  'O=C1CN(N=Cc2ccc([N+](=O)[O-])o2)C(=O)N1',
#  '[16*]c1ccc(Cl)cc1Cl',
#  '[16*]c1ccc([N+](=O)[O-])cc1',
#  '[3*]O[3*]',
#  'CC12CCC(CC1=O)C2(C)C',
#  '[8*]CC=C',
#  '[15*]C1([15*])C(=O)NC(=O)NC1=O',
#  '[16*]c1ccccc1',
#  '[4*]CC',
#  '[3*]O[3*]',
#  '[1*]C(=O)CCCC',
#  '[4*]CCC(C)C',
#  '[3*]O[3*]',
#  '[1*]C(C)=O',
#  '[3*]OC[8*]',
#  '[16*]c1ccccc1',
#  '[10*]N1C(=O)NC([13*])([13*])C1=O',
#  '[1*]C(=O)CCCCC',
#  '[16*]c1cccc(Cl)c1',
#  '[16*]c1cc(Cl)ccc1Cl',
#  'CCCBr',
#  '[8*]C[8*]',
#  '[8*]CCC',
#  '[13*]C1COC([13*])([13*])O1',
#  '[16*]c1ccc(Cl)cc1Cl',
#  '[9*]n1cncn1',
#  '[1*]C(=O)C[4*]',
#  '[5*]N(C)C=O',
#  '[11*]SP(=S)(OC)OC',
#  'Cc1ncnc2nccnc12',
#  'NC(N)=S',
#  'Cc1ccc(C)cc1',
#  '[8*]CC',
#  '[16*]c1ccccc1[16*]',
#  'ClC(Cl)(Cl)C(Cl)(Cl)Cl',
#  '[16*]c1ccc([16*])cc1',
#  '[1*]C(=O)C([8*])C(C)C',
#  '[16*]c1cccc([16*])c1',
#  '[3*]O[3*]',
#  '[16*]c1ccccc1',
#  '[4*]C([8*])C#N',
#  '[3*]OC(F)F',
#  'CCC[N+](=O)[O-]',
#  '[15*]C1CCC(C)CC1=O',
#  '[8*]C(C)C',
#  '[4*]CC',
#  '[5*]N1c2cc(Cl)ccc2NC(=O)c2cccnc21',
#  'O=[N+]([O-])c1cccc(Cl)c1Cl',
#  '[8*]CC=C',
#  '[15*]C1([15*])C(=O)NC(=S)NC1=O',
#  '[8*]C(C)CCC',
#  'c1ccc2c(c1)-c1cccc3cccc-2c13',
#  '[3*]O[3*]',
#  '[4*]C(C)C',
#  '[4*]CCC',
#  'Cc1cc(C)c2ccccc2c1',
#  '[16*]c1ccc(O)cc1',
#  '[7*]C([8*])CC',
#  'N#Cc1c(Cl)c(Cl)c(Cl)c(C#N)c1Cl',
#  '[16*]c1cc(Cl)ccc1Cl',
#  '[16*]c1ccc(Cl)c(Cl)c1',
#  '[16*]c1ccccc1',
#  '[13*]C1CO1',
#  '[16*]c1ccccc1',
#  '[8*]C(C)C',
#  '[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C',
#  '[6*]C(=O)CO',
#  'Clc1c(Cl)c(Cl)c2nccnc2c1Cl',
#  'OC1COC(O)C(O)C1O',
#  'ClCCl',
#  '[16*]c1cccc2ccccc12',
#  '[8*]CC',
#  'COC=O',
#  'O=[N+]([O-])c1ccccc1O',
#  'Cc1c[nH]c(=O)[nH]c1=O',
#  'CC(C)C',
#  '[13*]C1OC([13*])C(O)C1O',
#  '[9*]n1cnc2c(O)ncnc21',
#  '[8*]CO',
#  'N#Cc1cc(I)c(O)c(I)c1',
#  '[1*]C([6*])=O',
#  '[16*]c1ccc([N+](=O)[O-])cc1Cl',
#  '[16*]c1cc(Cl)ccc1O',
#  '[5*]N[5*]',
#  'CCCCC',
#  'Oc1ccccc1',
#  'Nc1ccc2cc3ccccc3cc2c1',
#  'Cn1cnc2c1c(=O)[nH]c(=O)n2C',
#  'c1ccc2cnccc2c1',
#  '[16*]c1ccc(Cl)cc1',
#  '[4*]C(C)C',
#  '[11*]SP(=S)(OC)OC',
#  '[1*]C(=O)C[4*]',
#  '[5*]N([5*])[5*]',
#  '[8*]CCCCCC',
#  '[16*]c1ccccc1',
#  '[16*]c1ccccc1',
#  '[16*]c1ccccc1Cl',
#  'C=C(C)CCC',
#  'CC(C)C(C)C(C)C',
#  'Clc1cc(Cl)c(Cl)c(Cl)c1Cl',
#  'O=[N+]([O-])c1cccc(O)c1',
#  'C=CCCCCCCCC',
#  '[4*]CC([4*])C[4*]',
#  '[3*]O[3*]',
#  '[1*]C(C)=O',
#  '[5*]N(C)C',
#  '[14*]c1nc(C)c([16*])c(O)n1',
#  '[8*]CCCC',
#  '[3*]O[3*]',
#  '[16*]c1ccccc1',
#  '[4*]C([8*])C#N',
#  '[1*]C([6*])=O',
#  '[16*]c1ccc(F)c([16*])c1',
#  '[15*]C1C(C=C(Cl)Cl)C1(C)C',
#  'c1ccncc1',
#  'CCCCCCCBr',
#  'Cc1ccncc1C',
#  '[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3(F)C(O)CC21C',
#  '[6*]C(=O)CO',
#  '[4*]CC',
#  '[3*]O[3*]',
#  '[11*]S[11*]',
#  '[4*]C[8*]',
#  '[16*]c1ccccc1[16*]',
#  '[5*]NC',
#  '[1*]C([1*])=O',
#  '[4*]CC',
#  '[3*]O[3*]',
#  '[1*]C(=O)CC([1*])=O',
#  'C=C(C)C1CC=C(C)CC1',
#  'c1ccc2c(c1)CCC2',
#  '[16*]c1ccc(O)cc1',
#  '[8*]C(C)(C)C',
#  'O=C1NC(=O)C2(CC2)C(=O)N1',
#  'Clc1cccc(I)c1',
#  'Brc1cccc2ccccc12',
#  '[7*]CC',
#  '[7*]CCC',
#  'Cc1cccc(C)n1',
#  'ClC=C(Cl)Cl',
#  'Nc1cccc2ccccc12',
#  'Cc1cccc(C)c1',
#  'Oc1ncc2nccnc2n1',
#  'CO',
#  '[15*]C1([15*])C(=O)NC(=O)NC1=O',
#  '[8*]CC',
#  '[8*]CCC(C)C',
#  'CCC(C)=O',
#  'O=c1[nH]cc(F)c(=O)[nH]1',
#  '[13*]C1OC([13*])C(O)C1O',
#  '[9*]n1ccc2c(N)ncnc21',
#  '[8*]CO',
#  'Oc1cccc(O)c1',
#  'CCCCCCO',
#  'CCCCCCl',
#  'C=CC=C',
#  '[4*]CCC',
#  '[3*]O[3*]',
#  '[1*]C(C)=O',
#  'Oc1ccc2c(c1)CCCC2',
#  'NC(=O)CCl',
#  '[3*]OP(=S)(OC)OC',
#  '[16*]c1cc(Cl)c(I)cc1Cl',
#  'Cc1ccc(Cl)cc1',
#  '[8*]C(C)(C)C',
#  '[14*]c1nnc([14*])n(N)c1=O',
#  '[11*]SC',
#  '[16*]c1ccc(C)cc1',
#  '[16*]c1cccc(C)c1',
#  '[3*]OP(=O)(O[3*])O[3*]',
#  '[16*]c1ccccc1C',
#  'CCCCCC=O',
#  '[1*]C([6*])=O',
#  '[3*]O[3*]',
#  '[16*]c1ccc(N)cc1',
#  '[4*]CCCC',
#  'Cc1ccc2c(c1)Oc1ncc(N)cc1C(=O)N2C',
#  '[7*]CCCC([7*])C',
#  '[7*]CCO',
#  '[7*]C(C)C',
#  '[16*]c1ccc(Cl)cc1',
#  '[16*]c1ccccc1Cl',
#  '[3*]OC[8*]',
#  '[10*]N1C(=O)NC([13*])([13*])C1=O',
#  '[16*]c1ccccc1',
#  '[1*]C(=O)CCCCCCC',
#  'CC[N+](=O)[O-]',
#  '[4*]CC(=C)C',
#  '[4*]CC',
#  '[8*]C(F)(F)F',
#  '[16*]c1cc([N+](=O)[O-])c([16*])c([N+](=O)[O-])c1',
#  '[5*]N([5*])[5*]',
#  'Clc1ccc(Cl)c(Cl)c1Cl',
#  '[3*]O[3*]',
#  '[1*]C(N)=O',
#  '[4*]CC(C)(C[4*])CCC',
#  '[15*]C1CCC2C3CC=C4CC(O)CCC4(C)C3CCC12C',
#  '[6*]C(C)=O',
#  'CI',
#  '[15*]C1CC(=O)NC(=O)C1',
#  '[15*]C1CC(C)CC(C)C1=O',
#  '[8*]CC([8*])O',
#  '[3*]OC[8*]',
#  '[10*]N1C(=O)NC([13*])([13*])C1=O',
#  '[16*]c1ccccc1',
#  '[1*]C(=O)CCCCCC',
#  'CC1=CC(=O)CC(C)(C)C1',
#  '[8*]C(C)CC',
#  '[8*]CC',
#  '[15*]C1([15*])C(=O)NC(=O)NC1=O',
#  'CCCCC(=O)CCCC',
#  '[15*]C1([15*])CCC(=O)NC1=O',
#  '[16*]c1ccccc1',
#  '[8*]CC',
#  'CCC(C)CC',
#  '[16*]c1ccc([16*])cc1',
#  '[4*]CC',
#  '[16*]c1cccc([16*])c1',
#  '[3*]O[3*]',
#  '[16*]c1ccccc1',
#  '[4*]C[8*]',
#  '[4*]CC([8*])(C)C',
#  '[16*]c1ccccc1C',
#  '[9*]n1c(C)nc2ccccc2c1=O',
#  'N#CCCl',
#  '[4*]CC',
#  '[3*]OP(=S)(CC)O[3*]',
#  '[16*]c1cc(Cl)c(Cl)cc1Cl',
#  'C#CC1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3CCC21C',
#  'c1ccnnc1',
#  'Clc1cc(Cl)c(Cl)c(Cl)c1',
#  'CC1COC2CC3(C)C(CC4C5C=C6CC(O)CCC6(C)CC5CCC43C)OC2C1',
#  'Nc1ccccc1O',
#  '[1*]C(=O)CCCCCCCC',
#  '[3*]O[3*]',
#  '[4*]CC',
#  '[3*]OC',
#  '[1*]C(=O)C([4*])C',
#  '[16*]c1c(C)cccc1C',
#  '[1*]C(=O)C[4*]',
#  '[5*]N([5*])[5*]',
#  '[3*]O[3*]',
#  '[4*]C(C)C',
#  '[16*]c1ccccc1[16*]',
#  '[5*]NC',
#  '[1*]C([1*])=O',
#  'CCC(C)Cl',
#  'Oc1ccc2ccccc2c1',
#  '[9*]n1nc([14*])oc1=O',
#  '[8*]C(C)(C)C',
#  '[3*]O[3*]',
#  '[4*]C(C)C',
#  '[16*]c1cc([16*])c(Cl)cc1Cl',
#  'C#CCCCC',
#  'C#CCCCCCCC',
#  'Cc1ccccc1Cl',
#  '[3*]O[3*]',
#  '[4*]C(C)C',
#  'Nc1ccc(S(=O)(=O)c2ccc(N)cc2)cc1',
#  'CNN',
#  'C#CC',
#  '[4*]CC',
#  '[3*]OP(=S)(O[3*])ON=C(C#N)c1ccccc1',
#  '[3*]O[3*]',
#  '[4*]C(C)C',
#  '[7*]C(C)OP(=S)(NCC)OC',
#  '[1*]C(=O)C[7*]',
#  'C=CC=O',
#  'O=c1[nH]cnc2nc[nH]c12',
#  'Oc1ccc2ncccc2c1',
#  'Fc1ccccc1',
#  'CCCCl',
#  '[4*]CC',
#  '[3*]O[3*]',
#  '[1*]C(C)=O',
#  'CCCC(C)(C)C',
#  'Cc1cc(C)c(C)c(C)c1C',
#  'CC12CCC(CC1)C(C)(C)O2',
#  '[3*]O[3*]',
#  '[1*]C(=O)CCCCCCCCC([1*])=O',
#  '[4*]CCCC',
#  '[16*]c1ccc(Cl)cc1',
#  'Cc1cccnc1C',
#  'C=C(C)C1CC=C(C)C(=O)C1',
#  '[4*]CC',
#  '[16*]c1ccc(Cl)cc1',
#  '[3*]OP(=S)(O[3*])SCS[11*]',
#  '[3*]OC',
#  '[13*]C1OC2COC(C)OC2C(O)C1O',
#  '[3*]OC1c2cc3c(cc2C(c2cc([16*])c(O)c([16*])c2)C2C(=O)OCC12)OCO3',
#  'c1cc2cccc3c4cccc5cccc(c(c1)c23)c54',
#  'Cc1ccc([N+](=O)[O-])cc1[N+](=O)[O-]',
#  'Brc1ccc2ccccc2c1',
#  '[5*]NC',
#  '[1*]C([1*])=O',
#  '[16*]c1cccc(N=CN(C)C)c1',
#  '[3*]O[3*]',
#  '[3*]OC',
#  '[14*]c1cnc2ncncc2n1',
#  '[15*]C1CC1',
#  '[5*]N1c2ncccc2C(=O)Nc2c(C)ccnc21',
#  '[4*]CC',
#  '[9*]n1nc([14*])nc1Cl',
#  '[8*]C(C)C',
#  '[3*]OP(=S)(O[3*])O[3*]',
#  'C=CC(=C)C',
#  '[7*]CCCC(C)(O)C=C',
#  '[7*]C(C)C',
#  '[16*]c1ccc([16*])c(C)c1',
#  '[3*]OP(=S)(OC)OC',
#  '[11*]SC',
#  'OC1CCCCC1',
#  '[8*]CC=C',
#  '[15*]C1(C)C(=O)NC(=O)NC1=O',
#  'CC12CCC3C(CCC4CC(O)CCC43C)C1CCC2=O',
#  'OCC(O)C(O)C(O)C(O)CO',
#  '[16*]c1ccc(C)cc1',
#  '[16*]c1ccccc1',
#  '[4*]CC',
#  '[4*]C(C)C',
#  '[14*]c1nc([14*])nc(Cl)n1',
#  '[5*]N[5*]',
#  '[16*]c1ccccc1',
#  '[5*]NC(N)=S',
#  'CCCC(=O)CCC',
#  'CC(=O)C(C)(C)C',
#  'Oc1ccc(Cl)cc1',
#  'O=C1CCCCC1',
#  'Cc1cccc(N)c1',
#  'N#CC(Cl)(Cl)Cl',
#  '[16*]c1cccc([16*])c1',
#  '[8*]C(F)(F)F',
#  '[5*]NC',
#  '[9*]n1ncc([16*])c(Cl)c1=O',
#  'CCCCCCCCC(C)=O',
#  '[14*]c1nc([14*])nc(Cl)n1',
#  '[4*]CC',
#  '[4*]C(C)C',
#  '[5*]N[5*]',
#  '[5*]N([5*])[5*]',
#  '[4*]CC',
#  '[1*]C([6*])=O',
#  '[3*]O[3*]',
#  '[16*]c1ccc(N)cc1',
#  'Clc1ccc(Cl)c(Cl)c1',
#  'Cc1nnc2n1-c1ccc(Cl)cc1C(c1ccccc1Cl)=NC2',
#  'Oc1ccccc1O',
#  '[4*]CC',
#  '[5*]N1c2ncccc2C(=O)N(C)c2cccnc21',
#  'CSC',
#  'Cc1ccccc1Br',
#  '[4*]CC',
#  '[3*]O[3*]',
#  '[1*]C(N)=O',
#  '[1*]C(C)=O',
#  '[3*]O[3*]',
#  '[15*]C1([15*])CCC2C3C=C(C)C4=CC(=O)CCC4(C)C3CCC21C',
#  '[4*]C1([15*])CCC2C3C=C(C)C4=CC(=O)CCC4(C)C3CCC21C',
#  '[6*]C(C)=O',
#  'CC(C)C(O)C(C)C',
#  'c1ccc2ccccc2c1',
#  '[4*]CC',
#  '[16*]c1ccccc1',
#  '[5*]N[5*]',
#  '[16*]c1ccccc1',
#  '[13*]C1([13*])NC(=O)NC1=O',
#  'Cc1c2ccccc2c(C)c2c1ccc1ccccc12',
#  '[4*]CC',
#  '[10*]N1C(=O)c2ccccc2C1=O',
#  '[4*]C([8*])CCl',
#  '[3*]OP(=S)(O[3*])S[11*]',
#  '[3*]OC',
#  '[8*]C([8*])C(Cl)(Cl)Cl',
#  '[16*]c1ccc([16*])cc1',
#  '[1*]C([6*])=O',
#  '[5*]N[5*]',
#  '[16*]c1c(F)cccc1F',
#  '[1*]C([1*])=O',
#  '[16*]c1cc(Cl)c(F)c(Cl)c1F',
#  '[3*]OC[8*]',
#  '[10*]N1C(=O)NC([13*])([13*])C1=O',
#  '[16*]c1ccccc1',
#  '[1*]C(=O)CCCC',
#  '[5*]N(C)C',
#  '[16*]c1ccc(Cl)cc1',
#  '[1*]C([1*])=O',
#  '[5*]N[5*]',
#  '[16*]c1ccccc1F',
#  '[9*]n1cncn1',
#  '[16*]c1ccc(F)cc1',
#  '[8*]CC([8*])([8*])O',
#  '[3*]O[3*]',
#  '[4*]CC([6*])=O',
#  '[15*]C1CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C1([15*])O',
#  '[1*]C(C)=O',
#  'CCCCBr',
#  'Brc1cc(Br)c(Br)cc1Br',
#  'CC(=O)CC(C)C',
#  '[4*]CC',
#  '[15*]C1CCCCC1',
#  '[5*]N([5*])[5*]',
#  '[1*]C(=O)S[11*]',
#  '[3*]OC',
#  '[16*]c1ccc(Cl)cc1',
#  '[16*]c1cccc([16*])c1',
#  '[3*]O[3*]',
#  '[16*]c1ccccc1',
#  '[4*]C([8*])C#N',
#  '[1*]C([6*])=O',
#  '[15*]C1C(C=C(Br)Br)C1(C)C',
#  '[8*]CC=C',
#  '[8*]C(C)CC',
#  '[15*]C1([15*])C(=O)NC(=O)NC1=O',
#  '[16*]c1ccc([N+](=O)[O-])c(C)c1',
#  '[3*]OP(=S)(OC)OC',
#  'Ic1cccc2ccccc12',
#  'OCC(O)C(O)C(O)C(O)CO',
#  'CCS',
#  'ClCC(Cl)Cl',
#  '[3*]O[3*]',
#  '[16*]c1ccccc1',
#  '[9*]n1nc(C)cc1[14*]',
#  '[5*]N(C)C',
#  '[1*]C([1*])=O',
#  '[6*]C(N)=O',
#  '[16*]c1ccccc1O',
#  'Cc1ccccc1[N+](=O)[O-]',
#  '[15*]C1([15*])C(=O)NC(=O)NC1=O',
#  '[8*]C(C)C',
#  '[16*]c1ccccc1C',
#  '[8*]CC',
#  'CCCCCCCCl',
#  '[15*]C1([15*])C(=O)NC(=O)NC1=O',
#  '[8*]CC',
#  '[16*]c1ccccc1',
#  '[8*]CC[8*]',
#  'ClC(Cl)C(Cl)Cl',
#  '[3*]OC',
#  '[5*]N1c2cc([16*])cc(C)c2NC(=O)c2cccnc21',
#  '[4*]CC',
#  'Cc1ccc2c(ccc3ccccc32)c1',
#  '[1*]C([6*])=O',
#  '[3*]O[3*]',
#  '[16*]c1ccccc1[16*]',
#  '[4*]CCCC',
#  '[3*]OC',
#  '[16*]c1c(O)c(Cl)c(Cl)c(Cl)c1Cl',
#  '[4*]CC',
#  '[3*]OP(=O)(OC)OC',
#  '[1*]C(=O)C([7*])Cl',
#  '[4*]CC[7*]',
#  '[5*]N([5*])[5*]',
#  'CC12CCC3C(=CCc4cc(O)ccc43)C1CCC2=O',
#  '[4*]CC',
#  '[3*]OC',
#  '[3*]O[3*]',
#  '[14*]c1cc(Cl)nc(N(C=O)NS(=O)(=O)c2ccccc2[16*])n1',
#  '[1*]C([6*])=O',
#  '[3*]OC',
#  '[16*]c1ccc([N+](=O)[O-])cc1',
#  'CCCCCCCl',
#  '[16*]c1cc(Cl)c(Cl)c(Cl)c1Cl',
#  '[13*]C1OC([13*])C(O)C(O)C1O',
#  '[4*]C1([13*])OC([13*])C(O)C1O',
#  '[3*]O[3*]',
#  '[13*]C1OC([13*])([13*])C(O)C1O',
#  '[4*]C[8*]',
#  '[8*]CO',
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC',
#  '[4*]CC',
#  '[5*]N1c2ccccc2N(C)C(=O)c2cccnc21',
#  'CC(Cl)Cl',
#  'Nc1ccc(S(N)(=O)=O)cc1',
#  '[16*]c1cc([N+](=O)[O-])c([16*])c([N+](=O)[O-])c1',
#  '[5*]N([5*])[5*]',
#  '[8*]C(C)C',
#  '[4*]CCC',
#  'ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl',
#  '[4*]CC',
#  '[3*]O[3*]',
#  '[4*]C(C)C',
#  '[3*]OP(=S)(NC(C)C)O[3*]',
#  '[1*]C([6*])=O',
#  '[16*]c1ccccc1[16*]',
#  'Clc1cccc(Cl)c1Cl',
#  'ClC(Cl)(Cl)Cl',
#  'O=[N+]([O-])c1ccc(Cl)c(Cl)c1',
#  'OC1CCCCCCC1',
#  'CC12CCC(=O)C=C1CCC1C2CCC2(C)C1CCC2(C)O',
#  '[16*]c1ccc([16*])cc1',
#  '[4*]CC',
#  '[3*]O[3*]',
#  '[1*]C(N)=O',
#  '[5*]N[5*]',
#  'CC1CCC(C)CC1',
#  'c1cnc2c(c1)ccc1ncccc12',
#  '[3*]OC',
#  '[4*]C(C)(C)C',
#  '[3*]OC',
#  '[7*]CC',
#  '[16*]c1ccc([16*])cc1',
#  '[7*]C[8*]',
#  'CCCCCCCCCCCCCCCCO',
#  'O=c1cc[nH]c(=O)[nH]1',
#  'Nc1ncnc2nc[nH]c12',
#  '[16*]c1cccc(Cl)c1Cl',
#  '[16*]c1cc(Cl)c(Cl)cc1Cl',
#  '[8*]C([8*])([8*])O',
#  '[16*]c1ccc([16*])cc1',
#  '[3*]OC',
#  '[15*]C1CC1',
#  '[16*]c1cncnc1',
#  'c1ccc2c(c1)-c1cccc3c1c-2cc1ccccc13',
#  '[16*]c1ccccc1',
#  '[1*]C([1*])=O',
#  '[5*]N[5*]',
#  '[15*]C1([15*])C(=O)NC(=O)NC1=O',
#  '[16*]c1ccccc1',
#  '[8*]CC',
#  '[16*]c1ccc(Cl)cc1',
#  '[16*]c1cccc(Cl)c1Cl',
#  '[16*]c1ccc([16*])cc1',
#  '[8*]C(C)C',
#  '[5*]N[5*]',
#  '[5*]N(C)C',
#  '[1*]C([1*])=O',
#  '[4*]CC',
#  '[14*]c1ccc(Cl)nn1',
#  '[11*]S[11*]',
#  '[1*]C(=O)C[4*]',
#  '[5*]N([5*])[5*]',
#  'CCC(C)(C)CO',
#  '[3*]O[3*]',
#  '[1*]C(=O)CCC',
#  '[4*]CCC',
#  'Cc1c([N+](=O)[O-])cc([N+](=O)[O-])cc1[N+](=O)[O-]',
#  '[12*]S(=O)(=O)c1ccccc1',
#  '[3*]OP(=S)(O[3*])S[11*]',
#  '[4*]C(C)C',
#  '[4*]CC[4*]',
#  '[5*]N[5*]',
#  'C1CCCCCC1',
#  '[4*]CCC',
#  '[3*]OC=O',
#  '[16*]c1ccccc1C',
#  '[8*]C(C)C',
#  'Nc1cccc(Cl)c1',
#  'CC(C)CC(C)C',
#  'c1ccc2c(c1)oc1ccccc12',
#  '[4*]CC',
#  '[3*]OS(C)(=O)=O',
#  '[13*]C1Oc2ccc([16*])cc2C1(C)C',
#  '[3*]O[3*]',
#  '[16*]c1cccc([16*])c1',
#  '[5*]N[5*]',
#  '[5*]N(C)C',
#  '[1*]C([1*])=O',
#  '[8*]C(F)(F)F',
#  'c1ccc2nc3ccccc3cc2c1',
#  '[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(=O)CC21C',
#  '[6*]C(=O)CO',
#  '[13*]C1OC(O)C(O)C(O)C1O',
#  '[8*]CO',
#  'Cc1cccc(O)c1',
#  '[6*]C(=O)NN1c2ccccc2CC1C',
#  '[16*]c1ccc(Cl)c(S(N)(=O)=O)c1',
#  '[15*]C1CC(C)C=C2C=CC(C)C([15*])C21',
#  '[3*]O[3*]',
#  '[8*]CC[8*]',
#  '[1*]C(=O)C(C)CC',
#  '[13*]C1CC(O)CC(=O)O1',
#  'O=[N+]([O-])c1ccc([N+](=O)[O-])cc1',
#  '[15*]C1(C2=CCC3CCC2C3)C(=O)NC(=O)NC1=O',
#  '[8*]CC',
#  '[4*]CC',
#  '[1*]C(=O)CCCCCCCCC',
#  '[3*]O[3*]',
#  '[5*]N(C)C',
#  '[16*]c1ccccc1',
#  '[1*]C([1*])=O',
#  '[5*]N[5*]',
#  '[4*]CC',
#  '[3*]O[3*]',
#  '[4*]CCC',
#  'CC(C)O',
#  'Cc1ccc2ccccc2c1',
#  'ClC(Br)Br',
#  '[16*]c1ccc(O)cc1',
#  '[8*]C(CC)C([8*])CC',
#  '[4*]CC',
#  '[3*]O[3*]',
#  '[11*]SP(=S)(OC)OC',
#  '[1*]C(=O)CC([4*])C([1*])=O',
#  '[16*]c1ccccc1',
#  '[8*]CCl',
#  '[7*]CC',
#  '[7*]CC=O',
#  '[16*]c1ccc(Br)c(Cl)c1',
#  '[5*]N[5*]',
#  '[1*]C(=O)N(C)OC',
#  'Cc1c2ccccc2c(C)c2ccccc12',
#  '[3*]OC',
#  '[1*]C(=O)CCCCC',
#  '[16*]c1ccc([16*])c(Cl)c1',
#  '[9*]n1nc([14*])oc1=O',
#  '[8*]C(C)(C)C',
#  '[5*]N[5*]',
#  '[5*]N(C)C',
#  '[1*]C([1*])=O',
#  '[16*]c1ccc(F)cc1',
#  '[5*]N[5*]',
#  '[1*]C(C)=O',
#  '[1*]C(=O)CCl',
#  '[16*]c1cccc([16*])c1[16*]',
#  '[8*]CC',
#  '[5*]N([5*])COC',
#  'C1=CCCCC1',
#  '[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(O)CC21C',
#  '[6*]C(=O)CO',
#  'c1cncnc1',
#  'O=[N+]([O-])c1ccc(Cl)cc1',
#  '[3*]OC',
#  '[1*]C(=O)CC',
#  'O=[N+]([O-])c1ccccc1Cl',
#  '[5*]N([5*])C',
#  '[16*]c1ccc(Cl)c(Cl)c1',
#  '[5*]N[5*]',
#  '[4*]CCCC',
#  '[1*]C([1*])=O',
#  '[14*]c1nnc([14*])s1',
#  '[8*]C(C)(C)C',
#  '[10*]N1C(=O)N(C)CC1O',
#  'O=[N+]([O-])c1ccccc1',
#  'Ic1ccccc1',
#  '[16*]c1ccccc1C',
#  '[10*]N1C(=O)c2cc(S(N)(=O)=O)c(Cl)cc2NC1C',
#  '[3*]OC',
#  '[3*]O[3*]',
#  '[4*]CC(O)C[4*]',
#  '[1*]C(N)=O',
#  '[16*]c1ccccc1[16*]',
#  '[1*]C(=O)CCl',
#  '[16*]c1cccc([16*])c1[16*]',
#  '[3*]OCN([5*])[5*]',
#  '[8*]CC',
#  '[4*]CCCC',
#  'Oc1cccc(Cl)c1Cl',
#  '[3*]OC',
#  '[1*]C(=O)CCC',
#  '[1*]C(=O)CC',
#  '[5*]N[5*]',
#  '[16*]c1ccc(Cl)c(Cl)c1',
#  '[16*]c1ccccc1',
#  '[14*]c1nc2c(N)nc(N)nc2nc1N',
#  '[4*]CC',
#  '[3*]O[3*]',
#  '[1*]C(=O)CCCCC',
#  '[8*]C(Cl)(Cl)Cl',
#  '[8*]C(O)CO',
#  '[13*]C1OC2OC([13*])C(O)C2O1',
#  'Cc1ccc(N=CN(C)C=Nc2ccc(C)cc2C)c(C)c1',
#  '[3*]OC',
#  '[14*]c1nc([14*])nc([14*])n1',
#  '[4*]C(C)C',
#  '[5*]N[5*]',
#  'C=CCCCCCC',
#  'Cc1ccc(N)cc1',
#  'Nc1nccs1',
#  '[16*]c1ccccc1',
#  '[5*]NC',
#  '[1*]C([1*])=O',
#  '[3*]O[3*]',
#  'CCCC(O)CC',
#  'Oc1c2ccccc2cc2ccccc12',
#  'Cc1ccc2cc3ccccc3cc2c1',
#  'Cc1cccc(C)c1C',
#  '[3*]O[3*]',
#  '[16*]c1ccc([16*])c(C)c1',
#  '[5*]N(C)C',
#  '[5*]NC',
#  '[1*]C([1*])=O',
#  'CCCCCCCC(C)O',
#  '[5*]N([5*])C',
#  '[16*]c1ccccc1',
#  '[4*]C([8*])(C)C',
#  '[5*]N[5*]',
#  '[1*]C([1*])=O',
#  'CCCC(=O)CC',
#  'N#Cc1cc(Br)c(O)c(Br)c1',
#  '[16*]c1ccccc1',
#  '[16*]c1ccc(Cl)c(Cl)c1',
#  '[5*]N([5*])C',
#  '[3*]O[3*]',
#  '[16*]c1ccccc1',
#  '[14*]c1nc2ccccc2s1',
#  '[1*]C(=O)C[4*]',
#  'Oc1cccc2ncccc12',
#  '[16*]c1ccccc1',
#  '[1*]C(=O)C1=C(C)OCCS1',
#  '[5*]N[5*]',
#  '[4*]CC',
#  '[3*]O[3*]',
#  '[16*]c1ccc2nc(S(N)(=O)=O)sc2c1',
#  'Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl',
#  'ClCBr',
#  '[8*]CC',
#  '[15*]C1([15*])C(=O)NC(=O)N(C)C1=O',
#  '[3*]O[3*]',
#  '[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C',
#  '[4*]CC([6*])=O',
#  '[1*]C(C)=O',
#  '[4*]C[8*]',
#  '[16*]c1ccccc1',
#  '[1*]C(N)=O',
#  '[5*]N[5*]',
#  '[5*]N(C)C',
#  '[1*]C([1*])=O',
#  '[16*]c1ccc(C)c(Cl)c1',
#  '[5*]N[5*]',
#  '[5*]N[5*]',
#  '[1*]C(=O)N(C)OC',
#  '[16*]c1ccc(Cl)c(Cl)c1',
#  'OC1CCCCCC1',
#  '[1*]C(=O)C(Cl)Cl',
#  '[4*]C(CO)C([8*])O',
#  '[16*]c1ccc(S(C)(=O)=O)cc1',
#  '[5*]N[5*]',
#  '[8*]CC',
#  '[15*]C1([15*])C(=O)NC(=S)NC1=O',
#  '[8*]C(C)CCC',
#  '[14*]c1nnc(S(N)(=O)=O)s1',
#  '[5*]N[5*]',
#  '[1*]C(C)=O',
#  'O=[N+]([O-])c1ccc(O)cc1',
#  'ClC1=C(Cl)C2(Cl)C3C4C=CC(C4)C3C1(Cl)C2(Cl)Cl',
#  'C1CCOC1',
#  'Nc1ccccc1[N+](=O)[O-]',
#  '[16*]c1cccc(Cl)c1Cl',
#  '[10*]N1C(=O)C([15*])C(=O)N1[10*]',
#  '[16*]c1ccccc1',
#  '[8*]CCCC',
#  'Cc1c([N+](=O)[O-])cccc1[N+](=O)[O-]',
#  '[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C',
#  '[6*]C(C)=O',
#  '[4*]CC',
#  '[5*]N([5*])[5*]',
#  '[14*]c1nc([14*])nc(Cl)n1',
#  '[4*]C(Cl)(Cl)C(Cl)Cl',
#  '[11*]SN1C(=O)C2CC=CCC2C1=O',
#  'Brc1ccc(Br)c(Br)c1',
#  'O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O',
#  '[8*]CC=C',
#  '[15*]C1([15*])C(=O)NC(=O)NC1=O',
#  '[8*]C(C)CCC',
#  '[16*]c1ccc(C)c(O)c1',
#  '[8*]C(C)C',
#  'O=C1CSC(=S)N1',
#  '[16*]c1ccc(O)cc1O',
#  '[14*]c1oc2cc(O)cc(O)c2c(=O)c1O',
#  'O=C1C2(Cl)C3(Cl)C4(Cl)C(Cl)(Cl)C5(Cl)C3(Cl)C1(Cl)C5(Cl)C24Cl',
#  '[4*]CC',
#  '[5*]N([5*])C(=S)SSC(=S)N([5*])[5*]',
#  'C1CCCCC1',
#  'ClC1=C(Cl)C(Cl)(C2(Cl)C(Cl)=C(Cl)C(Cl)=C2Cl)C(Cl)=C1Cl',
#  'Cc1cc(Cl)ccc1N=CN(C)C',
#  'CC12CCc3c(ccc4cc(O)ccc34)C1CCC2=O',
#  'CCCCCCCCO',
#  '[4*]CC',
#  '[11*]S[11*]',
#  'ClCCCl',
#  'CCC(C)(C)Cl',
#  'ClCCBr',
#  'Nc1ccc([N+](=O)[O-])cc1',
#  '[13*]C1OC(O)C(O)C(O)C1[15*]',
#  '[3*]O[3*]',
#  '[13*]C1OC([13*])C(O)C(O)C1O',
#  '[8*]CO',
#  '[4*]CC',
#  '[5*]N1c2ncccc2C(=O)N(CC)c2cccnc21',
#  'Clc1ccccc1',
#  'C=CCCCCCCC',
#  'Brc1ccc(I)cc1',
#  'CCC(C)(O)CC',
#  '[16*]c1ccccc1',
#  '[8*]CCCCC',
#  '[13*]C1NC(=O)NC1=O',
#  '[1*]C(N)=O',
#  '[5*]N[5*]',
#  '[3*]O[3*]',
#  '[4*]CC(O)CO',
#  '[1*]C([6*])=O',
#  '[5*]N[5*]',
#  '[16*]c1ccccc1[16*]',
#  '[16*]c1ccnc2cc(Cl)ccc12',
#  '[16*]c1ccc(Cl)cc1',
#  '[8*]C([8*])C(Cl)Cl',
#  '[3*]O[3*]',
#  '[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C',
#  '[1*]C(C)=O',
#  'Clc1cccc2ccccc12',
#  '[4*]CC',
#  '[5*]N1c2ccccc2C(=O)N(C)c2ccccc21',
#  'CCCCC(C)O',
#  '[8*]CCC',
#  '[15*]C1CCCC1',
#  '[4*]CC',
#  '[9*]n1cncc1[14*]',
#  '[3*]O[3*]',
#  '[16*]c1ccccc1',
#  '[8*]C([8*])C',
#  '[1*]C([6*])=O',
#  'Oc1ccc(Cl)c(Cl)c1',
#  '[16*]c1cccc([16*])c1',
#  '[3*]O[3*]',
#  '[16*]c1ccccc1',
#  '[4*]C([8*])C#N',
#  '[1*]C([6*])=O',
#  '[15*]C1C(C=C(Cl)Cl)C1(C)C',
#  'c1ccc2ocnc2c1',
#  'CCCCCO',
#  '[4*]CC',
#  '[16*]c1ccccc1',
#  '[5*]N([5*])[5*]',
#  'Fc1cccc(F)c1',
#  'N#CCCCl',
#  '[16*]c1ccccc1',
#  '[8*]CC(C)(C)C',
#  '[15*]C1([15*])C(=O)NC(=O)NC1=O',
#  '[16*]c1ccccc1',
#  '[8*]CC',
#  'Clc1ccccc1I',
#  'c1ccc2[nH]nnc2c1',
#  '[5*]NC',
#  '[1*]C([1*])=O',
#  '[16*]c1cccc2c1OC(C)(C)C2',
#  '[3*]O[3*]',
#  'Cc1cccc(C)c1O',
#  'CC(C)C(C)O',
#  '[16*]c1ccccc1',
#  '[8*]C([8*])O',
#  '[3*]OC',
#  '[1*]C(=O)CCCCCCCCC',
#  '[3*]OP(=S)(OC)OC',
#  '[16*]c1ccc([N+](=O)[O-])cc1Cl',
#  'CC(C)CBr',
#  'CCI',
#  '[5*]N(C)C',
#  '[3*]O[3*]',
#  '[1*]C([1*])=O',
#  '[14*]c1nc([14*])c(C)c(C)n1',
#  'CCCCCCBr',
#  'CCCC(C)C',
#  '[3*]O[3*]',
#  '[15*]C1C([15*])C1(C)C',
#  '[7*]C[8*]',
#  '[1*]C([6*])=O',
#  '[4*]C[8*]',
#  '[16*]c1c(F)c(F)c(C)c(F)c1F',
#  ...]

# %%
len(fr_all)
# Out:
# 2315

# %% [markdown]
# フラグメントでは重複するものがあります。ここでは`set()`関数を使って、一意のフラグメントの集合をつくります。下記のように実行するとフラグメント数として1028となりました。すなわち約半分が重複していたことになります。

# %%
frag_library = set(fr_all)
frag_library
# Out:
# {'CCCC(C)=O',
#  '[1*]C(=O)C(Cl)Cl',
#  'C1CCOCC1',
#  '[9*]n1c(=O)[nH]c(C)c(Br)c1=O',
#  '[13*]C1([13*])NC(=O)NC1=O',
#  'Cc1ccc2cc3ccccc3cc2c1',
#  'C=C(C)C1CC=C(C)CC1',
#  '[15*]C1CCC(C)CC1O',
#  'Cc1cccc(O)c1',
#  'Oc1cc(Cl)c(Cl)c(Cl)c1Cl',
#  '[14*]c1onc(C)c1C',
#  '[8*]CC(O)C(O)C(O)CO',
#  '[9*]n1oc(=O)n(C)c1=O',
#  'CCCCCCCCC',
#  'O=[N+]([O-])c1ccc(Cl)cc1',
#  '[16*]c1c(C)[nH]c(=O)[nH]c1=O',
#  '[5*]NC1=C(Cl)C(=O)c2ccccc2C1=O',
#  '[15*]C1CC(C)C=C2C=CC(C)C([15*])C21',
#  '[5*]N1c2ncccc2C(=O)N(CC)c2cccnc21',
#  '[15*]C1(C2=CCC3CCC2C3)C(=O)NC(=O)NC1=O',
#  'CCCC(=O)CC',
#  'N#Cc1ccccc1',
#  '[16*]c1cc([16*])cc([16*])c1',
#  '[14*]c1nnc([14*])n(N)c1=O',
#  'CCC#N',
#  'CC12CCc3c(ccc4cc(O)ccc34)C1CCC2=O',
#  '[7*]C(C=O)CC',
#  'CCS',
#  '[14*]c1nnc(S(N)(=O)=O)s1',
#  '[15*]C1(C)C(=O)NC(=O)NC1=O',
#  '[1*]C(=O)CCCCCC',
#  '[16*]c1ccc2oc(=O)c(Cl)c(C)c2c1',
#  'CCC(C)(C)C',
#  'OC1CCCCC1',
#  '[14*]c1ncc([N+](=O)[O-])s1',
#  '[5*]NC',
#  'O=Cc1ccccc1',
#  'O=c1[nH]c(=O)c2[nH]c(=O)[nH]c2[nH]1',
#  'NS(=O)(=O)c1cc(C2(O)NC(=O)c3ccccc32)ccc1Cl',
#  'C=CC(O)CCC',
#  'Cc1ccc(C)c2ccccc12',
#  'CC(C)CCC(C)(C)C',
#  '[5*]N([5*])COC',
#  'CC(C)Br',
#  '[1*]C(=O)C([7*])Cl',
#  'c1ccc2cnccc2c1',
#  'c1ccsc1',
#  '[6*]C(=O)CO',
#  'Cc1ccncc1C',
#  'Brc1ccc2ccccc2c1',
#  '[8*]CCCCC',
#  'C=C(C)C',
#  '[9*]n1ccnc1[N+](=O)[O-]',
#  '[4*]C(C)(C)C#N',
#  '[11*]S[11*]',
#  'ClCCCl',
#  'Cc1ncc2nccnc2n1',
#  'Cl/C=C\\Cl',
#  '[15*]C1CCC(=O)NC1=O',
#  '[13*]C1OC(O)C(O)C(O)C1O',
#  '[15*]C1(C)CCC2C3CCC4=CC(=O)CCC4(C)C3CCC21C',
#  '[13*]C1NC(=O)NC1=O',
#  'CC(C)C(C)O',
#  'Brc1ccc(I)cc1',
#  'COCOC',
#  'O=[N+]([O-])c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1',
#  'CCCCCCCCCCCCCCO',
#  'Oc1c2ccccc2cc2ccccc12',
#  'CC12CCC3C(CC=C4CC(O)CCC43C)C1CCC2=O',
#  '[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(=O)CC21C',
#  '[9*]n1ncc(N)c(Br)c1=O',
#  '[16*]c1ccc(Cl)c(Cl)c1',
#  'Cc1cc2ccccc2c2ccc3ccccc3c12',
#  '[13*]C1CC(=O)c2c(O)cc(O)cc2O1',
#  'CCC(C)Cl',
#  'Clc1ccc(Cl)cc1',
#  'O=C1NC(=O)C(=O)C(=O)N1',
#  '[4*]CC([4*])C[4*]',
#  '[16*]c1ccc(Cl)cc1',
#  '[3*]OP(=S)(O[3*])N1C(=O)c2ccccc2C1=O',
#  '[15*]C1CCCCCCC1',
#  'ClC(Cl)C(Cl)Cl',
#  '[16*]c1ccncc1',
#  'Fc1ccc(F)cc1',
#  '[5*]NC(=N)N',
#  '[3*]O[N+](=O)[O-]',
#  'Cc1c(C)c(C)c(C)c(C)c1C',
#  '[14*]c1nc(C)c([16*])c(=O)[nH]1',
#  'N#CCCl',
#  '[4*]C([4*])C(Cl)(Cl)Cl',
#  '[1*]C(=O)CCCCCCC',
#  'Clc1ccc(Cl)c(Cl)c1',
#  '[4*]CC=C',
#  '[16*]c1ccc(C)c(Cl)c1',
#  'O=[N+]([O-])c1ccccc1O',
#  '[16*]c1ccccc1O',
#  'C#CCC',
#  'Cc1cc(Cl)ccc1N=CN(C)C',
#  'O=[N+]([O-])c1cccc2ccccc12',
#  '[1*]C(=O)C([4*])C',
#  'C[N+](=O)[O-]',
#  'ClC1=C(Cl)C2(Cl)C3C(Cl)C(Cl)CC3C1(Cl)C2(Cl)Cl',
#  '[4*]CC([6*])=O',
#  '[14*]c1cc(C)nc([14*])n1',
#  'CCCCCl',
#  'CC12CCC(=O)C=C1CCC1C2CCC2(C)C1CCC2(C)O',
#  'Cc1ccc(C)c(C)c1',
#  'CI',
#  'BrC(Br)Br',
#  'C=CC=C',
#  'ClC1=C(Cl)C2(Cl)C3C4C=CC(C4)C3C1(Cl)C2(Cl)Cl',
#  'Clc1cc(Cl)c(Cl)cc1Cl',
#  'O=c1[nH]cnc2nc[nH]c12',
#  'C#CC1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3CCC21C',
#  'CC(C)Cl',
#  'CC(C)CCl',
#  '[5*]N1c2cc(Cl)ccc2NC(=O)c2cccnc21',
#  'CCCCCCC(C)=O',
#  'CCCCCCCC(C)O',
#  '[9*]n1nc(C)cc1[14*]',
#  '[1*]C([6*])=O',
#  'c1ccc2c(c1)Cc1c-2ccc2ccccc12',
#  'CCCCCCCCCCCCCCCCCCCC',
#  'CCCCCO',
#  '[11*]SP(=S)(OC)OC',
#  'CCCCCC(C)O',
#  '[16*]c1c(C)cccc1C',
#  '[4*]C(Br)C(Cl)(Cl)Br',
#  '[14*]c1nc([14*])c([16*])c(C)n1',
#  'OC1CCCCCC1',
#  'CCC(C)O',
#  'CC12CCC3C(CCC4CC5SC5CC43C)C1CCC2O',
#  '[16*]c1cccc(C)c1[16*]',
#  'CC(C)C',
#  '[5*]NC=O',
#  '[4*]C([8*])CCl',
#  'CCC(O)C(C)C',
#  '[16*]c1c(Cl)cc(Cl)cc1Cl',
#  '[15*]C1CCCCC1C',
#  '[10*]N1C(=O)NC([13*])([13*])C1=O',
#  '[3*]OP(=S)(OC)OC',
#  'C=CCCCCC',
#  'Cc1ccc2cc(C)ccc2c1',
#  'Cc1c([N+](=O)[O-])cccc1[N+](=O)[O-]',
#  'CCCCCC(O)CC',
#  '[5*]N1c2ncccc2C(=O)Nc2c([16*])cc(C)nc21',
#  'Cc1c2ccccc2c(C)c2ccccc12',
#  'C=CCl',
#  'c1ccnnc1',
#  'CCC(O)CC',
#  '[1*]C(=O)C[7*]',
#  '[15*]C1CCCCC1',
#  '[9*]n1nc([14*])nc1Cl',
#  'Oc1ccc2c(c1)CCCC2',
#  'CSSC',
#  '[16*]c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O',
#  'CCCC(C)C',
#  'C=C(C)C(=C)C',
#  '[16*]c1ccccc1F',
#  '[1*]C(=O)CCCCCCCCC',
#  'c1ccc2scnc2c1',
#  '[15*]C1C(C=C(Cl)Cl)C1(C)C',
#  'N#Cc1cc(Br)c(O)c(Br)c1',
#  '[8*]C([8*])(O)C(Cl)(Cl)Cl',
#  'C=C(C)C1CC=C(C)C(=O)C1',
#  '[15*]C1C(C)(C)C1(C)C',
#  '[16*]c1c(Cl)c(Cl)cc(Cl)c1Cl',
#  '[16*]c1ccc([16*])c(Cl)c1',
#  'CC(C)C(C)C(C)C',
#  'Nc1ccccc1Cl',
#  'CCCC(C)(C)CO',
#  '[10*]N1C(=O)OC(C)(C=C)C1=O',
#  'Cc1ccc2ccccc2c1',
#  '[8*]C([8*])C(Cl)(Cl)Cl',
#  'CC(C)CCO',
#  'Cc1cccc2c1ccc1ccccc12',
#  '[16*]c1ccc(F)cc1F',
#  'c1ccc2c(c1)cnc1ccccc12',
#  'c1ccc2c(c1)-c1cccc3cccc-2c13',
#  '[16*]c1ccc([N+](=O)[O-])cc1Cl',
#  '[16*]c1c2occc2c([16*])c2c(=O)cc(C)oc12',
#  'CC(C)CCCO',
#  'CCC(C)(C)O',
#  'Cc1cnc2cncnc2n1',
#  '[16*]c1c(F)cccc1F',
#  '[13*]C1CC(O)C([15*])C(C)O1',
#  '[14*]c1nc(N)c2cc([16*])c([16*])c([16*])c2n1',
#  '[1*]C(=O)C=C',
#  'CCCCCCCCCO',
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC',
#  'CC1CCC(C)CC1',
#  'C=C(Cl)Cl',
#  '[13*]C1Nc2cc([16*])c(S(N)(=O)=O)cc2S(=O)(=O)N1',
#  '[4*]CC(C)C',
#  '[16*]c1cc(Cl)c(Cl)cc1Cl',
#  'CCCO',
#  '[1*]C(=O)C1=C(C)NC(C)=C(C([1*])=O)C1[15*]',
#  'Fc1cccc(Br)c1',
#  'Oc1ccccc1O',
#  'CCC=O',
#  'ClC(Cl)(Cl)Cl',
#  '[8*]CC=C',
#  '[5*]NC(=S)N[5*]',
#  'CCC',
#  'O=[N+]([O-])c1ccccc1Cl',
#  'C=C(C)CC',
#  'Cc1cccc(N)c1',
#  '[13*]C1NC(=O)c2cc(S(N)(=O)=O)c(Cl)cc2N1',
#  'c1cc2c3c(c4ccc5ccccc5c4cc3c1)CC2',
#  'NC(N)=S',
#  'NC(=O)CCl',
#  'CCCCC(C)CC',
#  'Oc1ccc(Cl)c(Cl)c1',
#  'C1=CCC=CC1',
#  '[16*]c1ccc([N+](=O)[O-])c(C)c1',
#  'CCCCCCCCCCO',
#  '[1*]C(=O)C1=C(O)c2ccccc2S(=O)(=O)N1C',
#  'Oc1ccc(Cl)c(Cl)c1Cl',
#  'C1CCC2CCCCC2C1',
#  'COP(=O)(OC)OC(=CCl)c1cc(Cl)c(Cl)cc1Cl',
#  '[14*]c1ccccn1',
#  'CCCC(C)CO',
#  '[16*]c1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl',
#  '[10*]N1C(=O)c2ccccc2C1=O',
#  '[16*]c1ccc(O)c(O)c1',
#  '[8*]C([8*])C(Cl)Cl',
#  '[4*]C(C)(C)C',
#  '[13*]C1OC2OC([13*])C(O)C2O1',
#  'Fc1cccc(F)c1',
#  '[8*]CCO',
#  'CC(O)C(C)(C)C',
#  '[4*]C1([15*])C(C)CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC21C',
#  'CCCCO',
#  '[4*]C(C)(C)CCCC(C)CC[7*]',
#  'Oc1cc(Cl)c(Cl)cc1Cl',
#  '[16*]c1cccnc1',
#  'CC12CCC3C(CCC4CC(=O)CCC43C)C1CCC2O',
#  'CCCCS',
#  '[10*]N1CC(=O)N([10*])C1=O',
#  '[16*]c1ccc(N)cc1',
#  'OC1C(O)C(O)C(O)C(O)C1O',
#  'Cn1ccc(=O)[nH]c1=O',
#  '[3*]OP(=S)(O[3*])SCS[11*]',
#  'O=[N+]([O-])c1ccc(Cl)c(Cl)c1',
#  'Clc1cccc2ccccc12',
#  '[1*]C(=O)C1=C(C)OCCC1',
#  'O=C1OC(c2ccc(O)cc2)(c2ccc(O)cc2)c2ccccc21',
#  'CC(=O)CC(C)C',
#  '[8*]C[8*]',
#  'O=C1NC(=O)C2(CCCC2)C(=O)N1',
#  '[16*]c1ccc([16*])c(C)c1',
#  'Cc1c(C)c2c3ccccc3ccc2c2ccccc12',
#  '[16*]c1c(F)c(F)c(C)c(F)c1F',
#  '[13*]C1CC(O)C(O)C(C)O1',
#  '[14*]c1nc2ccccc2s1',
#  'Cc1c[nH]c2ccccc12',
#  'CCCCCCC',
#  'CC1=CC(=O)c2ccccc2C1=O',
#  '[13*]C1OC([13*])C(O)C(O)C1O',
#  '[1*]C(=O)CCCCC',
#  'CCCCC',
#  '[4*]CCCCCC(C)C',
#  'CC1(C)C(=O)NC(=O)NC1=O',
#  'CC(C)CO',
#  'CCCCCCCCCCCCCCCCCCO',
#  'O=C1CCCN1',
#  '[7*]C([8*])CC',
#  '[16*]c1ccc(S(C)=O)cc1',
#  'O=[N+]([O-])c1cccc(O)c1',
#  '[11*]SP(=O)(S[11*])S[11*]',
#  'Oc1c(Cl)ccc(Cl)c1Cl',
#  '[1*]C(=O)C(C)CC',
#  'Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl',
#  '[3*]OC=C',
#  '[16*]c1ccc(O)c([16*])c1',
#  'ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl',
#  'ICI',
#  '[14*]c1ncc2nccnc2n1',
#  '[4*]CCCCCC',
#  '[8*]CC(C)(C)C',
#  'O=[N+]([O-])c1cccc([N+](=O)[O-])c1',
#  'CC(C)[N+](=O)[O-]',
#  '[8*]CCC',
#  'CCC(C)C(C)=O',
#  '[4*]C(CO)CS(=O)CSC',
#  'C=CCCC',
#  'CCCCC(=O)CCCC',
#  '[15*]C1CCCC1',
#  'c1cnc2ncncc2n1',
#  'Cc1cccc([N+](=O)[O-])c1',
#  'Nc1ncnc2nc[nH]c12',
#  'O=[N+]([O-])c1ccccc1',
#  '[14*]c1cc(C)on1',
#  'Brc1ccccc1',
#  '[15*]C1([15*])CCC(=O)NC1=O',
#  '[4*]C(Cl)(Cl)C(Cl)Cl',
#  'CCCCCCCl',
#  'O=c1cc[nH]c(=O)[nH]1',
#  '[11*]SS(=O)CC=C',
#  'CC(C)I',
#  '[4*]CC(O)CO',
#  'CC(Cl)(Cl)Cl',
#  '[1*]C(=O)C(=NO[3*])SC',
#  'Clc1cc(Cl)c(Cl)c(Cl)c1Cl',
#  '[8*]C(C)CCC',
#  '[14*]c1cnc2cncnc2n1',
#  'Nc1ccc(O)cc1',
#  'CC1CO1',
#  '[8*]CC(=C)Br',
#  'CCCC=O',
#  '[3*]OP(=S)(O[3*])O[3*]',
#  '[9*]n1c(=O)[nH]c(C)c(Cl)c1=O',
#  'O=C1NC(=O)c2ccccc21',
#  '[15*]C1C([15*])C1(C)C',
#  'O=C1NC(=O)C2(CCC2)C(=O)N1',
#  'CCCCCCO',
#  'c1ccc2c(c1)ccc1c2ccc2c3ccccc3ccc21',
#  'Cc1ccc(Cl)cc1',
#  'CC1=CC(=O)CC(C)(C)C1',
#  'O=C1NC(=O)C2(CCCCCC2)C(=O)N1',
#  'Cc1ccnc(C)c1',
#  'CC(C)C(C)C',
#  'Cc1ccc(O)cc1',
#  'Clc1cc(Cl)c(Cl)c(Cl)c1',
#  '[13*]C1Oc2ccc([16*])cc2C1(C)C',
#  '[16*]c1cc(Cl)ccc1O',
#  '[9*]n1c(=O)c(N)c(C)n1C',
#  '[9*]n1nc([14*])oc1=O',
#  'Cc1ccc2c(c1)Oc1ncc(N)cc1C(=O)N2C',
#  'COP(=O)(OC)C(O)C(Cl)(Cl)Cl',
#  '[14*]c1nnc([14*])s1',
#  '[8*]C(C)(C)C',
#  'COC1=C(OC)C2C(=O)OCC2C=C1',
#  'O=c1ccnc(S)[nH]1',
#  'Cc1c2ccccc2cc2ccccc12',
#  '[5*]N1CCCCC1',
#  'Clc1ccc2ccccc2c1',
#  '[8*]C(C)C',
#  '[1*]C(=O)CC([1*])=O',
#  '[5*]N1c2ncccc2C(=O)Nc2c(C)cc(C)nc21',
#  '[14*]c1nc2c(N)nc(N)nc2nc1N',
#  'C1CCCCC1',
#  '[16*]c1cc(Cl)c(Cl)c(Cl)c1Cl',
#  '[1*]C(=O)C(Br)(CC)CC',
#  'CCCCl',
#  'CCCCCC(C)(C)O',
#  'Clc1ccccc1Br',
#  'C=C(C)CCC',
#  'CN1C(=O)CN=C(c2ccccc2)c2cc([N+](=O)[O-])ccc21',
#  'c1ccc2cc3c(cc2c1)-c1cccc2cccc-3c12',
#  'CCCCC(C)=O',
#  'Cc1ccccc1',
#  'Oc1c(Cl)cccc1Cl',
#  'CCCCCCCCCCCCCC',
#  'CC(C)C(O)C(C)C',
#  'CCCI',
#  'CCCC(C)(O)CC',
#  'Brc1cccc2ccccc12',
#  'CCC(C)CCO',
#  '[14*]c1nc2ccc([16*])cc2[nH]1',
#  'Cc1cc(C)cc(C)c1',
#  'CSC',
#  '[16*]c1cccc(Cl)c1Cl',
#  '[10*]N1CCNC1=O',
#  '[16*]c1cn(C)cc([16*])c1=O',
#  '[3*]OC=O',
#  '[9*]n1c(=O)c([16*])c(C)n1C',
#  '[16*]c1ccc(Br)cc1',
#  '[16*]c1ccc(F)cc1',
#  '[4*]C(C)C#C',
#  'Oc1ccncc1',
#  '[4*]C([8*])C(=O)C(C)(C)C',
#  '[16*]c1ccc2ccccc2c1',
#  '[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(O)CC21C',
#  'C1CCOC1',
#  '[16*]c1c(F)cccc1Cl',
#  'OC1CCCCCCC1',
#  '[6*]C(=O)C([8*])O',
#  'CCCCCCCCl',
#  'CCCC',
#  'CO',
#  '[7*]CCCCC',
#  '[1*]C(=O)CCCCCCCCC([1*])=O',
#  'c1cc2ccc3ccc4ccc5ccc6ccc1c1c2c3c4c5c61',
#  '[3*]OC[8*]',
#  '[5*]N1c2cc([16*])cc(C)c2NC(=O)c2cccnc21',
#  '[5*]NC(N)=S',
#  'OCC(O)C(O)CO',
#  '[4*]CC(C)(C[4*])CCC',
#  'Brc1cc(Br)c(Br)cc1Br',
#  'CN(C)C(=S)SSC(=S)N(C)C',
#  '[15*]C1([15*])C(C)CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC21C',
#  'O=Cc1ccc(O)cc1',
#  'Oc1ccc(O)cc1',
#  '[8*]CCCC',
#  '[3*]OCN([5*])[5*]',
#  '[13*]C1CO1',
#  '[16*]c1cccc(N=CN(C)C)c1',
#  'CCCCCC=O',
#  'Cc1cc(C)c(C)cc1C',
#  'CC(C)CC(C)O',
#  '[4*]C1([15*])CCC2C3C=C(C)C4=CC(=O)CCC4(C)C3CCC21C',
#  'NNc1ccccc1',
#  '[7*]CC([7*])C',
#  '[7*]C([8*])[8*]',
#  'Cc1c[nH]c(=O)[nH]c1=O',
#  '[16*]c1cc2c(cc1[16*])C1C(=O)c3ccc4c(c3OC1CO2)CC(C(=C)C)O4',
#  'Oc1ccc(Cl)cc1Cl',
#  'Nc1ccc(Cl)cc1',
#  'ClCCCCl',
#  'Cc1c[nH]c(=O)nc1N',
#  'Cc1ccc2c(ccc3c4c5c(cccc5cc32)CC4)c1',
#  'CC(C)CC(C)(C)C',
#  '[4*]C1(C#C)CCC2C3CCC4=CC(=O)CCC4C3CCC21C',
#  '[15*]C1(C2=CCCCC2)C(=O)NC(=O)NC1=O',
#  'ClC(Cl)C(Cl)(Cl)Cl',
#  '[9*]n1cnc2c(O)ncnc21',
#  '[16*]c1ccc(C)cc1',
#  'Cc1ccc([N+](=O)[O-])cc1[N+](=O)[O-]',
#  'C=CCCCO',
#  'CCCCCC',
#  '[1*]C(=O)CC[4*]',
#  'c1ccc2c(c1)ccc1c3ccccc3ccc21',
#  '[3*]OP(=S)(O[3*])ON=C(C#N)c1ccccc1',
#  'O=c1[nH]cnc2[nH]ncc12',
#  'CC1=C2C3OC(=O)C(C)C3CCC2(C)C=CC1=O',
#  'ClC(Cl)=C(Cl)C(Cl)=C(Cl)Cl',
#  'CC12CCC3c4ccc(O)cc4CCC3C1CC(O)C2O',
#  'Cc1cc(C)cc(O)c1',
#  '[8*]CC(C)C',
#  '[14*]c1cccc(Cl)n1',
#  'O=[N+]([O-])c1cccc(Cl)c1',
#  'ClC(Cl)=C(c1ccc(Cl)cc1)c1ccc(Cl)cc1',
#  'COP(=O)(NC(C)=O)SC',
#  'ClCCBr',
#  'ClC(Cl)(Cl)C(Cl)(Cl)Cl',
#  '[5*]N1C=CN([5*])C=C1',
#  '[1*]C(N)=O',
#  'CCCC(=O)CCC',
#  'c1ccc2nc3ccccc3cc2c1',
#  '[6*]C(=O)NN',
#  'CCCl',
#  'Oc1c(Cl)c(Cl)cc(Cl)c1Cl',
#  'O=c1oc2ccccc2c(O)c1C1CCCc2ccccc21',
#  '[8*]C([8*])([8*])O',
#  '[16*]c1cc(S(N)(=O)=O)c(Cl)cc1O',
#  '[16*]c1ccc(O)cc1',
#  'C=CC=O',
#  'Clc1cccc(I)c1',
#  'Nc1cc[nH]c(=O)n1',
#  'Cc1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O',
#  'CCO',
#  'CCC(=O)CC',
#  'CCCCCCC(C)O',
#  'c1ccc2ocnc2c1',
#  'Clc1ccc(Br)cc1',
#  '[16*]c1ccc(C)cc1O',
#  'Cc1ccc(S(N)(=O)=O)cc1',
#  'Oc1ccccn1',
#  'Cc1ccc(O)c(C)c1',
#  '[7*]CC',
#  'CCC[N+](=O)[O-]',
#  '[5*]N1c2ccccc2N(C)C(=O)c2cccnc21',
#  'Cc1cc(C)c2ccccc2c1',
#  '[4*]C([4*])C',
#  'Oc1ccccc1Cl',
#  'c1ccc2c3c(ccc2c1)-c1cccc2cccc-3c12',
#  '[7*]C(C)OP(=O)(OC)OC',
#  'CCCCCCCCCC(C)O',
#  'Nc1ccc(S(N)(=O)=O)cc1',
#  'Cc1cccc2sc3nncn3c12',
#  'CCCCCCCCBr',
#  '[15*]C1(C#C)CCC2C3CCC4=CC(=O)CCC4C3CCC21C',
#  'CC(=O)C(C)C',
#  '[6*]C(N)=O',
#  'CC#N',
#  'c1ccc2[nH]ccc2c1',
#  'Cn1c(=O)c2[nH]cnc2n(C)c1=O',
#  'C=CCCCCCCC',
#  'CCCC(C)(C)O',
#  '[16*]c1ccccc1I',
#  'CCCCCCCCO',
#  'Clc1ccc(Cl)c(Cl)c1Cl',
#  '[15*]C1([15*])CCC2C3C=C(C)C4=CC(=O)CCC4(C)C3CCC21C',
#  '[16*]c1ccc([16*])c([16*])c1',
#  'CC(=O)C(C)(C)C',
#  'C=CCC=C',
#  'CC12CCC(CC1=O)C2(C)C',
#  '[4*]CCC(C)C',
#  'CCCCC(C=O)CC',
#  '[1*]C(=O)C1=C(C)OCCS1(=O)=O',
#  '[1*]C(=O)CC',
#  '[11*]SC',
#  'Fc1ccccc1Br',
#  'Cc1ccccc1C',
#  '[14*]c1ccc(Cl)nn1',
#  'C#C',
#  '[7*]C(C)OP(=S)(NCC)OC',
#  'Cc1ccc(O)cc1C',
#  'O=C1NC(=O)C2(CCCCCCC2)C(=O)N1',
#  'c1ccc2c(c1)Cc1cc3ccccc3cc1-2',
#  'Oc1ccc(Br)cc1',
#  'Cc1c2ccccc2c(C)c2c1ccc1ccccc12',
#  'Clc1ccc(I)cc1',
#  'CBr',
#  '[5*]N1c2ncccc2C(=S)N(C)c2cccnc21',
#  'Cc1cccc(C)n1',
#  'CC(C)(C)CO',
#  '[4*]CCCC[4*]',
#  '[4*]CC([8*])(C)C',
#  'O=C1CNC(=O)N1',
#  'c1ccc(N=Nc2ccccc2)cc1',
#  '[12*]S(=O)(=O)C(F)(F)F',
#  'CCCCCC(C)C',
#  'ClC(Br)Br',
#  '[14*]c1cnccn1',
#  '[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3CCC12C',
#  'Cn1cnc2c1c(=O)[nH]c(=O)n2C',
#  '[3*]OS(=O)(=O)N(C)C',
#  '[3*]ON=C(C[4*])C(C)(C)C',
#  'CCC(C)(C)CO',
#  '[16*]c1ccc(C)c(O)c1',
#  '[5*]N1c2nc([14*])ccc2NC(=O)c2cccnc21',
#  '[16*]c1cccc2ccccc12',
#  'C1CCCC1',
#  'O=C1NC(=O)C2C=CC=CC12',
#  '[1*]C(=O)CCCC',
#  'O=c1[nH]c2cc(Cl)ccc2o1',
#  '[9*]n1c2nc(=O)[nH]c(=O)c-2nc2cc(C)c(C)cc21',
#  'CC(C)CC(C)(C)O',
#  'CCCCCCBr',
#  '[4*]CC(Cl)=C(Cl)Cl',
#  '[4*]C1([13*])OC([13*])C(O)C1O',
#  '[16*]c1ccc(Cl)c(Cl)c1Cl',
#  'c1ccccc1',
#  'CCC(C)C',
#  '[13*]C1OCC(O)C(O)C1O',
#  '[15*]C1CCC2(C)C(CCC3C2CCC2(C)C(C4=CC(=O)OC4)CCC32O)C1',
#  '[4*]CCO',
#  '[7*]C1C2C=C(C([8*])([8*])O)C1C1C(=O)NC(=O)C21',
#  'C1CCCCCC1',
#  'Cc1cccc(C)c1C',
#  'O=C1CCCCC1',
#  '[9*]n1cncn1',
#  '[15*]C1([15*])C(=O)NC(=O)NC1=O',
#  'C#CC',
#  '[13*]C1OCCO1',
#  'Cc1ccc(N)cc1',
#  'N#Cc1c(Cl)c(Cl)c(Cl)c(C#N)c1Cl',
#  '[13*]C1CC(O)CC(=O)O1',
#  '[16*]c1c(O)c2ccccc2oc1=O',
#  'CCBr',
#  'CCCCCCCC',
#  '[16*]c1cccc([16*])c1[16*]',
#  'Oc1cccc(Cl)c1',
#  'CC12CCC3C(CCC4CC(O)CCC43C)C1CCC2=O',
#  'CCC(C)=O',
#  'Clc1cccc(Cl)c1',
#  '[5*]N1c2ncccc2C(=O)N(C)c2ccc(Cl)nc21',
#  'ClC(Cl)=C(Cl)Cl',
#  'BrCCBr',
#  'C=CCCCCCCCC',
#  '[15*]C1CC2=CC(=O)CCC2(C)C2CCC3(C)C(CCC34CCC(=O)O4)C12',
#  '[8*]CCC(C)=O',
#  'FC(F)(Cl)C(F)(F)Cl',
#  'OC1COC(O)C(O)C1O',
#  '[4*]CCCC',
#  'CNN',
#  '[13*]C1Nc2cc(Cl)c(S(N)(=O)=O)cc2S(=O)(=O)N1',
#  'C=CC',
#  '[15*]C1C(=O)N2C(N(C)C)=Nc3ccc(C)cc3N2C1=O',
#  'Cc1ccccc1O',
#  'C#CCCC',
#  '[3*]OP(=S)(O[3*])S[11*]',
#  '[16*]c1cc([16*])c2c(c1Cl)OC1(C2=O)C(OC)=CC(=O)CC1C',
#  '[15*]C1CCC2(C)C(CCC3C2CC(O)C2(C)C(C4=CC(=O)OC4)CCC32O)C1',
#  '[11*]SS[11*]',
#  '[13*]C1COC([13*])([13*])O1',
#  'Oc1ncc2nccnc2n1',
#  '[15*]C1CC(C)CC(C)C1=O',
#  'Nc1cccc(Cl)c1',
#  'ClC1=C(Cl)C(Cl)(C2(Cl)C(Cl)=C(Cl)C(Cl)=C2Cl)C(Cl)=C1Cl',
#  'CCCCCCCCCCCCO',
#  'FC(F)(F)C(Cl)Br',
#  '[6*]C(=O)NNC[8*]',
#  '[1*]C(=O)C[4*]',
#  '[4*]CC([4*])C',
#  '[4*]CC(=C)C',
#  'CCC(C)(C)CC',
#  '[4*]CC(=C)Cl',
#  'C',
#  'Ic1ccccc1',
#  '[5*]N([5*])C(=S)SSC(=S)N([5*])[5*]',
#  'NS(=O)(=O)c1cc2c(cc1Cl)NCNS2(=O)=O',
#  'Nc1ccc([N+](=O)[O-])cc1',
#  '[5*]N1CCN([5*])CC1',
#  '[13*]C1OC2COC(C)OC2C(O)C1O',
#  '[15*]C1CCC(C)CC1=O',
#  '[16*]c1ccoc1C',
#  '[8*]C(O)C([8*])O',
#  '[1*]C(=O)CCCCCCCCCCC',
#  '[9*]n1ncc(N)c(Cl)c1=O',
#  'c1ccc2[nH]nnc2c1',
#  'CCCCCCl',
#  'c1ccc2c(c1)ccc1ccccc12',
#  'ClC1=C(Cl)C2(Cl)C3C(Cl)C=CC3C1(Cl)C2(Cl)Cl',
#  'c1ccc2c(c1)CCN2',
#  '[11*]SP(=O)(OC)OC',
#  '[14*]c1nc([14*])c(C)c(C)n1',
#  '[16*]c1cc(Cl)c(I)cc1Cl',
#  'CCCCCCCI',
#  'CC(C)C(=O)C(C)C',
#  '[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3(F)C(O)CC21C',
#  'c1ccc2[nH]ncc2c1',
#  'CC',
#  '[1*]C(=O)C[8*]',
#  'C#CCCCCCC',
#  '[9*]n1cncc1[14*]',
#  '[4*]CC[4*]',
#  'Nc1ccccc1[N+](=O)[O-]',
#  'CCCC(C)O',
#  'C=Cc1ccccc1',
#  '[4*]CC(O)C[4*]',
#  'Nc1nccs1',
#  '[10*]N1C(=O)C([15*])C(=O)N1[10*]',
#  'CC(Cl)CCl',
#  '[1*]C(=O)n1c([14*])nc2ccccc21',
#  '[1*]C(=O)C1=C(C)OCCS1',
#  '[8*]CCC(C)C',
#  'O=C1NC(=O)C(O)(C2(O)C(=O)NC(=O)NC2=O)C(=O)N1',
#  'C=CCC',
#  'CC(N)=O',
#  'Clc1cc(Cl)cc(Cl)c1',
#  'c1ccc2c(c1)CCCC2',
#  'O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=NC1O',
#  'O=[N+]([O-])c1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl',
#  'CCCCCBr',
#  'Cn1c(=O)c2c(ncn2C)n(C)c1=O',
#  'COC1=CC2OC3C=CC(O)=CC3C(=O)C2C(O)=C1',
#  '[8*]C([8*])C',
#  '[8*]C([8*])O',
#  '[4*]CC(Cl)=CCl',
#  'C=CC(=C)C',
#  'CCCCCCCC(C)=O',
#  'Oc1cc(Cl)cc(Cl)c1',
#  '[15*]C1(O)CCC2C3CC(C)C4=CC(=O)C=CC4(C)C3(F)C(O)CC21C',
#  'O=[N+]([O-])c1ccc(O)cc1',
#  '[5*]N(C)C',
#  '[16*]c1cc([N+](=O)[O-])c([16*])c([N+](=O)[O-])c1',
#  'Oc1ccc(Cl)cc1',
#  'O=C1CN=C(c2ccccc2Cl)c2cc([N+](=O)[O-])ccc2N1',
#  'C#CC1(O)CCC2C3CCc4cc(O)ccc4C3CCC21C',
#  '[15*]C12OC(C)(C)OC1CC1C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC12C',
#  '[16*]c1ccc([16*])cc1',
#  'O=C1CCC(=O)N1',
#  'Cc1cncc(C)c1',
#  '[10*]N1OCC(C)(C)C1=O',
#  '[14*]c1ccc2ccccc2n1',
#  '[7*]CCCC',
#  '[16*]c1cccc(C)c1',
#  'CCCCBr',
#  'CCC(C)CO',
#  'C#CC1(O)CCC2C3CCC4=Cc5oncc5CC4(C)C3CCC21C',
#  '[8*]CO',
#  'OC1C=CC2C1C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl',
#  'CC12CCC3C(CCC4=CC(=O)CCC43C)C1CCC2=O',
#  '[16*]c1ccc(Cl)c(S(N)(=O)=O)c1',
#  '[4*]C([8*])C#N',
#  'c1cc2ccc3ccc4ccc5cccc6c(c1)c2c3c4c56',
#  '[12*]S(=O)(=O)c1ccc(N)cc1',
#  '[16*]c1c(Cl)ccc(Cl)c1Cl',
#  '[15*]C1CCC2C3CC=C4CC(O)CCC4(C)C3CCC12C',
#  '[16*]c1ccccc1[16*]',
#  'Cc1ccc([N+](=O)[O-])cc1',
#  'CCC(C)(C)Cl',
#  'ClCCl',
#  '[9*]n1c(C)nc2ccccc2c1=O',
#  '[12*]S(=O)(=O)c1ccccc1',
#  '[8*]CC(O)CO',
#  '[7*]CCCC([7*])C',
#  'CCCCCCCCC(C)=O',
#  'Oc1cccc2ncccc12',
#  '[8*]C(C)O',
#  'c1ccc2c(c1)sc1ccccc12',
#  'Brc1ccccc1Br',
#  '[7*]CCC',
#  '[15*]C1C(C=C(Br)Br)C1(C)C',
#  '[16*]c1ccc(F)c([16*])c1',
#  'BrCBr',
#  'CCC(C=O)CC',
#  '[14*]c1nc(C)c([16*])c(O)n1',
#  'O=[N+]([O-])c1cccc(Cl)c1Cl',
#  '[10*]N1C(=O)C2(C)CC2(C)C1=O',
#  '[16*]c1ccnc2cc(Cl)ccc12',
#  '[1*]C(=O)C([4*])C(C)C',
#  '[4*]CC(C)(C)O',
#  'O=Cc1ccc2c(c1)OCO2',
#  '[5*]N(C)C=O',
#  'Brc1cc(Br)cc(Br)c1',
#  '[16*]c1cc(Cl)ccc1Cl',
#  'Oc1cc(Cl)cc(Cl)c1Cl',
#  'C#CCCCCC',
#  '[15*]C1(O)C(O)CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC21C',
#  'CCCCCCCCCCCCCCCCO',
#  'Nc1cc2c3ccccc3ccc2c2ccccc12',
#  'c1ccc2cc3cc4ccccc4cc3cc2c1',
#  'O=[N+]([O-])c1ccc(C=NO)o1',
#  'c1ccc2c(c1)[nH]c1ccccc12',
#  'Oc1c(Cl)cc(Cl)c(Cl)c1Cl',
#  'C=C',
#  'CC(C)O',
#  '[4*]CC[7*]',
#  'CCCCI',
#  'O=[N+]([O-])c1ccccc1[N+](=O)[O-]',
#  'O=C1CN(N=Cc2ccc([N+](=O)[O-])o2)C(=O)N1',
#  'c1ccc2c(c1)c1ccccc1c1ccccc21',
#  'c1cc2cccc3c4cccc5cccc(c(c1)c23)c54',
#  'CC12CCC(C1)C(C)(C)C2=O',
#  'Oc1cccc2ccccc12',
#  '[14*]c1cnc2ncncc2n1',
#  'CC12CC(=O)C3C(CCC4=CC(=O)CCC43C)C1CCC2=O',
#  'Cc1c([N+](=O)[O-])cc([N+](=O)[O-])cc1[N+](=O)[O-]',
#  'CCC#CCC',
#  'ClC(Cl)Cl',
#  '[9*]n1c(=O)cc(C)n1C',
#  '[3*]O[3*]',
#  'Cc1ccccc1[N+](=O)[O-]',
#  '[13*]C1OC([13*])([13*])C(O)C1O',
#  'CCCCC(C)O',
#  '[5*]N1c2ncccc2C(=O)Nc2c(C)ccnc21',
#  '[16*]c1cc(O)c(O)c(O)c1',
#  'Cc1ncnc2nccnc12',
#  'CC[N+](=O)[O-]',
#  '[1*]C(=O)CCC',
#  '[7*]CC[8*]',
#  'CN1C(=O)CN=C(c2ccccc2)c2cc(Cl)ccc21',
#  'Cc1ccccc1Br',
#  'O=[N+]([O-])C(Cl)(Cl)Cl',
#  'CCCCC(CC)CO',
#  '[1*]C([1*])=O',
#  '[4*]CC#CCCl',
#  'Sc1ccccc1',
#  'CC(C)(C)CCO',
#  'CC1COC2CC3(C)C(CC4C5C=C6CC(O)CCC6(C)CC5CCC43C)OC2C1',
#  'CC(C)C(C)(C)C',
#  'Oc1cccc(Cl)c1Cl',
#  'Cc1ccccc1Cl',
#  '[16*]c1cc(C)cc(C)c1',
#  'CCCCCCCO',
#  'Nc1cccc2ccccc12',
#  'NC(N)=O',
#  'CC1CCCC1',
#  '[4*]C[8*]',
#  '[7*]CC[7*]',
#  'c1ccc(NNc2ccccc2)cc1',
#  'ClC1=C(Cl)C2(Cl)C3C4CC(C5OC45)C3C1(Cl)C2(Cl)Cl',
#  'c1ccoc1',
#  'O=C1NC(=O)C(=O)N1',
#  'CCCC(C)(C)C',
#  'O=[N+]([O-])c1ccc([N+](=O)[O-])cc1',
#  '[15*]C1([15*])C(=O)NC(=O)N(C)C1=O',
#  'Clc1cccc(Cl)c1Cl',
#  'Clc1c(Cl)c(Cl)c2nccnc2c1Cl',
#  '[15*]C1CC1',
#  '[5*]N([5*])S(=O)c1ccc(N)cc1',
#  '[7*]C[8*]',
#  '[3*]OP(=S)(NC(C)C)O[3*]',
#  '[13*]C1OC([13*])C(O)C1O',
#  '[16*]c1cc([16*])c(Cl)cc1Cl',
#  '[11*]SN1C(=O)C2CC=CCC2C1=O',
#  'Nc1nc2[nH]cnc2c(=O)[nH]1',
#  'Cc1cc2c3ccccc3ccc2c2ccccc12',
#  '[16*]c1ccc(Cl)cc1Cl',
#  '[16*]c1c(Cl)cccc1Cl',
#  'O=C1NC(=O)C2(CCCCC2)C(=O)N1',
#  'CCCBr',
#  '[14*]c1nc([14*])nc(Cl)n1',
#  '[3*]OC',
#  '[8*]C(Cl)(Cl)Cl',
#  '[4*]C(C)C',
#  '[8*]C(O)CO',
#  'CC1CCCCC1',
#  '[1*]C(=O)CC(Cl)Cl',
#  'CC1(C)C2CCC1(C)C(O)C2',
#  'C#CC1(O)CCC2C3CCC4=CC(=O)CCC4(O)C3CCC21C',
#  'Cc1ccc2c(c1)C(=O)N(C)c1cc(N)ccc1O2',
#  '[16*]c1ccc2nc(S(N)(=O)=O)sc2c1',
#  'Cc1cccc(C)c1O',
#  '[14*]c1nc(Cl)c(Cl)cc1Cl',
#  '[4*]CCC[4*]',
#  '[16*]c1ccc(C=O)cc1',
#  'CCCCC(O)CC',
#  'Cc1cccnc1C',
#  'O=C1c2ccccc2Cc2ccccc2N1CCF',
#  '[15*]C1CCC2C3CCC4=CC(=O)CCC4(C)C3C(O)CC12C',
#  'C1=Cc2cccc3cccc1c23',
#  'COC=O',
#  '[13*]C1OC(O)C(O)C(O)C1[15*]',
#  'Brc1ccc(Br)cc1',
#  '[15*]C1(O)CCC2C3CCC4=CC(=O)C=CC4(C)C3C(O)CC21C',
#  'Clc1ccccc1Cl',
#  'BrC(Br)(Br)Br',
#  'CCCC(O)CCC',
#  'O=C1C=C2CC3(O)COc4c(ccc(O)c4O)C3=C2C=C1O',
#  '[8*]C(C)CC',
#  '[16*]c1cc([16*])c(C)cc1C',
#  'Cc1cc(=O)[nH]c(=S)[nH]1',
#  'O=C1Nc2ccc(Cl)cc2C(c2ccccc2Cl)=NC1O',
#  'Nc1nc(O)nc2nc[nH]c12',
#  'CCCCCCCCCCCCCCCC',
#  'ClCC(Cl)(Cl)Cl',
#  '[16*]c1cc(Cl)c(Br)cc1Cl',
#  '[7*]C([8*])C([7*])[8*]',
#  '[16*]c1cc([N+](=O)[O-])c([16*])c([N+](=O)[O-])c1N',
#  '[5*]N1c2ncccc2C(=O)N(C)c2cccnc21',
#  '[8*]C(CC)C([8*])CC',
#  '[1*]C(=O)C([8*])([8*])O',
#  'CC1=CCCCC1',
#  'Nc1nc(=O)[nH]cc1F',
#  'C=CCCCC',
#  '[16*]c1ccc2c(c1)OCO2',
#  'C=CCCCCCC',
#  'O=Cc1ccco1',
#  'Nc1ccc2cc3ccccc3cc2c1',
#  '[16*]c1ccccc1C',
#  'Cc1cccc2c(C)cccc12',
#  '[16*]c1ccccc1[N+](=O)[O-]',
#  '[5*]N([5*])C(=S)S[11*]',
#  'O=C1CSC(=S)N1',
#  '[3*]OC1=CC(=O)CC(C)(C)C1',
#  'OCC(O)CO',
#  'N#Cc1ccccc1C#N',
#  'c1ccc2c(c1)CCC2',
#  'C1=CCCCC1',
#  '[1*]C(=O)N(C)OC',
#  '[15*]C1(O)C(C)CC2C3CC(F)C4=CC(=O)C=CC4(C)C3(F)C(O)CC21C',
#  '[8*]CCCCCC',
#  '[7*]CCCC(C)(O)C=C',
#  '[5*]N([5*])[5*]',
#  '[10*]N1C(=O)N(C)CC1O',
#  '[16*]c1cc(Cl)c(F)c(Cl)c1F',
#  'Oc1cccc(O)c1',
#  '[9*]n1cnc2c1c(=O)n(C)c(=O)n2C',
#  '[1*]C(=O)C([8*])[8*]',
#  'CCC(CC)CO',
#  '[8*]CC',
#  '[7*]C(C)C',
#  'Nc1ccccc1',
#  'C1CCCCCCC1',
#  'Nc1cccc([N+](=O)[O-])c1',
#  '[10*]N1C(=O)c2cc(S(N)(=O)=O)c(Cl)cc2NC1C',
#  'Clc1ccccc1',
#  '[3*]OC(F)F',
#  'Cc1cccc(C)c1',
#  'CC(C)CC(C)C',
#  '[9*]n1ncc([16*])c(Cl)c1=O',
#  '[15*]C1([15*])C(=O)NC(=S)NC1=O',
#  '[9*]n1c(=O)oc2cc(Cl)ccc21',
#  '[15*]C1([15*])C(=O)NCNC1=O',
#  '[16*]c1cccc(Cl)c1',
#  '[14*]c1nc([14*])nc([14*])n1',
#  'CCCCCC(C)=O',
#  'CC1CCCO1',
#  'CC12CCC3c4ccc(O)cc4CCC3C1CCC2O',
#  '[16*]c1c(O)c(Cl)c(Cl)c(Cl)c1Cl',
#  'CC12CCC(=O)C=C1CCC1C2CCC2(C)C(O)CCC12',
#  'Cc1cc(C)c(C)c(C)c1C',
#  'Oc1ccc2ncccc2c1',
#  'c1ccc2c(c1)cc1ccc3cccc4ccc2c1c34',
#  '[16*]c1cncnc1',
#  'Cc1ccc(N=CN(C)C=Nc2ccc(C)cc2C)c(C)c1',
#  'FC(F)(Cl)C(F)(Cl)Cl',
#  'Cc1ccc(Br)cc1',
#  '[13*]C12OC(C)(C)OC1CC1C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC12C',
#  '[10*]N1CC([15*])C(Cl)C1=O',
#  '[6*]C([6*])=O',
#  'Oc1c(Cl)cc(Cl)cc1Cl',
#  'Oc1ccccc1',
#  'ClC1(Cl)C2(Cl)C3(Cl)C4(Cl)C(Cl)(Cl)C5(Cl)C3(Cl)C1(Cl)C5(Cl)C24Cl',
#  '[15*]C1CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C1([15*])O',
#  '[15*]C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3CCC21C',
#  'Cc1ccc(C)cc1',
#  'N#CN=C(N)N',
#  'CC12CCC(CC1)C(C)(C)O2',
#  'Nc1ccccc1O',
#  'c1ccc2c(c1)Cc1ccccc1-2',
#  '[14*]c1cc(Cl)nc(N(C=O)NS(=O)(=O)c2ccccc2[16*])n1',
#  'Clc1ccccc1I',
#  'O=C1c2ccccc2C(=O)c2ccccc21',
#  '[4*]C([8*])(C)C',
#  '[14*]c1ncnc2nccnc12',
#  'CN1C(=O)c2cccnc2Oc2ccccc21',
#  '[7*]CCO',
#  'Cc1cccc2c1Cc1ccccc1-2',
#  '[1*]C(=O)S[11*]',
#  'c1ccc2c(c1)-c1cccc3c1c-2cc1ccccc13',
#  'Nc1nc[nH]n1',
#  '[5*]N([5*])C',
#  'ClCBr',
#  'Cc1cc(C)c(O)c(C)c1',
#  'CCCCCCCCCCCCCCCO',
#  '[16*]c1cccc([16*])c1',
#  '[1*]C(=O)CCCCCCCC',
#  '[5*]N([5*])SN([5*])C',
#  'CCC(C)(O)CC',
#  '[15*]C1CC2CC1C1CCCC21',
#  '[8*]CC[8*]',
#  '[4*]CCCCCCCC',
#  'CCCC(O)CC',
#  '[4*]CCCCC',
#  'N#CC(Cl)(Cl)Cl',
#  '[16*]c1c([N+](=O)[O-])cc(S(N)(=O)=O)cc1[N+](=O)[O-]',
#  '[16*]c1c(Cl)cc(Cl)c(Cl)c1Cl',
#  '[9*]n1c([N+](=O)[O-])cnc1C',
#  'Brc1ccc(Br)c(Br)c1',
#  'CC1CCCCC1C',
#  '[5*]N1c2ccccc2N(C)C(=S)c2cccnc21',
#  'ClC=C(Cl)Cl',
#  '[3*]OS(C)(=O)=O',
#  'Cc1ccccc1N',
#  '[16*]c1ccc([N+](=O)[O-])cc1',
#  'CC12CCC3c4ccc(O)cc4CCC3C1CCC2=O',
#  'c1ccc2cc3ccccc3cc2c1',
#  'O=C1CN=C(c2ccccc2)c2cc([N+](=O)[O-])ccc2N1',
#  'ClC1=C(Cl)C2(Cl)C3CC=CC3C1(Cl)C2(Cl)Cl',
#  'c1ccc2ncccc2c1',
#  '[3*]OP(=S)(O[3*])SCSP(=S)(O[3*])O[3*]',
#  '[16*]c1cccc2c1OC(C)(C)C2',
#  'Oc1ccc2ccccc2c1',
#  'ClCC(Cl)Cl',
#  '[5*]N1CCCCC1C',
#  '[16*]c1ccccc1',
#  'CCCCC=O',
#  '[8*]CC([8*])([8*])O',
#  '[8*]CCl',
#  '[8*]C(Cl)Cl',
#  'Clc1cccc(Br)c1',
#  'c1cnc2c(c1)ccc1ncccc12',
#  '[16*]c1ccccc1Cl',
#  '[14*]c1cc(N)[n+]([O-])c(N)n1',
#  'CCN1C(=O)c2ccccc2Oc2ccccc21',
#  'CC(C)CBr',
#  'C=CC#N',
#  '[15*]C1CC(=O)NC(=O)C1',
#  'Cc1ccc2ccc(C)nc2c1',
#  'C=CCCC=C',
#  '[16*]c1c2occc2cc2ccc(=O)oc12',
#  'C=CC(C)C',
#  'CC(Cl)Cl',
#  'c1ccc2c(c1)oc1ccccc12',
#  '[8*]C([8*])CC([8*])O',
#  'Sc1nc2ccccc2s1',
#  'Cc1cc2ccccc2cc1C',
#  '[1*]C(=O)C([8*])C(C)C',
#  '[3*]OP(=O)(OC)OC',
#  'NS(=O)(=O)c1cc2c(cc1Cl)N=CNS2(=O)=O',
#  '[3*]OP(=O)(O[3*])O[3*]',
#  'Fc1ccccc1',
#  'Brc1cccc(Br)c1',
#  '[9*]n1c(=O)[nH]c2c(c1=O)CCC2',
#  'OCC(O)C(O)C(O)C(O)CO',
#  '[11*]SC(C)=O',
#  'C1=CCCCCC1',
#  'Oc1cccc2cccnc12',
#  'c1ccc2ccccc2c1',
#  '[16*]c1ccc(O)cc1O',
#  '[8*]C([8*])CC(C)=O',
#  'Cc1nnc2n1-c1ccc(Cl)cc1C(c1ccccc1Cl)=NC2',
#  '[9*]n1ccc2c(N)ncnc21',
#  'ClC(Cl)Br',
#  '[3*]OP(=S)(CC)O[3*]',
#  '[5*]N1c2ccccc2C(=O)N(C)c2ccccc21',
#  'c1cc2ccc3cccc4ccc(c1)c2c34',
#  'Ic1cccc2ccccc12',
#  '[16*]c1cc(Cl)cc(Cl)c1',
#  '[4*]C(CO)C([8*])O',
#  'Cc1cccc2ccccc12',
#  '[6*]C(C)=O',
#  '[1*]C(=O)CC([4*])C([1*])=O',
#  '[8*]CC([8*])(O)C[8*]',
#  'N#CCCCl',
#  '[7*]CC=O',
#  'O=C1C2(Cl)C3(Cl)C4(Cl)C(Cl)(Cl)C5(Cl)C3(Cl)C1(Cl)C5(Cl)C24Cl',
#  'C1=CCCC1',
#  'O=C1NC(=O)C2(CC2)C(=O)N1',
#  '[14*]c1oc2cc(O)cc(O)c2c(=O)c1O',
#  '[16*]c1ccc(S(=O)(=O)c2ccccc2)cc1C',
#  'O=c1[nH]cc(F)c(=O)[nH]1',
#  'CCC(C)C(C)C',
#  '[7*]C(Cl)C(F)(F)F',
#  '[4*]CC(CC)CCCC',
#  'C#CCCCCCCC',
#  '[3*]OC1c2cc3c(cc2C(c2cc([16*])c(O)c([16*])c2)C2C(=O)OCC12)OCO3',
#  'CCCCCCCBr',
#  '[16*]c1ccc(Cl)cc1O',
#  'c1ccncc1',
#  'Nc1cccc2nc3ccccc3cc12',
#  '[16*]c1ccc(S(C)(=O)=O)cc1',
#  '[1*]C(C)=O',
#  '[4*]CC',
#  ...}

# %%
print('BRICSが取り出した全フラグメント', len(set(fr_all)))
# Out:
# BRICSが取り出した全フラグメント 1028

# %% [markdown]
# ### 部分構造の指定
# フラグメント化された構造の一部を確認しましょう。frag_libraryのSMILESをMolオブジェクトに変換したものをlist_fragmentsに格納します。

# %%
list_fragments = [Chem.MolFromSmiles(smi) for smi in frag_library]

seed_structures = list_fragments[:2]
print(len(seed_structures))
# Out:
# 2

# %% [markdown]
# フラグメントの最初の2つの構造を描画したものを表示させます。（実行ごとにランダムに変化します）

# %%
Draw.MolsToGridImage(seed_structures)

# %% [markdown]
# ### 構造生成によるバーチャルライブラリーの構築
#
# 生成されたフラグメントを利用して元の化合物以外の新しい化合物を生成し、「仮想ライブラリ」を作成します。
#
# **構造生成（Structure Generation）**:
# 構造生成は、特定の条件や性質を満たす新しい化合物をコンピュータ上で生成するプロセスを指します。化学的に妥当な構造を効率的に生成することは、薬物設計や材料科学などの分野で重要です。フラグメントを組み合わせて新しい化合物の構造生成が行えますが、`BRICS.BRICSBuild()`関数を用いると、部分構造化されたフラグメントをコンピューター上で機械的に組み合わせて新しい構造を生成することが簡単にできます。
#
# **仮想ライブラリ（Virtual Library）**:
# 仮想ライブラリとは、化学的に実際に合成されていないが、理論的には存在し得る全ての化合物の集合を指します。仮想ライブラリを用いることで、実験室で合成するのは困難な大規模な化合物集合を網羅的に探索し、有望な化合物を同定することが可能です。また、仮想ライブラリを使うことで、既知の活性を持つ化合物の拡張や、新しい化合物の探索が進められます。

# %% [markdown]
# ### BRICSBuild()のデフォルト設定での構造生成
# frag_libraryのSMILESをMolオブジェクトに変換し、component変数として格納します。続いて`BRICSBuild()`関数で機械的に構造生成を行いbuild変数に格納します。この１行の処理で仮想ライブラリの荒削りの仮想ライブラリが生成されます。

# %%
component = [Chem.MolFromSmiles(smi) for smi in frag_library]
build = BRICS.BRICSBuild(component)

# %%
build
# Out:
# <generator object BRICSBuild at 0x00000241B8F70200>

# %% [markdown]
# 【解説】`BRICS.BRICSBuild()` メソッド
#
# `BRICS.BRICSBuild()` メソッドは、フラグメントされたMolオブジェクトのリストから、新しい化合物を生成する方法を提供します。
# 使用法は以下のようになります：
#
# ```python
# BRICS.BRICSBuild(mol seeds = seed_structures, maxDepth = 3)
# ```
#
# 引数:
# - `mol`: RDKitのMolオブジェクトで、分割対象となる化合物を表します。
# - `seeds` (オプション): 構造生成で必ず含むフラグメントを指定します。
# - `maxDepth` (オプション): 結合回数を指定します。
#
# 戻り値:
# `BRICS.BRICSBuild()` は、新しい構造生成の化合物からなるMolオブジェクトのジェネレータを返します。
#
#
# 分割された部分構造を統合することで、元の化合物とは異なる新しい化合物が得られます。

# %% [markdown]
# 上記のbuildに収まっている構造生成された化合物はジェネレータ型で保持されていますので、それを次のように`next()`関数を使って逐次的に呼び出してゆきます。この時、`UpdatePropertyCache()`関数で構造が適正であるかをチェックします。そのチェックを通ったものを`append()`メソッドで、generated_molsのオブジェクトとして格納します。
# このgenerated_molsの新しく構造生成された分子集合が「仮想ライブラリ」となります。

# %%
### 分子1000個を作成
generated_mols = []

for i in range(1000):
    m = next(build)
    m.UpdatePropertyCache(strict=True)
    generated_mols.append(m)

# %% [markdown]
# 得られた1000化合物の仮想化合物のうち、90化合物を表示してみましょう。

# %%
np.random.seed(1234)
np.random.shuffle(generated_mols)

Draw.MolsToGridImage(generated_mols[:90], molsPerRow=3, subImgSize=(300,150))

# %% [markdown]
# ### 【参考】BRICSBuild()の特定のフラグメントを包含させる
# ここでは、BRICSBuild()のオプションであるseedsで必須とするフラグメントを指定し、結合回数を３回とすることで仮想ライブラリを作成する事例です。材料開発で、必ず含ませる必要がある置換基や芳香族ユニットがある場合には、このようなフラグメントを指定することでターゲット化合物を効率的に生成させることができます。

# %%
build2 = BRICS.BRICSBuild(component, seeds = seed_structures, maxDepth = 3)

# %%
### 分子1000個を作成
generated_mols = []
for i in range(1000):
    m = next(build2)
    m.UpdatePropertyCache(strict=True)
    generated_mols.append(m)

# %%
import numpy as np
import random

np.random.seed(1234)
np.random.shuffle(generated_mols)
Draw.MolsToGridImage(generated_mols[:90], molsPerRow=3, subImgSize=(300,150))

# %% [markdown]
# ## 3.構造生成とファイル保存　(底本P.125)
#
# 底本では構造生成数を10万としていますが、ここでは1万と変更しています。構造生成を逐次処理とmultiprocessingによる並列処理とで行い、その処理時間について`time`関数を使って比較を行います。
# なお、並列計算はJupyter Notebookでは作動しません。（Google Colabでは動作することに留意）

# %%
from random import seed
from time import time
from multiprocessing import Pool

# %% [markdown]
# ### 逐次処理

# %%
NUM_ITER=10000

start = time()
seed(20200315)

builder = BRICS.BRICSBuild(fragments)

with open('./results/mol_single.smi', 'w') as f:
    for i in range(NUM_ITER):
        m = next(builder)
        m.UpdatePropertyCache(strict=True)
        
        smi = Chem.MolToSmiles(m)
        f.write(smi+'\n')
        
print('Elapsed time', stopwatch(start), '[mins]')

# %% [markdown]
# ### 並列処理
# 留意：Jupyter Notebookでは作動しません。Google Colabでのときのみ処理を行うようにしてください。

# %%
NUM_ITER=10000

start2 = time()
seed(20200315)

c = 0

builder = BRICS.BRICSBuild(fragments)

with Pool(4) as p:
    f = open('./results/mol_quad.smi', 'w')
    
    for smi in p.imap(func=sample_molecule, iterable=builder, chunksize=100):
        f.write(smi+'\n')
        c+=1
        if c == NUM_ITER:
            print(c)
            break
    f.close()
    
print('Elapsed time', stopwatch(start2), '[mins]')
